# %%
# Mit diesem Code sollen alle einzelnen Berufe aus dem Jahr 1950 herausgefunden werden.

# Da die Daten zum Jahr 1950 ebenfalls noch nicht indexiert sind, wie bspw. jene fürs Jahr 1925, braucht es diesen Code.
# Der gesamte Code liest eine oder mehrere TSV-Dateien (Tab-separierte Werte) ein und zählt, wie oft bestimmte Zeichenketten in einer bestimmten Spalte auftreten, vorausgesetzt, 
# dass das Jahr in einer Zeile den Wert '1950' enthält.

# Mit diesem Code werden die notwendigen reader importiert, damit das TSV (Tab Seperated Value - also Daten, die durch Leerschläge getrennt sind) lesbar wird
# und Regular Expressions, also die strings (Zeichenketten, also einzelne Worte und Zahlen) durchsucht werden können.

import csv
import re

# Die Funktion count_strings_in_tsv_files nimmt drei Argumente entgegen: 
# - file_paths: Eine Liste von Dateipfaden zu den TSV-Dateien, die analysiert werden sollen.
# - column_name: Der Name der Spalte, in der die Zeichenketten gezählt werden sollen.
# - encoding: Das Zeichenkodierungsformat der Dateien, standardmäßig 'utf-8'.
# Ein leeres Wörterbuch namens string_counts wird erstellt, um die Zählungen der Zeichenketten zu speichern.

def count_strings_in_tsv_files(file_paths, column_name, encoding='utf-8'):
    string_counts = {}

# Die Funktion durchläuft die Datei in dem, weiter unten übergebenen Dateipfad.
# Die Datei wird geöffnet und zeilenweise eingelesen.
# Für jede Zeile (row) in der TSV-Datei wird überprüft, ob das Jahr den Wert '1950' enthält.
# Wenn das Jahr '1950' ist, wird der Inhalt der angegebenen Spalte (column_name) in der aktuellen Zeile in seine einzelnen Bestandteile aufgeteilt, die durch Kommas getrennt sein könnten.
# In dieser Spalte befinden sich auch die Berufe.
# Für jedes einzelne Element in den aufgeteilten Inhalten wird eine Bereinigung durchgeführt, um alle Zahlen aus der Zeichenkette zu entfernen.
# Wenn das bereinigte Element nicht leer ist, wird es im Zählwörterbuch string_counts aktualisiert (also, Vorkommnis +1 addiert) oder hinzugefügt.

    
    for file_path in file_paths:
        with open(file_path, 'r', encoding=encoding) as tsvfile:
            tsvreader = csv.DictReader(tsvfile, delimiter='\t')
            for row in tsvreader:
                year = row.get('Year', '')
                if '1950' in year:
                    content = row.get(column_name, '')
                    for item in content.split(','):
                        clean_item = re.sub(r'\d+', '', item.strip())
                        if clean_item:
                            if clean_item in string_counts:
                                string_counts[clean_item] += 1
                            else:
                                string_counts[clean_item] = 1
                                
# Nun wird das Wörterbuch (string_counts) zurückgegeben, das die Zählungen der bereinigten Zeichenketten enthält.

    return string_counts

# Nun wird der, im Code oben, erwähnte Dateipfad definiert, sowie die zu untersuchende Zeile (column_name). Die zuvor definierte Funktion wird aufgerufen, anhand der Argumente (file_paths und column name)
# und das Ergebnis in der Variabel (result) gespeichert.

file_paths = ['C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/Telefonbuch/c4.tsv', 'C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/Telefonbuch/c5.tsv', 'C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/Telefonbuch/c8.tsv']  # Add your file paths here
column_name = 'AggregatedContent'
result = count_strings_in_tsv_files(file_paths, column_name)

# Nun werden die Resultate (result) durchgezählt und sortiert.

sorted_result = sorted(result.items(), key=lambda x: x[1], reverse=True)

# Diese Code zeigt nun die 200 häufigsten Zeichenketten an, unter denen sich auch die Berufe befinden. Dabei wird die Zeichenkette und die Häufigkeit angezeigt.

for string, count in sorted_result[:200]:
    print(f"{string}: {count} occurrences")
# Out:
#  : 26515 occurrences
#   : 395 occurrences
#  ): 378 occurrences
#   (  ): 240 occurrences
# IO : 111 occurrences
#  IO: 111 occurrences
#  OI: 66 occurrences
#   Landwirt: 56 occurrences
# OI : 49 occurrences
#     : 44 occurrences
#   (  ) Wenn keine Antwort: 36 occurrences
#   Bundesbahnen Schweiz. Stationsbüro: 33 occurrences
#   siehe Fortsetzung: 29 occurrences
#    : 27 occurrences
# .: 27 occurrences
#   Damensalon: 17 occurrences
#  (  ): 17 occurrences
# Yverdon: 15 occurrences
#   Wenn keine Antwort: 15 occurrences
#   (  ) Gemeindekanzlei: 15 occurrences
#   (  ) Bundesbahnen Schweiz.: 15 occurrences
#   Handlung: 15 occurrences
#   f   : 14 occurrences
#   l   : 14 occurrences
#   Bankbeamter: 13 occurrences
#   Landw.: 13 occurrences
# Aigle (bis zur Automatisierung): 12 occurrences
# Langnau (Emmental): 12 occurrences
#   Schreinerei: 12 occurrences
# Schwyz: 11 occurrences
#   Angestellter: 11 occurrences
# ): 11 occurrences
#  ': 10 occurrences
# Ò : 10 occurrences
#   Lehrer: 10 occurrences
#   (  ) Betreibungsamt: 10 occurrences
#   Stationsbüro: 10 occurrences
#   Schaffhauser  : 10 occurrences
#   Frau Wwe.: 9 occurrences
#   Herrensalon: 9 occurrences
#   Kolonialwaren: 9 occurrences
#  Il : 9 occurrences
# Interlaken: 9 occurrences
#   Viehhändler: 9 occurrences
# Langnau: 9 occurrences
# (  ): 9 occurrences
# Altdorf: 9 occurrences
#   Kantonalbank Korrespondentenstelle: 9 occurrences
#   Buchhalter: 8 occurrences
#   Konditorei: 8 occurrences
#   Restaurant: 8 occurrences
#   prakt. Arzt: 8 occurrences
#   Bahnhofstr. : 8 occurrences
#   Rechtsanwalt: 8 occurrences
#   (  ) Post Telegraph öffentl. Sprechstation: 8 occurrences
#   Betriebsleiter: 8 occurrences
#   kaufm. Angest.: 7 occurrences
#   J   : 7 occurrences
#        : 7 occurrences
#   Metzgerei: 7 occurrences
#   _  : 7 occurrences
# r. Caccia: 7 occurrences
#   Zahnarzt: 7 occurrences
#   Hebamme: 7 occurrences
#   Kaufmann: 7 occurrences
#   Chauffeur: 7 occurrences
#   Hauptstr. : 7 occurrences
#   Hans: 6 occurrences
#   Herren- u.: 6 occurrences
#  .: 6 occurrences
#   Schlosserei: 6 occurrences
#   Eidg. Beamter: 6 occurrences
#   eidg. Beamter: 6 occurrences
# Bümpliz: 6 occurrences
#   Ernst: 6 occurrences
# Ì : 6 occurrences
#   Postbeamter: 6 occurrences
#   Winterthur: 6 occurrences
#   Malergeschäft: 6 occurrences
#   Bahnhof: 6 occurrences
#      : 6 occurrences
#   pasticceria: 6 occurrences
#   Baugeschäft: 6 occurrences
#   (  ) Feuermeldestelle  Im Fernverkehr    (  ) Feuerwehrkommando: 6 occurrences
#   (  ) Äusser Geschäftszeit: 6 occurrences
#   (  ) Post Telegr. öff. Sprechstation: 6 occurrences
#   Bahnhofstr.: 6 occurrences
#   Büro: 6 occurrences
# Guttannen und Meiringen: 5 occurrences
#   Tankstelle «Breite» Zürcherstr. : 5 occurrences
#   med. dent.: 5 occurrences
# ': 5 occurrences
#   Malergesch.: 5 occurrences
# u.: 5 occurrences
#   Dr. med.: 5 occurrences
#   i: 5 occurrences
#   Alpenstr. : 5 occurrences
# ' : 5 occurrences
#   Fritz: 5 occurrences
#   costruzioni: 5 occurrences
#   Wohnung: 5 occurrences
#   Bundesbahnen Schweiz. Stationsbur.: 5 occurrences
#   (  ) Feuermeldestelle: 5 occurrences
#   (  ) Sprechstation öffentl. Post: 5 occurrences
#   Landwirtschafti. Genossenschaft: 5 occurrences
#  ) : 5 occurrences
#   Schulhaus: 5 occurrences
#   (  ) Ausgleichskasse: 5 occurrences
#   (  ) Verkehrsbureau: 5 occurrences
#   Innenausbau: 5 occurrences
#   Zimmerei und: 5 occurrences
#   Seestr. : 5 occurrences
#   Badenerstr. : 5 occurrences
#   Landw. Konsumgenossenschaft: 5 occurrences
#   (  ) wenn keine Antwort: 5 occurrences
#   Asag Auto-Service AG. Aeschenplatz: 4 occurrences
#   Zollbeamter: 4 occurrences
#   Bäckerei-Kondit.: 4 occurrences
#   Bäckerei-Konditorei: 4 occurrences
#   Malermstr.: 4 occurrences
#   Tapezierer: 4 occurrences
#   Wenn keine Antwort   : 4 occurrences
# der sie angehören: 4 occurrences
#   Lehrerin: 4 occurrences
#   Maurer: 4 occurrences
#   Frau: 4 occurrences
#   Thunstr. : 4 occurrences
# IO: 4 occurrences
#   u. Damen  : 4 occurrences
#   Gen.-Dir. PTT: 4 occurrences
#   u. Tiefbau: 4 occurrences
#   Installationen: 4 occurrences
#   a: 4 occurrences
#   Angest.: 4 occurrences
#   Typograph: 4 occurrences
# Yverdon  Schwyz: 4 occurrences
#   und Möbel  : 4 occurrences
#   .: 4 occurrences
#   f    t   : 4 occurrences
#   Dr. med. dent.: 4 occurrences
#       : 4 occurrences
#   IO: 4 occurrences
#   AG.: 4 occurrences
#   Damen- und: 4 occurrences
#   Herren- und: 4 occurrences
#   (  ) Josef mech. Schreinerei: 4 occurrences
# Rabius: 4 occurrences
# Sedrun: 4 occurrences
# Tavanasa: 4 occurrences
#   Bäckerei  : 4 occurrences
#         : 4 occurrences
#   Werkmeister: 4 occurrences
#   (  ) Gemeindeammannamt: 4 occurrences
#  IO): 4 occurrences
#   (  ) Sprechstation öffentliche: 4 occurrences
#   Filiale: 4 occurrences
#   Schmiede: 4 occurrences
#   Ingenieur: 4 occurrences
#   Landwirt und: 4 occurrences
#   Elektriker: 4 occurrences
#   Bäckerei und: 4 occurrences
#   u. Handlg.: 4 occurrences
#   (  ) Post Telegr. öffentliche Sprechstation: 4 occurrences
#   Prokurist: 4 occurrences
#   Gemeinde  : 4 occurrences
#  Landwirt: 4 occurrences
#   Walter: 4 occurrences
#   Feuermeldestelle: 4 occurrences
#   Privat: 4 occurrences
#   l: 4 occurrences
#   Hauptstrasse: 4 occurrences
#   Gemeindekrankenschwester: 4 occurrences
#   j   : 4 occurrences
#   wenn keine Antwort   : 4 occurrences
#   Dufourstr. : 4 occurrences
#  IO : 4 occurrences
#   Platz: 4 occurrences
#   Advokat u. Notar: 3 occurrences
#   Hans Hans: 3 occurrences
#   Werkstätte: 3 occurrences
#   Ì   : 3 occurrences
#   Malermeister: 3 occurrences
#   oder   : 3 occurrences
#   Dr. Chemiker: 3 occurrences
# -: 3 occurrences
# * : 3 occurrences
#   t   : 3 occurrences
#   Chemiker: 3 occurrences
#   Buxtorf & Cie. AG. Spalentorweg : 3 occurrences
#   Blumengeschäft: 3 occurrences
#   I   : 3 occurrences
#   Äusser Geschäftszeit: 3 occurrences
#   Gummi-Bereifung AG. Güterstr. : 3 occurrences
#  „: 3 occurrences
#  i: 3 occurrences
#   Gymnasiallehrer: 3 occurrences
#   Maschinen u.: 3 occurrences
#   Zürcherstr. : 3 occurrences
# OI: 3 occurrences
#  Ò: 3 occurrences

# %%
# Dieser Code erstellt ein neues, leeres Wörterbuch.
grouped_result = {}

# Dieser Code zählt einzelnen Wortketten am Anfang jeder Zeile durch. Wenn die ersten vier Zeichen
# dieselben sind wie bereits im Wörterbuch vorhanden, wird es der Gruppe hinzugefügt. Wenn es noch
# keine Gruppe mit diesen vier Zeichen am Anfang gibt, wird eine neue Gruppe erstellt.
# Vier Zeichen hat sich durch ein paar Tests als ideale Länge herausgestellt, da so Metzgerei und
# Metzgerbeispielsweise in der selben Gruppe landen.

for string, count in sorted_result:
    key = string[:4]
    if key in grouped_result:
        grouped_result[key].append((string, count))
    else:
        grouped_result[key] = [(string, count)]

# Es wird nochmals ein neues, leeres Wörterbuch erstellt.
group_total_counts = {}

# Nun werden alle einzelnen Einträge in den Gruppend durchgezählt.
for key, values in grouped_result.items():
    total_count = sum(count for _, count in values)
    group_total_counts[key] = total_count

# Und als Gruppe mit Anzahl einträgen dargestellt.
for key, values in grouped_result.items():
    print(f"Gruppe: {key} ({group_total_counts[key]} Einträge total)")
    #for string, count in values:
    #    print(f"{string}: {count} Mal") Dieser Code würde die einzelnen EInträge in den Gruppen
    # anzeigen. Dies ist aber mehr verwirrend als hilfreich.
    print()
# Out:
# Gruppe:   (26515 Einträge total)
#
# Gruppe:    (395 Einträge total)
#
# Gruppe:  ) (378 Einträge total)
#
# Gruppe:   (  (10478 Einträge total)
#
# Gruppe: IO  (111 Einträge total)
#
# Gruppe:  IO (111 Einträge total)
#
# Gruppe:  OI (66 Einträge total)
#
# Gruppe:   La (1155 Einträge total)
#
# Gruppe: OI  (49 Einträge total)
#
# Gruppe:      (347 Einträge total)
#
# Gruppe:   Bu (1073 Einträge total)
#
# Gruppe:   si (61 Einträge total)
#
# Gruppe:     (27 Einträge total)
#
# Gruppe: . (27 Einträge total)
#
# Gruppe:   Da (401 Einträge total)
#
# Gruppe:  (   (206 Einträge total)
#
# Gruppe: Yver (30 Einträge total)
#
# Gruppe:   We (3267 Einträge total)
#
# Gruppe:   Ha (5420 Einträge total)
#
# Gruppe:   f  (40 Einträge total)
#
# Gruppe:   l  (103 Einträge total)
#
# Gruppe:   Ba (1644 Einträge total)
#
# Gruppe: Aigl (26 Einträge total)
#
# Gruppe: Lang (29 Einträge total)
#
# Gruppe:   Sc (4365 Einträge total)
#
# Gruppe: Schw (25 Einträge total)
#
# Gruppe:   An (1097 Einträge total)
#
# Gruppe: ) (11 Einträge total)
#
# Gruppe:  ' (10 Einträge total)
#
# Gruppe: Ò  (10 Einträge total)
#
# Gruppe:   Le (1232 Einträge total)
#
# Gruppe:   St (2809 Einträge total)
#
# Gruppe:   Fr (4457 Einträge total)
#
# Gruppe:   He (3771 Einträge total)
#
# Gruppe:   Ko (963 Einträge total)
#
# Gruppe:  Il  (19 Einträge total)
#
# Gruppe: Inte (19 Einträge total)
#
# Gruppe:   Vi (444 Einträge total)
#
# Gruppe: (  ) (135 Einträge total)
#
# Gruppe: Altd (12 Einträge total)
#
# Gruppe:   Ka (2559 Einträge total)
#
# Gruppe:   Re (1371 Einträge total)
#
# Gruppe:   pr (24 Einträge total)
#
# Gruppe:   Be (1942 Einträge total)
#
# Gruppe:   ka (61 Einträge total)
#
# Gruppe:   J  (28 Einträge total)
#
# Gruppe:   Me (1448 Einträge total)
#
# Gruppe:   _  (46 Einträge total)
#
# Gruppe: r. C (17 Einträge total)
#
# Gruppe:   Za (229 Einträge total)
#
# Gruppe:   Ch (768 Einträge total)
#
# Gruppe:  . (6 Einträge total)
#
# Gruppe:   Ei (323 Einträge total)
#
# Gruppe:   ei (17 Einträge total)
#
# Gruppe: Bümp (16 Einträge total)
#
# Gruppe:   Er (3301 Einträge total)
#
# Gruppe: Ì  (6 Einträge total)
#
# Gruppe:   Po (941 Einträge total)
#
# Gruppe:   Wi (2550 Einträge total)
#
# Gruppe:   Ma (5318 Einträge total)
#
# Gruppe:   pa (16 Einträge total)
#
# Gruppe:   Bü (741 Einträge total)
#
# Gruppe: Gutt (21 Einträge total)
#
# Gruppe:   Ta (316 Einträge total)
#
# Gruppe:   me (43 Einträge total)
#
# Gruppe: ' (5 Einträge total)
#
# Gruppe: u. (5 Einträge total)
#
# Gruppe:   Dr (274 Einträge total)
#
# Gruppe:   i (5 Einträge total)
#
# Gruppe:   Al (2115 Einträge total)
#
# Gruppe: '  (5 Einträge total)
#
# Gruppe:   co (28 Einträge total)
#
# Gruppe:   Wo (2089 Einträge total)
#
# Gruppe:  )  (5 Einträge total)
#
# Gruppe:   In (332 Einträge total)
#
# Gruppe:   Zi (403 Einträge total)
#
# Gruppe:   Se (1035 Einträge total)
#
# Gruppe:   As (80 Einträge total)
#
# Gruppe:   Zo (142 Einträge total)
#
# Gruppe:   Bä (328 Einträge total)
#
# Gruppe: der  (66 Einträge total)
#
# Gruppe:   Th (877 Einträge total)
#
# Gruppe: IO (4 Einträge total)
#
# Gruppe:   u. (373 Einträge total)
#
# Gruppe:   Ge (2381 Einträge total)
#
# Gruppe:   a (4 Einträge total)
#
# Gruppe:   Ty (15 Einträge total)
#
# Gruppe:   un (130 Einträge total)
#
# Gruppe:   . (4 Einträge total)
#
# Gruppe:   IO (10 Einträge total)
#
# Gruppe:   AG (88 Einträge total)
#
# Gruppe: Rabi (4 Einträge total)
#
# Gruppe: Sedr (4 Einträge total)
#
# Gruppe: Tava (4 Einträge total)
#
# Gruppe:  IO) (7 Einträge total)
#
# Gruppe:   Fi (569 Einträge total)
#
# Gruppe:   El (800 Einträge total)
#
# Gruppe:   Pr (1671 Einträge total)
#
# Gruppe:  Lan (32 Einträge total)
#
# Gruppe:   Wa (3440 Einträge total)
#
# Gruppe:   Fe (1028 Einträge total)
#
# Gruppe:   l (4 Einträge total)
#
# Gruppe:   j  (36 Einträge total)
#
# Gruppe:   we (862 Einträge total)
#
# Gruppe:   Du (217 Einträge total)
#
# Gruppe:  IO  (761 Einträge total)
#
# Gruppe:   Pl (142 Einträge total)
#
# Gruppe:   Ad (331 Einträge total)
#
# Gruppe:   Ì  (9 Einträge total)
#
# Gruppe:   od (129 Einträge total)
#
# Gruppe: - (3 Einträge total)
#
# Gruppe: *  (3 Einträge total)
#
# Gruppe:   t  (22 Einträge total)
#
# Gruppe:   Bl (511 Einträge total)
#
# Gruppe:   I  (58 Einträge total)
#
# Gruppe:   Äu (244 Einträge total)
#
# Gruppe:   Gu (840 Einträge total)
#
# Gruppe:  „ (3 Einträge total)
#
# Gruppe:  i (3 Einträge total)
#
# Gruppe:   Gy (122 Einträge total)
#
# Gruppe:   Zü (211 Einträge total)
#
# Gruppe: OI (3 Einträge total)
#
# Gruppe:  Ò (3 Einträge total)
#
# Gruppe:   Co (537 Einträge total)
#
# Gruppe:   Bo (895 Einträge total)
#
# Gruppe:  l   (5 Einträge total)
#
# Gruppe:   d. (82 Einträge total)
#
# Gruppe:   Ni (324 Einträge total)
#
# Gruppe:   Li (868 Einträge total)
#
# Gruppe:   kf (5 Einträge total)
#
# Gruppe: Wabe (8 Einträge total)
#
# Gruppe:   Sp (802 Einträge total)
#
# Gruppe:   SB (18 Einträge total)
#
# Gruppe:   en (7 Einträge total)
#
# Gruppe:   Pi (333 Einträge total)
#
# Gruppe: di c (11 Einträge total)
#
# Gruppe: lì  (3 Einträge total)
#
# Gruppe: Cast (5 Einträge total)
#
# Gruppe:   Mi (604 Einträge total)
#
# Gruppe:   st (62 Einträge total)
#
# Gruppe: Hofs (3 Einträge total)
#
# Gruppe:   Sa (743 Einträge total)
#
# Gruppe:   Kf (61 Einträge total)
#
# Gruppe:   Ga (829 Einträge total)
#
# Gruppe:   Gm (55 Einträge total)
#
# Gruppe: „ (3 Einträge total)
#
# Gruppe:   P. (108 Einträge total)
#
# Gruppe:   Fa (542 Einträge total)
#
# Gruppe: Loca (4 Einträge total)
#
# Gruppe:   Fu (261 Einträge total)
#
# Gruppe:   Ob (278 Einträge total)
#
# Gruppe:   Au (865 Einträge total)
#
# Gruppe:   f (3 Einträge total)
#
# Gruppe:  ) J (8 Einträge total)
#
# Gruppe:   Mo (794 Einträge total)
#
# Gruppe:   Br (1220 Einträge total)
#
# Gruppe:  * (3 Einträge total)
#
# Gruppe:   Un (178 Einträge total)
#
# Gruppe:   ’ (3 Einträge total)
#
# Gruppe: nach (36 Einträge total)
#
# Gruppe:   Fo (259 Einträge total)
#
# Gruppe:  '   (13 Einträge total)
#
# Gruppe:   Wä (165 Einträge total)
#
# Gruppe:  ) _ (3 Einträge total)
#
# Gruppe:   iu (14 Einträge total)
#
# Gruppe:   Hs (146 Einträge total)
#
# Gruppe:   ph (8 Einträge total)
#
# Gruppe:   Gr (1070 Einträge total)
#
# Gruppe:   Ri (953 Einträge total)
#
# Gruppe:   Bi (770 Einträge total)
#
# Gruppe:   Di (409 Einträge total)
#
# Gruppe:   Ho (1047 Einträge total)
#
# Gruppe:   Si (655 Einträge total)
#
# Gruppe:   Ki (452 Einträge total)
#
# Gruppe:   Go (992 Einträge total)
#
# Gruppe: OI   (550 Einträge total)
#
# Gruppe:   Op (55 Einträge total)
#
# Gruppe:   Ve (628 Einträge total)
#
# Gruppe:  l (2 Einträge total)
#
# Gruppe:   Gl (225 Einträge total)
#
# Gruppe:   Mö (169 Einträge total)
#
# Gruppe:   Aa (25 Einträge total)
#
# Gruppe: d. F (22 Einträge total)
#
# Gruppe:   Mü (541 Einträge total)
#
# Gruppe:   Pu (54 Einträge total)
#
# Gruppe: u. s (14 Einträge total)
#
# Gruppe:  | (2 Einträge total)
#
# Gruppe: Laut (3 Einträge total)
#
# Gruppe: bei  (3 Einträge total)
#
# Gruppe: wora (6 Einträge total)
#
# Gruppe:   Wü (181 Einträge total)
#
# Gruppe: Ò (2 Einträge total)
#
# Gruppe:  .   (35 Einträge total)
#
# Gruppe:   H (2 Einträge total)
#
# Gruppe:   Or (152 Einträge total)
#
# Gruppe:  Juc (2 Einträge total)
#
# Gruppe:   Mu (259 Einträge total)
#
# Gruppe:   Ku (783 Einträge total)
#
# Gruppe: b (2 Einträge total)
#
# Gruppe:   Ap (92 Einträge total)
#
# Gruppe: städ (2 Einträge total)
#
# Gruppe:   Wu (91 Einträge total)
#
# Gruppe:   Ra (453 Einträge total)
#
# Gruppe:   Te (320 Einträge total)
#
# Gruppe:   Ci (101 Einträge total)
#
# Gruppe: a (2 Einträge total)
#
# Gruppe: * (2 Einträge total)
#
# Gruppe:   Ju (663 Einträge total)
#
# Gruppe:   Tr (637 Einträge total)
#
# Gruppe:   Do (339 Einträge total)
#
# Gruppe:   vo (213 Einträge total)
#
# Gruppe:   Ze (294 Einträge total)
#
# Gruppe:   Uh (45 Einträge total)
#
# Gruppe:   Od (51 Einträge total)
#
# Gruppe:   Lö (120 Einträge total)
#
# Gruppe:   fo (8 Einträge total)
#
# Gruppe:   E. (259 Einträge total)
#
# Gruppe:   Gi (519 Einträge total)
#
# Gruppe:   a  (10 Einträge total)
#
# Gruppe: v (2 Einträge total)
#
# Gruppe:   ca (31 Einträge total)
#
# Gruppe: vie  (14 Einträge total)
#
# Gruppe:   Ab (314 Einträge total)
#
# Gruppe:   Kü (333 Einträge total)
#
# Gruppe:   Pa (2262 Einträge total)
#
# Gruppe:   be (16 Einträge total)
#
# Gruppe:   ne (8 Einträge total)
#
# Gruppe:   le (9 Einträge total)
#
# Gruppe:   au (107 Einträge total)
#
# Gruppe:   in (34 Einträge total)
#
# Gruppe:   Ca (1091 Einträge total)
#
# Gruppe:   S. (96 Einträge total)
#
# Gruppe:   sa (13 Einträge total)
#
# Gruppe: comu (3 Einträge total)
#
# Gruppe:   se (15 Einträge total)
#
# Gruppe:   ta (4 Einträge total)
#
# Gruppe: Bern (16 Einträge total)
#
# Gruppe: v. C (8 Einträge total)
#
# Gruppe: Minu (11 Einträge total)
#
# Gruppe: Mura (7 Einträge total)
#
# Gruppe:   fr (21 Einträge total)
#
# Gruppe: Sold (4 Einträge total)
#
# Gruppe: imp. (3 Einträge total)
#
# Gruppe: Mass (6 Einträge total)
#
# Gruppe: per  (2 Einträge total)
#
# Gruppe: v. P (15 Einträge total)
#
# Gruppe:   v. (129 Einträge total)
#
# Gruppe:   la (14 Einträge total)
#
# Gruppe: r (2 Einträge total)
#
# Gruppe:   e  (15 Einträge total)
#
# Gruppe: mate (2 Einträge total)
#
# Gruppe:   du (22 Einträge total)
#
# Gruppe:  OI  (467 Einträge total)
#
# Gruppe:   Cr (90 Einträge total)
#
# Gruppe:   I (2 Einträge total)
#
# Gruppe:  — (2 Einträge total)
#
# Gruppe:  Bau (19 Einträge total)
#
# Gruppe:   Kä (262 Einträge total)
#
# Gruppe:   Oe (192 Einträge total)
#
# Gruppe:   Hu (1030 Einträge total)
#
# Gruppe: Ziff (108 Einträge total)
#
# Gruppe:   Sä (67 Einträge total)
#
# Gruppe: Butt (3 Einträge total)
#
# Gruppe: Etti (2 Einträge total)
#
# Gruppe: Nott (2 Einträge total)
#
# Gruppe: Surs (2 Einträge total)
#
# Gruppe: Trie (3 Einträge total)
#
# Gruppe: Wauw (2 Einträge total)
#
# Gruppe: f. F (9 Einträge total)
#
# Gruppe:   Ro (2383 Einträge total)
#
# Gruppe:   Jo (2593 Einträge total)
#
# Gruppe:   Lo (696 Einträge total)
#
# Gruppe:   Hü (199 Einträge total)
#
# Gruppe:   De (497 Einträge total)
#
# Gruppe:   Ww (26 Einträge total)
#
# Gruppe: .  (2 Einträge total)
#
# Gruppe:   Pf (615 Einträge total)
#
# Gruppe:   So (495 Einträge total)
#
# Gruppe:  ) H (19 Einträge total)
#
# Gruppe: Säge (5 Einträge total)
#
# Gruppe: u. W (29 Einträge total)
#
# Gruppe:   Ar (1015 Einträge total)
#
# Gruppe:  Ó (2 Einträge total)
#
# Gruppe: der (2 Einträge total)
#
# Gruppe:   Je (627 Einträge total)
#
# Gruppe:   Am (300 Einträge total)
#
# Gruppe:   Gü (137 Einträge total)
#
# Gruppe:  ? (2 Einträge total)
#
# Gruppe:   A. (77 Einträge total)
#
# Gruppe:   Kr (722 Einträge total)
#
# Gruppe:   Hä (381 Einträge total)
#
# Gruppe:  Gär (4 Einträge total)
#
# Gruppe:   j (2 Einträge total)
#
# Gruppe: Burg (4 Einträge total)
#
# Gruppe: Laus (2 Einträge total)
#
# Gruppe: La C (3 Einträge total)
#
# Gruppe: )( (2 Einträge total)
#
# Gruppe:  Anl (2 Einträge total)
#
# Gruppe:   Vo (446 Einträge total)
#
# Gruppe:  Fra (26 Einträge total)
#
# Gruppe: u. V (31 Einträge total)
#
# Gruppe: .   (2 Einträge total)
#
# Gruppe: ausg (10 Einträge total)
#
# Gruppe:   de (204 Einträge total)
#
# Gruppe:   Gä (80 Einträge total)
#
# Gruppe:   Nä (65 Einträge total)
#
# Gruppe:   Kl (450 Einträge total)
#
# Gruppe:   Xa (109 Einträge total)
#
# Gruppe:   Sk (26 Einträge total)
#
# Gruppe:   Su (358 Einträge total)
#
# Gruppe:   Lu (626 Einträge total)
#
# Gruppe:   di (52 Einträge total)
#
# Gruppe:   Ja (1849 Einträge total)
#
# Gruppe:   J. (278 Einträge total)
#
# Gruppe: Mine (3 Einträge total)
#
# Gruppe:   B. (43 Einträge total)
#
# Gruppe:   c (2 Einträge total)
#
# Gruppe: Wein (7 Einträge total)
#
# Gruppe: üniv (2 Einträge total)
#
# Gruppe:   Zu (193 Einträge total)
#
# Gruppe:   C (2 Einträge total)
#
# Gruppe: ?  (2 Einträge total)
#
# Gruppe:   G. (124 Einträge total)
#
# Gruppe:   Fl (328 Einträge total)
#
# Gruppe:  )   (72 Einträge total)
#
# Gruppe: Sees (3 Einträge total)
#
# Gruppe:   En (250 Einträge total)
#
# Gruppe:   äu (248 Einträge total)
#
# Gruppe:   Zw (135 Einträge total)
#
# Gruppe:   J (2 Einträge total)
#
# Gruppe: H. K (3 Einträge total)
#
# Gruppe: I (2 Einträge total)
#
# Gruppe: Il (2 Einträge total)
#
# Gruppe: r-   (32 Einträge total)
#
# Gruppe:   Eg (290 Einträge total)
#
# Gruppe: f. P (11 Einträge total)
#
# Gruppe: (äus (3 Einträge total)
#
# Gruppe: land (25 Einträge total)
#
# Gruppe:   Lä (83 Einträge total)
#
# Gruppe: C (2 Einträge total)
#
# Gruppe:   Fö (18 Einträge total)
#
# Gruppe:  Ï (2 Einträge total)
#
# Gruppe: IO I (8 Einträge total)
#
# Gruppe:   M. (218 Einträge total)
#
# Gruppe:   Ti (120 Einträge total)
#
# Gruppe: Flum (2 Einträge total)
#
# Gruppe: Trüb (2 Einträge total)
#
# Gruppe: Unte (5 Einträge total)
#
# Gruppe: Vätt (2 Einträge total)
#
# Gruppe: IO O (5 Einträge total)
#
# Gruppe: sind (25 Einträge total)
#
# Gruppe:   ab (29 Einträge total)
#
# Gruppe:   Eu (415 Einträge total)
#
# Gruppe:   Ot (1465 Einträge total)
#
# Gruppe: de V (1 Einträge total)
#
# Gruppe:   Ac (55 Einträge total)
#
# Gruppe: IO   (766 Einträge total)
#
# Gruppe: Zeic (72 Einträge total)
#
# Gruppe:   Em (1838 Einträge total)
#
# Gruppe:   L. (110 Einträge total)
#
# Gruppe:   Os (717 Einträge total)
#
# Gruppe: Elis (13 Einträge total)
#
# Gruppe:   Ep (30 Einträge total)
#
# Gruppe: Jako (8 Einträge total)
#
# Gruppe: . Dr (1 Einträge total)
#
# Gruppe:   Ru (1622 Einträge total)
#
# Gruppe:  Leu (8 Einträge total)
#
# Gruppe:   M  (17 Einträge total)
#
# Gruppe:   Aé (2 Einträge total)
#
# Gruppe:   H. (249 Einträge total)
#
# Gruppe:   Ae (217 Einträge total)
#
# Gruppe:   Ke (464 Einträge total)
#
# Gruppe:   Ne (454 Einträge total)
#
# Gruppe:   Rü (332 Einträge total)
#
# Gruppe:   Cl (211 Einträge total)
#
# Gruppe:    H (64 Einträge total)
#
# Gruppe:  Dic (1 Einträge total)
#
# Gruppe:   Ts (186 Einträge total)
#
# Gruppe:   Es (101 Einträge total)
#
# Gruppe:  Doe (1 Einträge total)
#
# Gruppe:   io (1 Einträge total)
#
# Gruppe:  OOl (1 Einträge total)
#
# Gruppe:   Wy (232 Einträge total)
#
# Gruppe:   Wö (22 Einträge total)
#
# Gruppe:   Is (201 Einträge total)
#
# Gruppe:   Lü (232 Einträge total)
#
# Gruppe:  Weh (2 Einträge total)
#
# Gruppe:   Cé (16 Einträge total)
#
# Gruppe:   Af (23 Einträge total)
#
# Gruppe:  Aga (1 Einträge total)
#
# Gruppe:   Ag (52 Einträge total)
#
# Gruppe:   fü (54 Einträge total)
#
# Gruppe:   f. (33 Einträge total)
#
# Gruppe: Ó  ( (4 Einträge total)
#
# Gruppe: H. G (2 Einträge total)
#
# Gruppe:   Na (274 Einträge total)
#
# Gruppe:  Wal (58 Einträge total)
#
# Gruppe: phar (12 Einträge total)
#
# Gruppe: .    (39 Einträge total)
#
# Gruppe:  Ó T (4 Einträge total)
#
# Gruppe:   F. (105 Einträge total)
#
# Gruppe:  von (4 Einträge total)
#
# Gruppe: Andr (3 Einträge total)
#
# Gruppe:   Pe (712 Einträge total)
#
# Gruppe: Enge (4 Einträge total)
#
# Gruppe:   Hi (442 Einträge total)
#
# Gruppe:  ) B (14 Einträge total)
#
# Gruppe:   Aq (3 Einträge total)
#
# Gruppe:   V. (58 Einträge total)
#
# Gruppe: -    (6 Einträge total)
#
# Gruppe:   On (4 Einträge total)
#
# Gruppe:  Fri (89 Einträge total)
#
# Gruppe:   R. (138 Einträge total)
#
# Gruppe: med. (10 Einträge total)
#
# Gruppe: spez (4 Einträge total)
#
# Gruppe:   Äs (1 Einträge total)
#
# Gruppe:   Ug (18 Einträge total)
#
# Gruppe: Ó  d (1 Einträge total)
#
# Gruppe:   ba (4 Einträge total)
#
# Gruppe:   Nü (33 Einträge total)
#
# Gruppe:   At (68 Einträge total)
#
# Gruppe:    A (45 Einträge total)
#
# Gruppe:   Ex (34 Einträge total)
#
# Gruppe: £ ™u (1 Einträge total)
#
# Gruppe:   Nv (1 Einträge total)
#
# Gruppe:   Ì. (1 Einträge total)
#
# Gruppe: @___ (2 Einträge total)
#
# Gruppe: Off. (2 Einträge total)
#
# Gruppe:   Vö (51 Einträge total)
#
# Gruppe: Spal (1 Einträge total)
#
# Gruppe:   Gh (32 Einträge total)
#
# Gruppe:   Gé (12 Einträge total)
#
# Gruppe:   Ph (125 Einträge total)
#
# Gruppe: u. A (36 Einträge total)
#
# Gruppe: str. (68 Einträge total)
#
# Gruppe:   Ed (801 Einträge total)
#
# Gruppe: (-Ha (13 Einträge total)
#
# Gruppe:  Öl  (5 Einträge total)
#
# Gruppe: v. J (4 Einträge total)
#
# Gruppe: u. K (17 Einträge total)
#
# Gruppe: o@ _ (1 Einträge total)
#
# Gruppe:    ( (4 Einträge total)
#
# Gruppe:   Bö (166 Einträge total)
#
# Gruppe:   Ef (8 Einträge total)
#
# Gruppe:  . F (1 Einträge total)
#
# Gruppe:   Id (287 Einträge total)
#
# Gruppe:  P.  (1 Einträge total)
#
# Gruppe:   W. (272 Einträge total)
#
# Gruppe:   Rö (196 Einträge total)
#
# Gruppe:  Hil (5 Einträge total)
#
# Gruppe:   Hy (17 Einträge total)
#
# Gruppe:   Kn (233 Einträge total)
#
# Gruppe:  Fil (11 Einträge total)
#
# Gruppe:   Rh (51 Einträge total)
#
# Gruppe: Luze (3 Einträge total)
#
# Gruppe: . Se (2 Einträge total)
#
# Gruppe:   Fä (58 Einträge total)
#
# Gruppe:   C. (66 Einträge total)
#
# Gruppe: orst (1 Einträge total)
#
# Gruppe:    M (52 Einträge total)
#
# Gruppe:   Ny (73 Einträge total)
#
# Gruppe: Leon (2 Einträge total)
#
# Gruppe:   Ur (108 Einträge total)
#
# Gruppe: des  (37 Einträge total)
#
# Gruppe:  S.  (3 Einträge total)
#
# Gruppe:  Han (98 Einträge total)
#
# Gruppe:   No (161 Einträge total)
#
# Gruppe: ”  B (2 Einträge total)
#
# Gruppe: Bazz (1 Einträge total)
#
# Gruppe:   i  (215 Einträge total)
#
# Gruppe: Base (2 Einträge total)
#
# Gruppe: Baum (5 Einträge total)
#
# Gruppe: Hans (25 Einträge total)
#
# Gruppe: Humm (1 Einträge total)
#
# Gruppe:    L (36 Einträge total)
#
# Gruppe:  Bei (3 Einträge total)
#
# Gruppe: Bels (1 Einträge total)
#
# Gruppe: . Be (5 Einträge total)
#
# Gruppe: . Ma (7 Einträge total)
#
# Gruppe: ^^   (1 Einträge total)
#
# Gruppe: .  J (1 Einträge total)
#
# Gruppe: Petr (1 Einträge total)
#
# Gruppe: foru (1 Einträge total)
#
# Gruppe: En-g (1 Einträge total)
#
# Gruppe: Alic (1 Einträge total)
#
# Gruppe:  Pri (31 Einträge total)
#
# Gruppe:  Flo (4 Einträge total)
#
# Gruppe: an d (14 Einträge total)
#
# Gruppe:   Mä (106 Einträge total)
#
# Gruppe:   Ir (82 Einträge total)
#
# Gruppe:  Her (28 Einträge total)
#
# Gruppe: männ (1 Einträge total)
#
# Gruppe:  Rob (23 Einträge total)
#
# Gruppe: Am K (1 Einträge total)
#
# Gruppe:  Bie (6 Einträge total)
#
# Gruppe: Ó  O (1 Einträge total)
#
# Gruppe:  Bir (3 Einträge total)
#
# Gruppe:  Emi (28 Einträge total)
#
# Gruppe:   N. (17 Einträge total)
#
# Gruppe:   Bj (3 Einträge total)
#
# Gruppe: Bld. (1 Einträge total)
#
# Gruppe: u. H (41 Einträge total)
#
# Gruppe: (-Fü (1 Einträge total)
#
# Gruppe:   Bé (17 Einträge total)
#
# Gruppe:  Max (30 Einträge total)
#
# Gruppe:  Suz (3 Einträge total)
#
# Gruppe:   Yv (18 Einträge total)
#
# Gruppe: Bien (1 Einträge total)
#
# Gruppe:   BI (3 Einträge total)
#
# Gruppe:  Osv (1 Einträge total)
#
# Gruppe:   To (203 Einträge total)
#
# Gruppe:  _ . (1 Einträge total)
#
# Gruppe:   '  (41 Einträge total)
#
# Gruppe:  Bol (7 Einträge total)
#
# Gruppe: repa (1 Einträge total)
#
# Gruppe:   .  (129 Einträge total)
#
# Gruppe:  Mal (5 Einträge total)
#
# Gruppe: ' Pr (1 Einträge total)
#
# Gruppe: f. K (7 Einträge total)
#
# Gruppe: (-Mu (1 Einträge total)
#
# Gruppe:    O (20 Einträge total)
#
# Gruppe:   Pc (1 Einträge total)
#
# Gruppe:  Wer (45 Einträge total)
#
# Gruppe: (-Br (7 Einträge total)
#
# Gruppe:  ) D (6 Einträge total)
#
# Gruppe:  ) M (10 Einträge total)
#
# Gruppe:   Hr (18 Einträge total)
#
# Gruppe:   T. (10 Einträge total)
#
# Gruppe:   Üb (2 Einträge total)
#
# Gruppe: gäss (1 Einträge total)
#
# Gruppe:  Ern (64 Einträge total)
#
# Gruppe:  Pau (45 Einträge total)
#
# Gruppe:    R (29 Einträge total)
#
# Gruppe: * Br (1 Einträge total)
#
# Gruppe: retr (2 Einträge total)
#
# Gruppe:  Bri (4 Einträge total)
#
# Gruppe: Ï  L (1 Einträge total)
#
# Gruppe:   Sö (20 Einträge total)
#
# Gruppe:    G (29 Einträge total)
#
# Gruppe:   K. (104 Einträge total)
#
# Gruppe:   Hc (245 Einträge total)
#
# Gruppe:   z. (273 Einträge total)
#
# Gruppe:  Ber (29 Einträge total)
#
# Gruppe:   Eb (125 Einträge total)
#
# Gruppe: /    (3 Einträge total)
#
# Gruppe: vorm (23 Einträge total)
#
# Gruppe:   Eh (75 Einträge total)
#
# Gruppe:  Bun (5 Einträge total)
#
# Gruppe: F. ( (1 Einträge total)
#
# Gruppe: u. D (35 Einträge total)
#
# Gruppe: Hard (2 Einträge total)
#
# Gruppe: Frei (9 Einträge total)
#
# Gruppe:    F (33 Einträge total)
#
# Gruppe: li   (3 Einträge total)
#
# Gruppe:   Ol (157 Einträge total)
#
# Gruppe: tägl (7 Einträge total)
#
# Gruppe:  Ott (36 Einträge total)
#
# Gruppe: Bürs (1 Einträge total)
#
# Gruppe:   W  (15 Einträge total)
#
# Gruppe:  Joh (27 Einträge total)
#
# Gruppe: St.  (15 Einträge total)
#
# Gruppe:   ii (2 Einträge total)
#
# Gruppe:   Ul (180 Einträge total)
#
# Gruppe: elek (31 Einträge total)
#
# Gruppe: matt (3 Einträge total)
#
# Gruppe:   Dü (130 Einträge total)
#
# Gruppe:   Ce (131 Einträge total)
#
# Gruppe:    E (61 Einträge total)
#
# Gruppe:  Äus (13 Einträge total)
#
# Gruppe: Ò Ch (1 Einträge total)
#
# Gruppe:   re (15 Einträge total)
#
# Gruppe:   Fj (2 Einträge total)
#
# Gruppe:   Ak (44 Einträge total)
#
# Gruppe:  Eld (1 Einträge total)
#
# Gruppe: Ò  ( (9 Einträge total)
#
# Gruppe:   Ah (10 Einträge total)
#
# Gruppe: Neua (5 Einträge total)
#
# Gruppe:   )  (4 Einträge total)
#
# Gruppe: (-Hi (3 Einträge total)
#
# Gruppe:   Cu (85 Einträge total)
#
# Gruppe:   Sy (27 Einträge total)
#
# Gruppe: Felt (1 Einträge total)
#
# Gruppe:   ch (10 Einträge total)
#
# Gruppe:   Uf (36 Einträge total)
#
# Gruppe: für  (36 Einträge total)
#
# Gruppe:  Dam (3 Einträge total)
#
# Gruppe:   Dä (86 Einträge total)
#
# Gruppe: Ó  H (5 Einträge total)
#
# Gruppe:   Dé (17 Einträge total)
#
# Gruppe:  Alf (17 Einträge total)
#
# Gruppe: Oi   (8 Einträge total)
#
# Gruppe:  Ver (18 Einträge total)
#
# Gruppe: chem (12 Einträge total)
#
# Gruppe: tech (22 Einträge total)
#
# Gruppe:   Nu (73 Einträge total)
#
# Gruppe:  Mar (69 Einträge total)
#
# Gruppe: Ó  D (3 Einträge total)
#
# Gruppe: Bäum (1 Einträge total)
#
# Gruppe:   Dö (45 Einträge total)
#
# Gruppe:  ) E (9 Einträge total)
#
# Gruppe: in W (1 Einträge total)
#
# Gruppe: Alfr (2 Einträge total)
#
# Gruppe:  Ò O (1 Einträge total)
#
# Gruppe:   Md (1 Einträge total)
#
# Gruppe:  _ F (1 Einträge total)
#
# Gruppe: ing. (4 Einträge total)
#
# Gruppe:  . P (3 Einträge total)
#
# Gruppe:  ' G (2 Einträge total)
#
# Gruppe: Bild (1 Einträge total)
#
# Gruppe:  Tsc (9 Einträge total)
#
# Gruppe: . Ge (2 Einträge total)
#
# Gruppe: (-Ho (5 Einträge total)
#
# Gruppe:   I. (21 Einträge total)
#
# Gruppe: (-Ke (3 Einträge total)
#
# Gruppe:  Eck (2 Einträge total)
#
# Gruppe:   Ec (42 Einträge total)
#
# Gruppe:   Et (70 Einträge total)
#
# Gruppe:   Ai (14 Einträge total)
#
# Gruppe: Steu (4 Einträge total)
#
# Gruppe: Kano (1 Einträge total)
#
# Gruppe: Rösc (2 Einträge total)
#
# Gruppe:  Jos (67 Einträge total)
#
# Gruppe: Eidg (9 Einträge total)
#
# Gruppe: Ó  E (4 Einträge total)
#
# Gruppe: von  (26 Einträge total)
#
# Gruppe:  Eis (3 Einträge total)
#
# Gruppe:   Sü (49 Einträge total)
#
# Gruppe: alle (15 Einträge total)
#
# Gruppe:   Um (30 Einträge total)
#
# Gruppe:   Va (171 Einträge total)
#
# Gruppe:  Eng (7 Einträge total)
#
# Gruppe:   Gv (1 Einträge total)
#
# Gruppe:  Rud (31 Einträge total)
#
# Gruppe:   Ly (103 Einträge total)
#
# Gruppe: Albe (4 Einträge total)
#
# Gruppe:   Im (166 Einträge total)
#
# Gruppe: Juli (3 Einträge total)
#
# Gruppe: lade (1 Einträge total)
#
# Gruppe: Etab (1 Einträge total)
#
# Gruppe:   Ev (43 Einträge total)
#
# Gruppe:   Ey (16 Einträge total)
#
# Gruppe:   Ig (11 Einträge total)
#
# Gruppe: prak (44 Einträge total)
#
# Gruppe:  Aug (6 Einträge total)
#
# Gruppe:    J (38 Einträge total)
#
# Gruppe:   Ew (15 Einträge total)
#
# Gruppe:  Jul (11 Einträge total)
#
# Gruppe:   r  (33 Einträge total)
#
# Gruppe:  E.  (5 Einträge total)
#
# Gruppe: Firs (1 Einträge total)
#
# Gruppe: qq g (1 Einträge total)
#
# Gruppe: — Ki (1 Einträge total)
#
# Gruppe: r.   (2 Einträge total)
#
# Gruppe:   Jb (23 Einträge total)
#
# Gruppe: anla (1 Einträge total)
#
# Gruppe: Flac (1 Einträge total)
#
# Gruppe: Will (15 Einträge total)
#
# Gruppe:  Sch (159 Einträge total)
#
# Gruppe: Mari (6 Einträge total)
#
# Gruppe:  Ó W (2 Einträge total)
#
# Gruppe:   It (69 Einträge total)
#
# Gruppe:    V (13 Einträge total)
#
# Gruppe: Paul (14 Einträge total)
#
# Gruppe:  Ros (9 Einträge total)
#
# Gruppe: . Fe (1 Einträge total)
#
# Gruppe: . He (5 Einträge total)
#
# Gruppe: de D (5 Einträge total)
#
# Gruppe: Emil (16 Einträge total)
#
# Gruppe:   '_ (1 Einträge total)
#
# Gruppe:  Fro (5 Einträge total)
#
# Gruppe: f. M (18 Einträge total)
#
# Gruppe:   wy (1 Einträge total)
#
# Gruppe:   Fü (95 Einträge total)
#
# Gruppe: Binn (1 Einträge total)
#
# Gruppe: konz (2 Einträge total)
#
# Gruppe: Heub (1 Einträge total)
#
# Gruppe:  Gab (4 Einträge total)
#
# Gruppe: ;.„  (1 Einträge total)
#
# Gruppe: und  (53 Einträge total)
#
# Gruppe: u. G (23 Einträge total)
#
# Gruppe: '    (5 Einträge total)
#
# Gruppe:   r— (6 Einträge total)
#
# Gruppe:  J.  (5 Einträge total)
#
# Gruppe:  Gen (6 Einträge total)
#
# Gruppe: Agen (3 Einträge total)
#
# Gruppe: A. M (3 Einträge total)
#
# Gruppe: H. H (1 Einträge total)
#
# Gruppe: L. B (1 Einträge total)
#
# Gruppe: schä (3 Einträge total)
#
# Gruppe: Uhr  (58 Einträge total)
#
# Gruppe: Sams (4 Einträge total)
#
# Gruppe:   zu (58 Einträge total)
#
# Gruppe: Buch (11 Einträge total)
#
# Gruppe:   Ls (3 Einträge total)
#
# Gruppe: Gers (3 Einträge total)
#
# Gruppe:  Car (5 Einträge total)
#
# Gruppe:  Gie (1 Einträge total)
#
# Gruppe:  Gia (3 Einträge total)
#
# Gruppe:  Gis (6 Einträge total)
#
# Gruppe: . .  (7 Einträge total)
#
# Gruppe: sieh (16 Einträge total)
#
# Gruppe:  ß (1 Einträge total)
#
# Gruppe:  - P (1 Einträge total)
#
# Gruppe:  Gle (1 Einträge total)
#
# Gruppe: ”OI  (1 Einträge total)
#
# Gruppe:   Gö (60 Einträge total)
#
# Gruppe: (-Ur (1 Einträge total)
#
# Gruppe:   Gn (33 Einträge total)
#
# Gruppe:   Hö (144 Einträge total)
#
# Gruppe:  Gol (3 Einträge total)
#
# Gruppe:   Jd (2 Einträge total)
#
# Gruppe: Priv (22 Einträge total)
#
# Gruppe:  «   (3 Einträge total)
#
# Gruppe: Gren (1 Einträge total)
#
# Gruppe:  Gre (5 Einträge total)
#
# Gruppe: Hein (10 Einträge total)
#
# Gruppe: u. e (3 Einträge total)
#
# Gruppe:   Gs (36 Einträge total)
#
# Gruppe: ce S (1 Einträge total)
#
# Gruppe: Wenn (4 Einträge total)
#
# Gruppe: Büro (3 Einträge total)
#
# Gruppe:  r.  (2 Einträge total)
#
# Gruppe: Walt (10 Einträge total)
#
# Gruppe: Deti (1 Einträge total)
#
# Gruppe:  Hab (4 Einträge total)
#
# Gruppe: Kohl (4 Einträge total)
#
# Gruppe:  Ì ( (3 Einträge total)
#
# Gruppe: u. k (3 Einträge total)
#
# Gruppe:  Ó H (4 Einträge total)
#
# Gruppe: Hand (13 Einträge total)
#
# Gruppe:  . ' (4 Einträge total)
#
# Gruppe: de f (4 Einträge total)
#
# Gruppe: Neue (4 Einträge total)
#
# Gruppe:   T— (1 Einträge total)
#
# Gruppe:  Har (4 Einträge total)
#
# Gruppe:   Î. (1 Einträge total)
#
# Gruppe:  Eug (9 Einträge total)
#
# Gruppe:   BA (5 Einträge total)
#
# Gruppe:   Sv (18 Einträge total)
#
# Gruppe: (-Lo (1 Einträge total)
#
# Gruppe: Ì  E (2 Einträge total)
#
# Gruppe: Coif (2 Einträge total)
#
# Gruppe: de l (8 Einträge total)
#
# Gruppe: Blum (2 Einträge total)
#
# Gruppe: Soph (2 Einträge total)
#
# Gruppe: Hugo (2 Einträge total)
#
# Gruppe: (-Dü (1 Einträge total)
#
# Gruppe:   pe (9 Einträge total)
#
# Gruppe: Erns (20 Einträge total)
#
# Gruppe:   Cä (12 Einträge total)
#
# Gruppe:  Eli (4 Einträge total)
#
# Gruppe: b. d (3 Einträge total)
#
# Gruppe:   Hl (7 Einträge total)
#
# Gruppe:   F  (2 Einträge total)
#
# Gruppe: Ì  R (6 Einträge total)
#
# Gruppe: Ó  S (4 Einträge total)
#
# Gruppe: Eter (1 Einträge total)
#
# Gruppe: Müll (7 Einträge total)
#
# Gruppe: IO ä (1 Einträge total)
#
# Gruppe: BVB. (1 Einträge total)
#
# Gruppe:   Il (68 Einträge total)
#
# Gruppe:  J   (2 Einträge total)
#
# Gruppe: ' (  (6 Einträge total)
#
# Gruppe: ' Ho (1 Einträge total)
#
# Gruppe: Geor (4 Einträge total)
#
# Gruppe: Stei (4 Einträge total)
#
# Gruppe: Thie (1 Einträge total)
#
# Gruppe:  Kat (5 Einträge total)
#
# Gruppe: W. & (1 Einträge total)
#
# Gruppe:   Lé (25 Einträge total)
#
# Gruppe:  Woh (52 Einträge total)
#
# Gruppe:  Kar (43 Einträge total)
#
# Gruppe:   If (6 Einträge total)
#
# Gruppe:    I (14 Einträge total)
#
# Gruppe:   Ih (3 Einträge total)
#
# Gruppe:  Ò   (1 Einträge total)
#
# Gruppe:  Ó I (1 Einträge total)
#
# Gruppe:    S (44 Einträge total)
#
# Gruppe: Hutg (1 Einträge total)
#
# Gruppe:   Jü (36 Einträge total)
#
# Gruppe: soin (1 Einträge total)
#
# Gruppe:  Moo (3 Einträge total)
#
# Gruppe:  Rit (11 Einträge total)
#
# Gruppe:  Ise (3 Einträge total)
#
# Gruppe: Nota (2 Einträge total)
#
# Gruppe:   ül (6 Einträge total)
#
# Gruppe:   Iw (6 Einträge total)
#
# Gruppe: @ Al (1 Einträge total)
#
# Gruppe: Hamm (3 Einträge total)
#
# Gruppe:   Jä (62 Einträge total)
#
# Gruppe:  Hel (6 Einträge total)
#
# Gruppe: Jetz (1 Einträge total)
#
# Gruppe:   Ji (6 Einträge total)
#
# Gruppe: Rapi (1 Einträge total)
#
# Gruppe:  Jor (4 Einträge total)
#
# Gruppe:   Jö (48 Einträge total)
#
# Gruppe:   Jr (1 Einträge total)
#
# Gruppe:  str (1 Einträge total)
#
# Gruppe: Volk (2 Einträge total)
#
# Gruppe: . Ju (4 Einträge total)
#
# Gruppe:   Ry (107 Einträge total)
#
# Gruppe: Vale (2 Einträge total)
#
# Gruppe: Kaeg (1 Einträge total)
#
# Gruppe:  Spr (10 Einträge total)
#
# Gruppe: Gass (2 Einträge total)
#
# Gruppe:   ]  (21 Einträge total)
#
# Gruppe: Kalt (2 Einträge total)
#
# Gruppe: Kamm (3 Einträge total)
#
# Gruppe: Kämp (2 Einträge total)
#
# Gruppe: Kant (8 Einträge total)
#
# Gruppe: Frau (12 Einträge total)
#
# Gruppe: Kays (1 Einträge total)
#
# Gruppe:   i. (22 Einträge total)
#
# Gruppe: Ï Zo (1 Einträge total)
#
# Gruppe:  Ker (3 Einträge total)
#
# Gruppe: Frit (16 Einträge total)
#
# Gruppe:  Lil (5 Einträge total)
#
# Gruppe:  Wil (34 Einträge total)
#
# Gruppe:  Kle (4 Einträge total)
#
# Gruppe:   v  (3 Einträge total)
#
# Gruppe:  Ö K (2 Einträge total)
#
# Gruppe: Ì IO (3 Einträge total)
#
# Gruppe: v. M (9 Einträge total)
#
# Gruppe:   Kö (112 Einträge total)
#
# Gruppe: v. K (11 Einträge total)
#
# Gruppe: Best (1 Einträge total)
#
# Gruppe: Korn (1 Einträge total)
#
# Gruppe:  ) K (7 Einträge total)
#
# Gruppe:  Kox (1 Einträge total)
#
# Gruppe:   V  (7 Einträge total)
#
# Gruppe: . Wa (3 Einträge total)
#
# Gruppe:  Eri (3 Einträge total)
#
# Gruppe:   ZK (1 Einträge total)
#
# Gruppe:  Led (4 Einträge total)
#
# Gruppe:    i (15 Einträge total)
#
# Gruppe: Krei (4 Einträge total)
#
# Gruppe: Werk (10 Einträge total)
#
# Gruppe:   Ut (45 Einträge total)
#
# Gruppe: Ò  E (5 Einträge total)
#
# Gruppe: Gund (2 Einträge total)
#
# Gruppe: Ober (9 Einträge total)
#
# Gruppe:   __ (9 Einträge total)
#
# Gruppe: (-Si (4 Einträge total)
#
# Gruppe: Heiz (3 Einträge total)
#
# Gruppe: (-Ro (5 Einträge total)
#
# Gruppe: de d (3 Einträge total)
#
# Gruppe: (Koh (1 Einträge total)
#
# Gruppe: eher (20 Einträge total)
#
# Gruppe: Baug (2 Einträge total)
#
# Gruppe:  Lai (1 Einträge total)
#
# Gruppe:   Vr (18 Einträge total)
#
# Gruppe: Ò  P (6 Einträge total)
#
# Gruppe: Frie (7 Einträge total)
#
# Gruppe: ‘    (3 Einträge total)
#
# Gruppe: Grim (3 Einträge total)
#
# Gruppe: d. V (3 Einträge total)
#
# Gruppe: erat (1 Einträge total)
#
# Gruppe: Real (1 Einträge total)
#
# Gruppe: Liat (1 Einträge total)
#
# Gruppe: n    (1 Einträge total)
#
# Gruppe:   ou (2 Einträge total)
#
# Gruppe:    P (54 Einträge total)
#
# Gruppe:  Ger (20 Einträge total)
#
# Gruppe: _ So (1 Einträge total)
#
# Gruppe:   bi (3 Einträge total)
#
# Gruppe: Ó  F (2 Einträge total)
#
# Gruppe: Feli (1 Einträge total)
#
# Gruppe: mâch (1 Einträge total)
#
# Gruppe:  Erw (9 Einträge total)
#
# Gruppe:  . L (1 Einträge total)
#
# Gruppe:  Lud (4 Einträge total)
#
# Gruppe:  Ges (10 Einträge total)
#
# Gruppe:  Ant (13 Einträge total)
#
# Gruppe:   -  (15 Einträge total)
#
# Gruppe: Cand (1 Einträge total)
#
# Gruppe:  Ò D (3 Einträge total)
#
# Gruppe:    W (53 Einträge total)
#
# Gruppe: Ó  M (1 Einträge total)
#
# Gruppe:  Hen (4 Einträge total)
#
# Gruppe: Dold (2 Einträge total)
#
# Gruppe:  Mau (12 Einträge total)
#
# Gruppe:  Got (26 Einträge total)
#
# Gruppe: Pols (1 Einträge total)
#
# Gruppe:  . J (2 Einträge total)
#
# Gruppe:  zn  (1 Einträge total)
#
# Gruppe: Im Z (1 Einträge total)
#
# Gruppe: priv (10 Einträge total)
#
# Gruppe:  ..  (5 Einträge total)
#
# Gruppe: . Al (1 Einträge total)
#
# Gruppe:  Mey (4 Einträge total)
#
# Gruppe: ring (1 Einträge total)
#
# Gruppe: Ò  A (2 Einträge total)
#
# Gruppe:  Geo (7 Einträge total)
#
# Gruppe: Tour (1 Einträge total)
#
# Gruppe:  Ò H (6 Einträge total)
#
# Gruppe:    K (31 Einträge total)
#
# Gruppe: Rösl (3 Einträge total)
#
# Gruppe:   ^  (1 Einträge total)
#
# Gruppe:   U. (8 Einträge total)
#
# Gruppe:   Ky (14 Einträge total)
#
# Gruppe:   et (8 Einträge total)
#
# Gruppe:  ^ M (1 Einträge total)
#
# Gruppe: Zahn (7 Einträge total)
#
# Gruppe: nerr (1 Einträge total)
#
# Gruppe: (-Zi (2 Einträge total)
#
# Gruppe: Dr.  (42 Einträge total)
#
# Gruppe:  Muc (1 Einträge total)
#
# Gruppe: Eric (2 Einträge total)
#
# Gruppe: erri (1 Einträge total)
#
# Gruppe:  Mül (10 Einträge total)
#
# Gruppe: . a  (1 Einträge total)
#
# Gruppe: (von (1 Einträge total)
#
# Gruppe: .-.  (3 Einträge total)
#
# Gruppe: d. O (2 Einträge total)
#
# Gruppe:  The (15 Einträge total)
#
# Gruppe: u. M (20 Einträge total)
#
# Gruppe:  Mün (2 Einträge total)
#
# Gruppe:   My (16 Einträge total)
#
# Gruppe:  Ò B (7 Einträge total)
#
# Gruppe:   /S (2 Einträge total)
#
# Gruppe:  Nes (1 Einträge total)
#
# Gruppe:   Nö (12 Einträge total)
#
# Gruppe: hard (2 Einträge total)
#
# Gruppe: .  N (1 Einträge total)
#
# Gruppe: . Fr (8 Einträge total)
#
# Gruppe:  Gus (5 Einträge total)
#
# Gruppe:   Oc (66 Einträge total)
#
# Gruppe:   Of (29 Einträge total)
#
# Gruppe:   Og (9 Einträge total)
#
# Gruppe:   Oh (7 Einträge total)
#
# Gruppe:   Ou (10 Einträge total)
#
# Gruppe: Paap (1 Einträge total)
#
# Gruppe: Frey (1 Einträge total)
#
# Gruppe: Vert (14 Einträge total)
#
# Gruppe:   Pé (11 Einträge total)
#
# Gruppe:  x   (2 Einträge total)
#
# Gruppe:  Mas (5 Einträge total)
#
# Gruppe: stei (1 Einträge total)
#
# Gruppe:  - u (1 Einträge total)
#
# Gruppe:  Wen (48 Einträge total)
#
# Gruppe: w— L (1 Einträge total)
#
# Gruppe:   Zy (11 Einträge total)
#
# Gruppe:   Ò  (3 Einträge total)
#
# Gruppe: (-Fl (1 Einträge total)
#
# Gruppe: Rauc (1 Einträge total)
#
# Gruppe: Pfei (1 Einträge total)
#
# Gruppe: Révi (1 Einträge total)
#
# Gruppe:  H.  (6 Einträge total)
#
# Gruppe:   al (21 Einträge total)
#
# Gruppe: phot (2 Einträge total)
#
# Gruppe: X. . (1 Einträge total)
#
# Gruppe: ' Ei (1 Einträge total)
#
# Gruppe:   Iv (8 Einträge total)
#
# Gruppe:  Sta (21 Einträge total)
#
# Gruppe:   Pn (13 Einträge total)
#
# Gruppe: Frem (1 Einträge total)
#
# Gruppe:  _ (1 Einträge total)
#
# Gruppe: — Po (1 Einträge total)
#
# Gruppe:   °  (2 Einträge total)
#
# Gruppe: Klei (7 Einträge total)
#
# Gruppe: Aeus (1 Einträge total)
#
# Gruppe: Must (1 Einträge total)
#
# Gruppe: Eilg (1 Einträge total)
#
# Gruppe:  Ell (1 Einträge total)
#
# Gruppe: Kann (1 Einträge total)
#
# Gruppe: Volt (1 Einträge total)
#
# Gruppe: Bund (1 Einträge total)
#
# Gruppe: Hole (1 Einträge total)
#
# Gruppe: Bad. (1 Einträge total)
#
# Gruppe: Pake (1 Einträge total)
#
# Gruppe: Horb (1 Einträge total)
#
# Gruppe: Marg (2 Einträge total)
#
# Gruppe: W. ( (1 Einträge total)
#
# Gruppe: (-Re (2 Einträge total)
#
# Gruppe:   py (1 Einträge total)
#
# Gruppe:   Py (3 Einträge total)
#
# Gruppe:   Ps (4 Einträge total)
#
# Gruppe:  Qua (2 Einträge total)
#
# Gruppe:   Qu (48 Einträge total)
#
# Gruppe:   Ré (9 Einträge total)
#
# Gruppe: OI M (2 Einträge total)
#
# Gruppe:   HI (4 Einträge total)
#
# Gruppe:   Rä (40 Einträge total)
#
# Gruppe:  Rad (3 Einträge total)
#
# Gruppe: „  P (3 Einträge total)
#
# Gruppe:  OC (1 Einträge total)
#
# Gruppe: Rich (4 Einträge total)
#
# Gruppe:   Ib (11 Einträge total)
#
# Gruppe: A    (1 Einträge total)
#
# Gruppe:   Sw (17 Einträge total)
#
# Gruppe:  Kri (6 Einträge total)
#
# Gruppe:   W’ (8 Einträge total)
#
# Gruppe:   AC (4 Einträge total)
#
# Gruppe:   Fé (7 Einträge total)
#
# Gruppe:  Win (5 Einträge total)
#
# Gruppe:   he (1 Einträge total)
#
# Gruppe:  z.  (14 Einträge total)
#
# Gruppe:  Rhe (6 Einträge total)
#
# Gruppe:  Ban (4 Einträge total)
#
# Gruppe:   }  (1 Einträge total)
#
# Gruppe: Ribo (1 Einträge total)
#
# Gruppe:  Hei (17 Einträge total)
#
# Gruppe:  Sol (4 Einträge total)
#
# Gruppe:  . W (4 Einträge total)
#
# Gruppe: Expe (1 Einträge total)
#
# Gruppe:  Som (3 Einträge total)
#
# Gruppe: . Ha (5 Einträge total)
#
# Gruppe:  Lou (9 Einträge total)
#
# Gruppe: Rint (1 Einträge total)
#
# Gruppe:  Emm (5 Einträge total)
#
# Gruppe: Loh  (1 Einträge total)
#
# Gruppe:   BV (1 Einträge total)
#
# Gruppe: v. R (10 Einträge total)
#
# Gruppe: Hege (2 Einträge total)
#
# Gruppe:  Roh (5 Einträge total)
#
# Gruppe: weg  (8 Einträge total)
#
# Gruppe:  Rös (7 Einträge total)
#
# Gruppe:  Rou (3 Einträge total)
#
# Gruppe: ' Pa (2 Einträge total)
#
# Gruppe:  Bot (3 Einträge total)
#
# Gruppe: kauf (2 Einträge total)
#
# Gruppe: fein (6 Einträge total)
#
# Gruppe:   SA (5 Einträge total)
#
# Gruppe:  Ó D (2 Einträge total)
#
# Gruppe: ’ -- (1 Einträge total)
#
# Gruppe:   r- (17 Einträge total)
#
# Gruppe:  l — (2 Einträge total)
#
# Gruppe: u. I (23 Einträge total)
#
# Gruppe:  Hed (6 Einträge total)
#
# Gruppe:   rr (1 Einträge total)
#
# Gruppe: Créd (1 Einträge total)
#
# Gruppe:  G.  (4 Einträge total)
#
# Gruppe: (-Bu (3 Einträge total)
#
# Gruppe:  Mat (10 Einträge total)
#
# Gruppe: Söhn (5 Einträge total)
#
# Gruppe:   M' (2 Einträge total)
#
# Gruppe:  u n (1 Einträge total)
#
# Gruppe:  x „ (1 Einträge total)
#
# Gruppe: f. L (2 Einträge total)
#
# Gruppe:  Cha (5 Einträge total)
#
# Gruppe: gesc (2 Einträge total)
#
# Gruppe: G. ( (1 Einträge total)
#
# Gruppe:   .- (1 Einträge total)
#
# Gruppe: Joha (2 Einträge total)
#
# Gruppe:   üd (2 Einträge total)
#
# Gruppe:   ze (1 Einträge total)
#
# Gruppe:  i.  (2 Einträge total)
#
# Gruppe: .  P (6 Einträge total)
#
# Gruppe: The  (1 Einträge total)
#
# Gruppe: Wohn (23 Einträge total)
#
# Gruppe: Krat (1 Einträge total)
#
# Gruppe:  . . (11 Einträge total)
#
# Gruppe:   fi (14 Einträge total)
#
# Gruppe:  ) N (3 Einträge total)
#
# Gruppe: fabr (1 Einträge total)
#
# Gruppe:   Zb (38 Einträge total)
#
# Gruppe: Ò  O (2 Einträge total)
#
# Gruppe: Ì  J (4 Einträge total)
#
# Gruppe: Uhr) (13 Einträge total)
#
# Gruppe:  | S (1 Einträge total)
#
# Gruppe:  t „ (1 Einträge total)
#
# Gruppe: Ò  C (1 Einträge total)
#
# Gruppe: . Ru (2 Einträge total)
#
# Gruppe: . Wi (2 Einträge total)
#
# Gruppe:  **  (1 Einträge total)
#
# Gruppe: Edua (2 Einträge total)
#
# Gruppe:   u- (2 Einträge total)
#
# Gruppe:   ‘  (8 Einträge total)
#
# Gruppe:  . ( (3 Einträge total)
#
# Gruppe:   Sn (5 Einträge total)
#
# Gruppe:   po (11 Einträge total)
#
# Gruppe:   an (6 Einträge total)
#
# Gruppe: de C (2 Einträge total)
#
# Gruppe: sani (14 Einträge total)
#
# Gruppe: Than (1 Einträge total)
#
# Gruppe: (-vo (3 Einträge total)
#
# Gruppe:  l P (1 Einträge total)
#
# Gruppe: (-Ki (2 Einträge total)
#
# Gruppe:    Ò (1 Einträge total)
#
# Gruppe: L n  (1 Einträge total)
#
# Gruppe:   ö  (2 Einträge total)
#
# Gruppe:  Obe (9 Einträge total)
#
# Gruppe:  Hör (1 Einträge total)
#
# Gruppe: Sund (1 Einträge total)
#
# Gruppe:   F» (1 Einträge total)
#
# Gruppe: __r_ (1 Einträge total)
#
# Gruppe: Stun (2 Einträge total)
#
# Gruppe: (-Fr (4 Einträge total)
#
# Gruppe:  x . (1 Einträge total)
#
# Gruppe: Homb (2 Einträge total)
#
# Gruppe: '   (1 Einträge total)
#
# Gruppe: Dels (1 Einträge total)
#
# Gruppe:  Ste (29 Einträge total)
#
# Gruppe:  Ì H (2 Einträge total)
#
# Gruppe:  Bäc (2 Einträge total)
#
# Gruppe:  Ani (1 Einträge total)
#
# Gruppe:   Lt (3 Einträge total)
#
# Gruppe: d. S (13 Einträge total)
#
# Gruppe: ü  S (1 Einträge total)
#
# Gruppe: Euge (1 Einträge total)
#
# Gruppe:   Sz (10 Einträge total)
#
# Gruppe: bänd (1 Einträge total)
#
# Gruppe:   SV (1 Einträge total)
#
# Gruppe:   Tu (111 Einträge total)
#
# Gruppe: Tech (5 Einträge total)
#
# Gruppe: verl (8 Einträge total)
#
# Gruppe: Test (1 Einträge total)
#
# Gruppe: Lina (4 Einträge total)
#
# Gruppe: dipi (43 Einträge total)
#
# Gruppe: engl (6 Einträge total)
#
# Gruppe:   Ue (60 Einträge total)
#
# Gruppe: Made (1 Einträge total)
#
# Gruppe:    N (9 Einträge total)
#
# Gruppe:   c) (1 Einträge total)
#
# Gruppe: e    (1 Einträge total)
#
# Gruppe:   Us (16 Einträge total)
#
# Gruppe:  Val (1 Einträge total)
#
# Gruppe:   VH (1 Einträge total)
#
# Gruppe:  Vie (2 Einträge total)
#
# Gruppe:  Vom (1 Einträge total)
#
# Gruppe:   /  (4 Einträge total)
#
# Gruppe:   VS (4 Einträge total)
#
# Gruppe:   Vu (17 Einträge total)
#
# Gruppe:   Tü (26 Einträge total)
#
# Gruppe: d. a (1 Einträge total)
#
# Gruppe: grab (1 Einträge total)
#
# Gruppe:  Nel (1 Einträge total)
#
# Gruppe:  — O (16 Einträge total)
#
# Gruppe: ('as (1 Einträge total)
#
# Gruppe: Blot (1 Einträge total)
#
# Gruppe: u. F (10 Einträge total)
#
# Gruppe: Ó  C (1 Einträge total)
#
# Gruppe: . pe (1 Einträge total)
#
# Gruppe: u. n (3 Einträge total)
#
# Gruppe: lage (1 Einträge total)
#
# Gruppe: de B (4 Einträge total)
#
# Gruppe: Antw (2 Einträge total)
#
# Gruppe:  Ì E (1 Einträge total)
#
# Gruppe: Kest (1 Einträge total)
#
# Gruppe:  Ann (13 Einträge total)
#
# Gruppe:    B (44 Einträge total)
#
# Gruppe: Ó  W (3 Einträge total)
#
# Gruppe: gepr (1 Einträge total)
#
# Gruppe:  Wis (5 Einträge total)
#
# Gruppe: Ò  W (11 Einträge total)
#
# Gruppe: Unt. (4 Einträge total)
#
# Gruppe: . Ro (6 Einträge total)
#
# Gruppe:  ) u (3 Einträge total)
#
# Gruppe: Würt (1 Einträge total)
#
# Gruppe: Seil (3 Einträge total)
#
# Gruppe:  .(' (1 Einträge total)
#
# Gruppe:   Sm (10 Einträge total)
#
# Gruppe:   Zä (13 Einträge total)
#
# Gruppe: Ò  L (4 Einträge total)
#
# Gruppe: u. a (2 Einträge total)
#
# Gruppe: Jacq (1 Einträge total)
#
# Gruppe: Karl (7 Einträge total)
#
# Gruppe:  Zie (7 Einträge total)
#
# Gruppe: in A (3 Einträge total)
#
# Gruppe:   h  (2 Einträge total)
#
# Gruppe:   Zr (3 Einträge total)
#
# Gruppe:   Zs (5 Einträge total)
#
# Gruppe:  Zub (2 Einträge total)
#
# Gruppe:    Z (26 Einträge total)
#
# Gruppe: Schl (9 Einträge total)
#
# Gruppe:  Edw (3 Einträge total)
#
# Gruppe: wenn (12 Einträge total)
#
# Gruppe: BERN (1 Einträge total)
#
# Gruppe: Emme (2 Einträge total)
#
# Gruppe:   AB (2 Einträge total)
#
# Gruppe: Reij (1 Einträge total)
#
# Gruppe:  Kur (5 Einträge total)
#
# Gruppe: Rosa (4 Einträge total)
#
# Gruppe: Aebi (2 Einträge total)
#
# Gruppe:  Ed. (7 Einträge total)
#
# Gruppe:  Aeb (5 Einträge total)
#
# Gruppe:   - (1 Einträge total)
#
# Gruppe:  Stu (12 Einträge total)
#
# Gruppe: mit  (5 Einträge total)
#
# Gruppe:   Ik (4 Einträge total)
#
# Gruppe:   da (5 Einträge total)
#
# Gruppe:  Agi (1 Einträge total)
#
# Gruppe:  Agu (1 Einträge total)
#
# Gruppe:  jjA (1 Einträge total)
#
# Gruppe: Chem (6 Einträge total)
#
# Gruppe:  All (1 Einträge total)
#
# Gruppe: fahr (2 Einträge total)
#
# Gruppe: Nikl (2 Einträge total)
#
# Gruppe: P. ( (3 Einträge total)
#
# Gruppe: ___  (3 Einträge total)
#
# Gruppe: Arbe (2 Einträge total)
#
# Gruppe:   fé (4 Einträge total)
#
# Gruppe: Arti (1 Einträge total)
#
# Gruppe: Arx  (1 Einträge total)
#
# Gruppe: Ausl (1 Einträge total)
#
# Gruppe: Rayd (1 Einträge total)
#
# Gruppe:  Aut (14 Einträge total)
#
# Gruppe: offi (6 Einträge total)
#
# Gruppe: f. B (2 Einträge total)
#
# Gruppe:  Big (2 Einträge total)
#
# Gruppe:   wo (2 Einträge total)
#
# Gruppe: Zeit (2 Einträge total)
#
# Gruppe:   te (16 Einträge total)
#
# Gruppe: (-Ba (8 Einträge total)
#
# Gruppe:  Wym (2 Einträge total)
#
# Gruppe: A.G  (1 Einträge total)
#
# Gruppe:  iO  (1 Einträge total)
#
# Gruppe: ’ We (1 Einträge total)
#
# Gruppe: Wi I (1 Einträge total)
#
# Gruppe: Ì  S (4 Einträge total)
#
# Gruppe: au g (1 Einträge total)
#
# Gruppe: Wint (2 Einträge total)
#
# Gruppe: E. D (1 Einträge total)
#
# Gruppe: Äuss (4 Einträge total)
#
# Gruppe:   II (15 Einträge total)
#
# Gruppe:   IV (5 Einträge total)
#
# Gruppe: de b (34 Einträge total)
#
# Gruppe:   a. (15 Einträge total)
#
# Gruppe: Beer (2 Einträge total)
#
# Gruppe: d. B (13 Einträge total)
#
# Gruppe: in F (11 Einträge total)
#
# Gruppe: d. I (3 Einträge total)
#
# Gruppe: wese (1 Einträge total)
#
# Gruppe: Uhr. (1 Einträge total)
#
# Gruppe: i. F (19 Einträge total)
#
# Gruppe:  Osc (4 Einträge total)
#
# Gruppe: u. S (57 Einträge total)
#
# Gruppe:   mi (2 Einträge total)
#
# Gruppe:  zum (2 Einträge total)
#
# Gruppe:   ju (10 Einträge total)
#
# Gruppe:  Bur (16 Einträge total)
#
# Gruppe: jun. (17 Einträge total)
#
# Gruppe:  Bom (2 Einträge total)
#
# Gruppe:  Bon (2 Einträge total)
#
# Gruppe:   bu (5 Einträge total)
#
# Gruppe: „  H (3 Einträge total)
#
# Gruppe: (-Zu (2 Einträge total)
#
# Gruppe: Lieb (1 Einträge total)
#
# Gruppe:  Ric (7 Einträge total)
#
# Gruppe: Chut (1 Einträge total)
#
# Gruppe: Neub (1 Einträge total)
#
# Gruppe: Bert (2 Einträge total)
#
# Gruppe:  Osk (9 Einträge total)
#
# Gruppe:  Buc (12 Einträge total)
#
# Gruppe:    D (14 Einträge total)
#
# Gruppe:  Bef (1 Einträge total)
#
# Gruppe:  Dep (1 Einträge total)
#
# Gruppe:  „ l (1 Einträge total)
#
# Gruppe: Parl (1 Einträge total)
#
# Gruppe:  Eid (2 Einträge total)
#
# Gruppe:   va (17 Einträge total)
#
# Gruppe: .Reg (1 Einträge total)
#
# Gruppe:  Ò P (6 Einträge total)
#
# Gruppe: mech (42 Einträge total)
#
# Gruppe:  Chr (21 Einträge total)
#
# Gruppe:  Duf (2 Einträge total)
#
# Gruppe: Trau (2 Einträge total)
#
# Gruppe: Räbl (1 Einträge total)
#
# Gruppe: Sche (2 Einträge total)
#
# Gruppe: civi (1 Einträge total)
#
# Gruppe:   su (4 Einträge total)
#
# Gruppe:    C (26 Einträge total)
#
# Gruppe: de I (2 Einträge total)
#
# Gruppe: d. K (12 Einträge total)
#
# Gruppe: Suva (1 Einträge total)
#
# Gruppe: soz. (14 Einträge total)
#
# Gruppe:  Cit (2 Einträge total)
#
# Gruppe:   üa (1 Einträge total)
#
# Gruppe: pr D (1 Einträge total)
#
# Gruppe: Clai (1 Einträge total)
#
# Gruppe: f. f (2 Einträge total)
#
# Gruppe:   gl (1 Einträge total)
#
# Gruppe:   gé (2 Einträge total)
#
# Gruppe:  . B (3 Einträge total)
#
# Gruppe:  ) P (19 Einträge total)
#
# Gruppe: bis  (6 Einträge total)
#
# Gruppe:   ga (2 Einträge total)
#
# Gruppe:   D. (6 Einträge total)
#
# Gruppe: (-Gu (3 Einträge total)
#
# Gruppe: . Da (1 Einträge total)
#
# Gruppe: Gesu (1 Einträge total)
#
# Gruppe: in G (1 Einträge total)
#
# Gruppe: Dett (2 Einträge total)
#
# Gruppe:  K.  (4 Einträge total)
#
# Gruppe:   D’ (2 Einträge total)
#
# Gruppe: bteu (1 Einträge total)
#
# Gruppe:  Dis (2 Einträge total)
#
# Gruppe: la L (2 Einträge total)
#
# Gruppe:  Jea (6 Einträge total)
#
# Gruppe: i-Pi (1 Einträge total)
#
# Gruppe:   BE (12 Einträge total)
#
# Gruppe:  de  (4 Einträge total)
#
# Gruppe:  Den (1 Einträge total)
#
# Gruppe: télé (2 Einträge total)
#
# Gruppe: Edel (1 Einträge total)
#
# Gruppe: Ò An (1 Einträge total)
#
# Gruppe:  Ren (3 Einträge total)
#
# Gruppe: (-W  (1 Einträge total)
#
# Gruppe: Pike (1 Einträge total)
#
# Gruppe:  Rep (3 Einträge total)
#
# Gruppe: and  (1 Einträge total)
#
# Gruppe:   Eq (2 Einträge total)
#
# Gruppe: /-%  (1 Einträge total)
#
# Gruppe:   PT (2 Einträge total)
#
# Gruppe:   Ez (7 Einträge total)
#
# Gruppe: Bros (1 Einträge total)
#
# Gruppe:  Eva (3 Einträge total)
#
# Gruppe: Fank (1 Einträge total)
#
# Gruppe:  Arn (14 Einträge total)
#
# Gruppe:  Fas (1 Einträge total)
#
# Gruppe: zum  (7 Einträge total)
#
# Gruppe:   ev (7 Einträge total)
#
# Gruppe: Pres (1 Einträge total)
#
# Gruppe: Ì Ka (1 Einträge total)
#
# Gruppe:  Ó M (4 Einträge total)
#
# Gruppe: Ò Er (1 Einträge total)
#
# Gruppe: Le P (1 Einträge total)
#
# Gruppe:  Lin (8 Einträge total)
#
# Gruppe: Swis (1 Einträge total)
#
# Gruppe: (-Di (3 Einträge total)
#
# Gruppe: (-Mü (3 Einträge total)
#
# Gruppe: fédé (3 Einträge total)
#
# Gruppe: Ò  F (6 Einträge total)
#
# Gruppe: (-So (2 Einträge total)
#
# Gruppe: Amba (1 Einträge total)
#
# Gruppe: Mara (1 Einträge total)
#
# Gruppe:  Con (5 Einträge total)
#
# Gruppe: Ò  M (11 Einträge total)
#
# Gruppe: Merk (3 Einträge total)
#
# Gruppe:  Tan (4 Einträge total)
#
# Gruppe:   Hé (12 Einträge total)
#
# Gruppe:  C F (1 Einträge total)
#
# Gruppe:  Ida (6 Einträge total)
#
# Gruppe: Zur  (1 Einträge total)
#
# Gruppe: Lade (1 Einträge total)
#
# Gruppe: Q  P (1 Einträge total)
#
# Gruppe: erst (2 Einträge total)
#
# Gruppe:  Nik (4 Einträge total)
#
# Gruppe: (-v. (2 Einträge total)
#
# Gruppe: „@ A (1 Einträge total)
#
# Gruppe:  Ing (4 Einträge total)
#
# Gruppe: de s (3 Einträge total)
#
# Gruppe: Expr (1 Einträge total)
#
# Gruppe: . _  (1 Einträge total)
#
# Gruppe: de v (2 Einträge total)
#
# Gruppe: Helv (3 Einträge total)
#
# Gruppe:  Ò W (7 Einträge total)
#
# Gruppe: .Hel (1 Einträge total)
#
# Gruppe: féd. (1 Einträge total)
#
# Gruppe:   Gf (23 Einträge total)
#
# Gruppe: v. G (11 Einträge total)
#
# Gruppe: „.   (1 Einträge total)
#
# Gruppe: frei (4 Einträge total)
#
# Gruppe: Glas (1 Einträge total)
#
# Gruppe:  Gla (5 Einträge total)
#
# Gruppe: a. d (6 Einträge total)
#
# Gruppe: Co.  (19 Einträge total)
#
# Gruppe: d. Z (5 Einträge total)
#
# Gruppe: tail (1 Einträge total)
#
# Gruppe: Max  (6 Einträge total)
#
# Gruppe: Otto (9 Einträge total)
#
# Gruppe:  Fr. (5 Einträge total)
#
# Gruppe: Simo (2 Einträge total)
#
# Gruppe: Köni (3 Einträge total)
#
# Gruppe: Spin (5 Einträge total)
#
# Gruppe: au B (2 Einträge total)
#
# Gruppe:   SI (10 Einträge total)
#
# Gruppe: im H (2 Einträge total)
#
# Gruppe: Fußp (1 Einträge total)
#
# Gruppe: Frid (1 Einträge total)
#
# Gruppe: Züri (12 Einträge total)
#
# Gruppe: t    (2 Einträge total)
#
# Gruppe:  _   (4 Einträge total)
#
# Gruppe: __ H (1 Einträge total)
#
# Gruppe:  o   (1 Einträge total)
#
# Gruppe:  Häu (1 Einträge total)
#
# Gruppe: ' Er (1 Einträge total)
#
# Gruppe: berg (9 Einträge total)
#
# Gruppe: Bier (1 Einträge total)
#
# Gruppe: Astr (3 Einträge total)
#
# Gruppe: ATT  (1 Einträge total)
#
# Gruppe:   br (1 Einträge total)
#
# Gruppe: Maga (2 Einträge total)
#
# Gruppe:  Ali (2 Einträge total)
#
# Gruppe: Mart (6 Einträge total)
#
# Gruppe:   BL (5 Einträge total)
#
# Gruppe: Land (25 Einträge total)
#
# Gruppe: bank (1 Einträge total)
#
# Gruppe:  _ L (1 Einträge total)
#
# Gruppe: „  A (4 Einträge total)
#
# Gruppe:   ri (10 Einträge total)
#
# Gruppe:  ] W (2 Einträge total)
#
# Gruppe: f. D (2 Einträge total)
#
# Gruppe: leum (1 Einträge total)
#
# Gruppe:  rjM (1 Einträge total)
#
# Gruppe: „  G (3 Einträge total)
#
# Gruppe: Bäre (2 Einträge total)
#
# Gruppe: „  J (2 Einträge total)
#
# Gruppe: .  F (3 Einträge total)
#
# Gruppe: Sonn (7 Einträge total)
#
# Gruppe:  Ill (2 Einträge total)
#
# Gruppe: La F (1 Einträge total)
#
# Gruppe:  Imm (1 Einträge total)
#
# Gruppe: blau (1 Einträge total)
#
# Gruppe: - Uh (5 Einträge total)
#
# Gruppe: Info (2 Einträge total)
#
# Gruppe: Flub (1 Einträge total)
#
# Gruppe:  med (2 Einträge total)
#
# Gruppe: OI . (1 Einträge total)
#
# Gruppe: nich (2 Einträge total)
#
# Gruppe:  Ins (4 Einträge total)
#
# Gruppe: im G (6 Einträge total)
#
# Gruppe: Losv (1 Einträge total)
#
# Gruppe:  n L (1 Einträge total)
#
# Gruppe: Jaco (1 Einträge total)
#
# Gruppe: Aux  (3 Einträge total)
#
# Gruppe:   —  (73 Einträge total)
#
# Gruppe: Schü (3 Einträge total)
#
# Gruppe:  Jer (2 Einträge total)
#
# Gruppe: (-Ch (3 Einträge total)
#
# Gruppe: de L (3 Einträge total)
#
# Gruppe: Jord (2 Einträge total)
#
# Gruppe:  Fel (8 Einträge total)
#
# Gruppe: Eris (1 Einträge total)
#
# Gruppe:   t- (2 Einträge total)
#
# Gruppe: Jost (1 Einträge total)
#
# Gruppe:   li (8 Einträge total)
#
# Gruppe: A.G. (1 Einträge total)
#
# Gruppe:  Käg (1 Einträge total)
#
# Gruppe:   äh (1 Einträge total)
#
# Gruppe: Anto (5 Einträge total)
#
# Gruppe: pens (11 Einträge total)
#
# Gruppe: „  L (2 Einträge total)
#
# ...
#
# Gruppe: 'Il  (1 Einträge total)
#
# Gruppe: Moos (2 Einträge total)
#
# Gruppe:  Rod (1 Einträge total)
#
# Gruppe:  Fol (1 Einträge total)
#
# Gruppe: Alex (1 Einträge total)
#
# Gruppe:  Tes (2 Einträge total)
#
# Gruppe:  Ï R (1 Einträge total)
#
# Gruppe:  Gps (1 Einträge total)
#
# Gruppe: ft z (1 Einträge total)
#
# Gruppe: Wöhr (1 Einträge total)
#
# Gruppe: Krät (1 Einträge total)
#
# Gruppe: an S (1 Einträge total)
#
# Gruppe: d. k (2 Einträge total)
#
# Gruppe: Ï  G (1 Einträge total)
#
# Gruppe:  Not (2 Einträge total)
#
# Gruppe:   Pö (1 Einträge total)
#
# Gruppe:  Tön (1 Einträge total)
#
# Gruppe:   R  (1 Einträge total)
#
# Gruppe: Ò  R (1 Einträge total)
#
# Gruppe:  Ó S (7 Einträge total)
#
# Gruppe:   Tg (1 Einträge total)
#
# Gruppe:   VO (1 Einträge total)
#
# Gruppe:   WÜ (1 Einträge total)
#
# Gruppe:   üm (1 Einträge total)
#
# Gruppe:  Auf (2 Einträge total)
#
# Gruppe:  Hem (1 Einträge total)
#
# Gruppe:  Zop (1 Einträge total)
#
# Gruppe:  Elv (1 Einträge total)
#
# Gruppe: guta (1 Einträge total)
#
# Gruppe:  Ett (2 Einträge total)
#
# Gruppe:   ae (1 Einträge total)
#
# Gruppe:   är (2 Einträge total)
#
# Gruppe: u.   (2 Einträge total)
#
# Gruppe:   Üh (1 Einträge total)
#
# Gruppe:  Seh (1 Einträge total)
#
# Gruppe:   ßa (1 Einträge total)
#
# Gruppe: ob / (1 Einträge total)
#
# Gruppe: Waff (1 Einträge total)
#
# Gruppe:   Î  (1 Einträge total)
#
# Gruppe:  „ . (1 Einträge total)
#
# Gruppe:   Ün (1 Einträge total)
#
# Gruppe: L. ( (1 Einträge total)
#
# Gruppe: Bat. (1 Einträge total)
#
# Gruppe:  Huo (1 Einträge total)
#
# Gruppe: Leop (1 Einträge total)
#
# Gruppe:  Vic (1 Einträge total)
#
# Gruppe: WJU  (1 Einträge total)
#
# Gruppe: z. H (3 Einträge total)
#
# Gruppe: Chur (1 Einträge total)
#
# Gruppe:  - D (1 Einträge total)
#
# Gruppe: Eber (1 Einträge total)
#
# Gruppe:   BÖ (1 Einträge total)
#
# Gruppe: Pfäf (2 Einträge total)
#
# Gruppe:   Ff (1 Einträge total)
#
# Gruppe:  ) - (1 Einträge total)
#
# Gruppe:  Ror (1 Einträge total)
#
# Gruppe:  --- (2 Einträge total)
#
# Gruppe: Koll (1 Einträge total)
#
# Gruppe: Ì OI (2 Einträge total)
#
# Gruppe: nebe (1 Einträge total)
#
# Gruppe: . Bä (1 Einträge total)
#
# Gruppe:  Ben (1 Einträge total)
#
# Gruppe: Seid (1 Einträge total)
#
# Gruppe:  - E (2 Einträge total)
#
# Gruppe: z. T (1 Einträge total)
#
# Gruppe: Obri (1 Einträge total)
#
# Gruppe: Revi (1 Einträge total)
#
# Gruppe: sere (1 Einträge total)
#
# Gruppe: Hung (1 Einträge total)
#
# Gruppe: c Zü (1 Einträge total)
#
# Gruppe: f. I (2 Einträge total)
#
# Gruppe:  Ï Z (1 Einträge total)
#
# Gruppe:  Näg (3 Einträge total)
#
# Gruppe:  Hoo (1 Einträge total)
#
# Gruppe: Gero (1 Einträge total)
#
# Gruppe:   Qü (1 Einträge total)
#
# Gruppe:  Î B (1 Einträge total)
#
# Gruppe:   Jw (1 Einträge total)
#
# Gruppe: Hoss (1 Einträge total)
#
# Gruppe:  Att (1 Einträge total)
#
# Gruppe: Ï  u (1 Einträge total)
#
# Gruppe:  Ì J (1 Einträge total)
#
# Gruppe:  Gai (1 Einträge total)
#
# Gruppe: Gali (1 Einträge total)
#
# Gruppe: Rebs (2 Einträge total)
#
# Gruppe:  Kd. (2 Einträge total)
#
# Gruppe: Reg’ (1 Einträge total)
#
# Gruppe:  ülr (1 Einträge total)
#
# Gruppe: Eri. (1 Einträge total)
#
# Gruppe: Ö  J (2 Einträge total)
#
# Gruppe:   WH (1 Einträge total)
#
# Gruppe:  Ö G (1 Einträge total)
#
# Gruppe:  Nuo (1 Einträge total)
#
# Gruppe:  Ó P (1 Einträge total)
#
# Gruppe: il  (1 Einträge total)
#
# Gruppe: (in  (1 Einträge total)
#
# Gruppe:  Rec (2 Einträge total)
#
# Gruppe:  Von (1 Einträge total)
#
# Gruppe: Ì )  (1 Einträge total)
#
# Gruppe:  Sem (2 Einträge total)
#
# Gruppe:   mä (2 Einträge total)
#
# Gruppe: Feri (1 Einträge total)
#
# Gruppe: AG D (1 Einträge total)
#
# Gruppe: samm (1 Einträge total)
#
# Gruppe:  pol (1 Einträge total)
#
# Gruppe: ' IO (1 Einträge total)
#
# Gruppe:   SE (1 Einträge total)
#
# Gruppe: Glat (1 Einträge total)
#
# Gruppe:  Hög (1 Einträge total)
#
# Gruppe: Huf- (1 Einträge total)
#
# Gruppe:  Wür (1 Einträge total)
#
# Gruppe:  Ó F (2 Einträge total)
#
# Gruppe: Rufe (1 Einträge total)
#
# Gruppe: naus (1 Einträge total)
#
# Gruppe:  Zel (3 Einträge total)
#
# Gruppe: rit  (1 Einträge total)
#
# Gruppe: Spcn (1 Einträge total)
#
# Gruppe:  Ò@@ (1 Einträge total)
#
# Gruppe:   (’ (1 Einträge total)
#
# Gruppe:  OI) (1 Einträge total)
#
# Gruppe: ) Jo (2 Einträge total)
#
# Gruppe:  Ì)  (1 Einträge total)
#
# Gruppe: z. R (4 Einträge total)
#
# Gruppe: ciré (1 Einträge total)
#
# Gruppe:  — - (1 Einträge total)
#
# Gruppe:  - G (1 Einträge total)
#
# Gruppe:  Gun (1 Einträge total)
#
# Gruppe:   H  (2 Einträge total)
#
# Gruppe:  Dru (1 Einträge total)
#
# Gruppe:   MI (1 Einträge total)
#
# Gruppe:  Zim (1 Einträge total)
#
# Gruppe: Am s (1 Einträge total)
#
# Gruppe: Laad (1 Einträge total)
#
# Gruppe: Heer (1 Einträge total)
#
# Gruppe: ” ’  (1 Einträge total)
#
# Gruppe: E. u (1 Einträge total)
#
# Gruppe: °  H (1 Einträge total)
#
# Gruppe:  M o (1 Einträge total)
#
# Gruppe:  Lip (2 Einträge total)
#
# Gruppe: ÌÌ   (1 Einträge total)
#
# Gruppe: iÖ   (1 Einträge total)
#
# Gruppe: jede (2 Einträge total)
#
# Gruppe:   wm (1 Einträge total)
#
# Gruppe: '  w (1 Einträge total)
#
# Gruppe: u.sa (1 Einträge total)
#
# Gruppe: Ï  V (1 Einträge total)
#
# Gruppe: Ferr (1 Einträge total)
#
# Gruppe: Hitt (1 Einträge total)
#
# Gruppe:  Jud (1 Einträge total)
#
# Gruppe: %% B (1 Einträge total)
#
# Gruppe:   EW (1 Einträge total)
#
# Gruppe: X Si (1 Einträge total)
#
# Gruppe: beam (1 Einträge total)
#
# Gruppe: $ OS (1 Einträge total)
#
# Gruppe: Ì Ul (1 Einträge total)
#
# Gruppe: IA F (1 Einträge total)
#
# Gruppe: »  H (1 Einträge total)
#
# Gruppe: Ande (2 Einträge total)
#
# Gruppe: Baus (1 Einträge total)
#
# Gruppe:   ar (1 Einträge total)
#
# Gruppe: Bere (1 Einträge total)
#
# Gruppe: Bänd (1 Einträge total)
#
# Gruppe: Ï Ge (1 Einträge total)
#
# Gruppe:   SO (4 Einträge total)
#
# Gruppe:  Küt (1 Einträge total)
#
# Gruppe:  wäh (1 Einträge total)
#
# Gruppe: Ehra (1 Einträge total)
#
# Gruppe:  Hür (1 Einträge total)
#
# Gruppe: Ó  L (3 Einträge total)
#
# Gruppe:  Kud (1 Einträge total)
#
# Gruppe:  Nee (1 Einträge total)
#
# Gruppe: Pécl (1 Einträge total)
#
# Gruppe: -xW  (1 Einträge total)
#
# Gruppe: Klos (1 Einträge total)
#
# Gruppe:  OÌ  (1 Einträge total)
#
# Gruppe: Dorf (1 Einträge total)
#
# Gruppe:  Ó B (1 Einträge total)
#
# Gruppe: . La (1 Einträge total)
#
# Gruppe: Emmi (1 Einträge total)
#
# Gruppe: z. r (2 Einträge total)
#
# Gruppe:  A (1 Einträge total)
#
# Gruppe:  rot (1 Einträge total)
#
# Gruppe: Blic (3 Einträge total)
#
# Gruppe: lycr (1 Einträge total)
#
# Gruppe: S (1 Einträge total)
#
# Gruppe: jed. (1 Einträge total)
#
# Gruppe: emon (1 Einträge total)
#
# Gruppe:   F- (1 Einträge total)
#
# Gruppe: .- U (1 Einträge total)
#
# Gruppe:  Jag (1 Einträge total)
#
# Gruppe:  Kis (1 Einträge total)
#
# Gruppe:  i J (1 Einträge total)
#
# Gruppe: 'A M (1 Einträge total)
#
# Gruppe:  Rau (1 Einträge total)
#
# Gruppe: erwa (1 Einträge total)
#
# Gruppe:  Bön (1 Einträge total)
#
# Gruppe: Ï Oe (1 Einträge total)
#
# Gruppe:  erf (1 Einträge total)
#
# Gruppe: H’ha (1 Einträge total)
#
# Gruppe: !  (1 Einträge total)
#
# Gruppe: ' äu (1 Einträge total)
#
# Gruppe:  Rea (1 Einträge total)
#
# Gruppe: Tonw (1 Einträge total)
#
# Gruppe:  ^ (1 Einträge total)
#
# Gruppe:   LÜ (1 Einträge total)
#
# Gruppe:  UO (1 Einträge total)
#
# Gruppe: „ -- (1 Einträge total)
#
# Gruppe: ' -  (1 Einträge total)
#
# Gruppe: A. B (1 Einträge total)
#
# Gruppe:  ] (1 Einträge total)
#
# Gruppe:  Sti (2 Einträge total)
#
# Gruppe:  Cas (1 Einträge total)
#
# Gruppe:  Zwa (1 Einträge total)
#
# Gruppe: Boks (1 Einträge total)
#
# Gruppe:  Kit (1 Einträge total)
#
# Gruppe:   A- (1 Einträge total)
#
# Gruppe: Aebl (1 Einträge total)
#
# Gruppe: Zurb (1 Einträge total)
#
# Gruppe: Harr (1 Einträge total)
#
# Gruppe: Kirs (1 Einträge total)
#
# Gruppe: eom  (1 Einträge total)
#
# Gruppe:   MÖ (1 Einträge total)
#
# Gruppe: Î  J (1 Einträge total)
#
# Gruppe:  Kap (1 Einträge total)
#
# Gruppe: (-Hö (1 Einträge total)
#
# Gruppe: Vago (1 Einträge total)
#
# Gruppe: Orts (1 Einträge total)
#
# Gruppe:  Baz (1 Einträge total)
#
# Gruppe:  Mär (1 Einträge total)
#
# Gruppe: Näfe (1 Einträge total)
#
# Gruppe:  Büg (1 Einträge total)
#
# Gruppe: o___ (1 Einträge total)
#
# Gruppe: ÏO   (1 Einträge total)
#
# Gruppe: /Rhe (1 Einträge total)
#
# Gruppe: r.  (1 Einträge total)
#
# Gruppe: - bi (1 Einträge total)
#
# Gruppe: .  V (1 Einträge total)
#
# Gruppe:  Obr (1 Einträge total)
#
# Gruppe: Coil (1 Einträge total)
#
# Gruppe: (.'e (1 Einträge total)
#
# Gruppe:  Gui (1 Einträge total)
#
# Gruppe:   Jc (1 Einträge total)
#
# Gruppe:   ' (1 Einträge total)
#
# Gruppe: Gips (1 Einträge total)
#
# Gruppe: Kass (1 Einträge total)
#
# Gruppe:    h (1 Einträge total)
#
# Gruppe:  Th. (1 Einträge total)
#
# Gruppe: Otel (1 Einträge total)
#
# Gruppe:  Ded (1 Einträge total)
#
# Gruppe:   ( (1 Einträge total)
#
# Gruppe:  Ufe (1 Einträge total)
#
# Gruppe: sstr (1 Einträge total)
#
# Gruppe:  Läd (1 Einträge total)
#
# Gruppe:  Vig (1 Einträge total)
#
# Gruppe: Reit (1 Einträge total)
#
# Gruppe:  Ó A (2 Einträge total)
#
# Gruppe: Sema (1 Einträge total)
#
# Gruppe: La (1 Einträge total)
#
# Gruppe: Rait (1 Einträge total)
#
# Gruppe:  Ò — (1 Einträge total)
#
# Gruppe: VVer (1 Einträge total)
#
# Gruppe: Ï  R (1 Einträge total)
#
# Gruppe: ächt (1 Einträge total)
#
# Gruppe: gege (1 Einträge total)
#
# Gruppe:  Ò u (1 Einträge total)
#
# Gruppe: Ì Ma (1 Einträge total)
#
# Gruppe:  Dil (1 Einträge total)
#
# Gruppe: (-No (1 Einträge total)
#
# Gruppe:  Ó E (2 Einträge total)
#
# Gruppe: ( Ó) (1 Einträge total)
#
# Gruppe: san. (1 Einträge total)
#
# Gruppe: Oi  (1 Einträge total)
#
# Gruppe: Zano (1 Einträge total)
#
# Gruppe: Ò  Z (1 Einträge total)
#
# Gruppe:  Van (1 Einträge total)
#
# Gruppe: Hürl (1 Einträge total)
#
# Gruppe: olek (1 Einträge total)
#
# Gruppe: deh. (1 Einträge total)
#
# Gruppe: Pred (1 Einträge total)
#
# Gruppe:  t J (1 Einträge total)
#
# Gruppe: (-Bi (1 Einträge total)
#
# Gruppe:   ïk (1 Einträge total)
#
# Gruppe: (-Lä (1 Einträge total)
#
# Gruppe:  Rüd (1 Einträge total)
#
# Gruppe: . (- (1 Einträge total)
#
# Gruppe: La   (1 Einträge total)
#
# Gruppe:  int (1 Einträge total)
#
# Gruppe:  )Ro (1 Einträge total)
#
# Gruppe:  Suo (1 Einträge total)
#
# Gruppe:  Hee (1 Einträge total)
#
# Gruppe: frar (1 Einträge total)
#
# Gruppe:  Ì M (3 Einträge total)
#
# Gruppe: Thal (2 Einträge total)
#
# Gruppe:  Syf (1 Einträge total)
#
# Gruppe: ' Au (1 Einträge total)
#
# Gruppe:  Ó L (1 Einträge total)
#
# Gruppe:  Trü (1 Einträge total)
#
# Gruppe: Ì He (1 Einträge total)
#
# Gruppe:   wi (1 Einträge total)
#
# Gruppe: rete (2 Einträge total)
#
# Gruppe: Die  (1 Einträge total)
#
# Gruppe: Vorb (1 Einträge total)
#
# Gruppe: Beda (2 Einträge total)
#
# Gruppe: Soli (1 Einträge total)
#
# Gruppe: Loch (1 Einträge total)
#
# Gruppe:  Tog (1 Einträge total)
#
# Gruppe:  S.V (1 Einträge total)
#
# Gruppe: ^) (1 Einträge total)
#
# Gruppe:   T( (1 Einträge total)
#
# Gruppe: clec (1 Einträge total)
#
# Gruppe: Samn (1 Einträge total)
#
# Gruppe: Vadu (1 Einträge total)
#
# Gruppe: Wall (2 Einträge total)
#
# Gruppe: Bad  (1 Einträge total)
#
# Gruppe:   Zc (1 Einträge total)
#
# Gruppe: Ó  N (1 Einträge total)
#
# Gruppe:  Sav (1 Einträge total)
#
# Gruppe: Savo (1 Einträge total)
#
# Gruppe: Ermä (1 Einträge total)
#
# Gruppe: Fric (1 Einträge total)
#
# Gruppe: «f B (1 Einträge total)
#
# Gruppe: 'Löw (1 Einträge total)
#
# Gruppe:  t F (1 Einträge total)
#
# Gruppe: Ç  P (1 Einträge total)
#
# Gruppe: übr. (1 Einträge total)
#
# Gruppe: A  W (1 Einträge total)
#
# Gruppe: elep (1 Einträge total)
#
# Gruppe:  Mäg (1 Einträge total)
#
# Gruppe: delw (1 Einträge total)
#
# Gruppe:  Pee (1 Einträge total)
#
# Gruppe:  Ì R (1 Einträge total)
#
# Gruppe: de G (1 Einträge total)
#
# Gruppe: '  M (1 Einträge total)
#
# Gruppe: '  z (1 Einträge total)
#
# Gruppe:  Voe (1 Einträge total)
#
# Gruppe:   S- (2 Einträge total)
#
# Gruppe: Kapl (1 Einträge total)
#
# Gruppe: Kur- (1 Einträge total)
#
# Gruppe:  Fit (1 Einträge total)
#
# Gruppe: ' Ro (1 Einträge total)
#
# Gruppe:  - S (1 Einträge total)
#
# Gruppe:  Ö M (1 Einträge total)
#
# Gruppe:  Ass (1 Einträge total)
#
# Gruppe: (Eng (1 Einträge total)
#
# Gruppe: Sibl (1 Einträge total)
#
# Gruppe: «neu (1 Einträge total)
#
# Gruppe: Biet (1 Einträge total)
#
# Gruppe:  EKT (1 Einträge total)
#
# Gruppe: (-En (1 Einträge total)
#
# Gruppe:  Täu (1 Einträge total)
#
# Gruppe:  wil (1 Einträge total)
#
# Gruppe:  __  (1 Einträge total)
#
# Gruppe: Ò  v (1 Einträge total)
#
# Gruppe:  Im  (1 Einträge total)
#
# Gruppe:  psy (1 Einträge total)
#
# Gruppe: Farn (1 Einträge total)
#
# Gruppe: b. K (1 Einträge total)
#
# Gruppe: d. N (1 Einträge total)
#
# Gruppe: (-Ae (1 Einträge total)
#
# Gruppe: Ì  U (1 Einträge total)
#
# Gruppe: Ambu (1 Einträge total)
#
# Gruppe: z. O (1 Einträge total)
#
# Gruppe:  Ì (1 Einträge total)
#
# Gruppe: fore (1 Einträge total)
#
# Gruppe:  Seg (1 Einträge total)
#
# Gruppe: Wegm (2 Einträge total)
#
# Gruppe:  Ull (1 Einträge total)
#
# Gruppe: Ö (1 Einträge total)
#
# Gruppe:  Dec (1 Einträge total)
#
# Gruppe: ands (1 Einträge total)
#
# Gruppe: '  U (1 Einträge total)
#
# Gruppe: u. m (1 Einträge total)
#
# Gruppe: Thei (1 Einträge total)
#
# Gruppe:  Ì S (1 Einträge total)
#
# Gruppe: Kraf (1 Einträge total)
#
# Gruppe: Spör (1 Einträge total)
#
# Gruppe: (  Ì (1 Einträge total)
#
# Gruppe:  Sel (1 Einträge total)
#
# Gruppe:  Sty (1 Einträge total)
#
# Gruppe:  Paj (1 Einträge total)
#
# Gruppe:  -  (1 Einträge total)
#
# Gruppe: u. - (1 Einträge total)
#
# Gruppe: (-Hü (1 Einträge total)
#
# Gruppe: a* G (1 Einträge total)
#
# Gruppe: _ _  (1 Einträge total)
#
# Gruppe: f. m (1 Einträge total)
#
# Gruppe:  IBa (1 Einträge total)
#
# Gruppe:   KI (1 Einträge total)
#
# Gruppe: Bekl (1 Einträge total)
#
# Gruppe: ' we (1 Einträge total)
#
# Gruppe: Lösc (1 Einträge total)
#
# Gruppe: kirc (1 Einträge total)
#
# Gruppe: * Eb (1 Einträge total)
#
# Gruppe: . Ja (1 Einträge total)
#
# Gruppe:  Adv (1 Einträge total)
#
# Gruppe:  Ede (1 Einträge total)
#
# Gruppe:  For (2 Einträge total)
#
# Gruppe:  Güg (1 Einträge total)
#
# Gruppe:  Ink (1 Einträge total)
#
# Gruppe: Spoe (1 Einträge total)
#
# Gruppe:  Kir (1 Einträge total)
#
# Gruppe: Liec (1 Einträge total)
#
# Gruppe:  Mäh (1 Einträge total)
#
# Gruppe: J. V (1 Einträge total)
#
# Gruppe:  Näs (1 Einträge total)
#
# Gruppe:  Pon (1 Einträge total)
#
# Gruppe:  Bec (1 Einträge total)
#
# Gruppe: Brie (1 Einträge total)
#
# Gruppe:  Vad (1 Einträge total)
#
# Gruppe:  Ege (1 Einträge total)
#
# Gruppe:  Sof (1 Einträge total)
#
# Gruppe:  Soj (1 Einträge total)
#
# Gruppe:  Vai (1 Einträge total)
#
# Gruppe: ) Di (1 Einträge total)
#
# Gruppe: Dir. (1 Einträge total)
#
# Gruppe:  Exp (1 Einträge total)
#
# Gruppe:  Jäg (1 Einträge total)
#
# Gruppe: La s (1 Einträge total)
#
# Gruppe:  Ó Z (1 Einträge total)
#
# Gruppe: (-Zü (1 Einträge total)
#
# Gruppe: Café (1 Einträge total)
#
# Gruppe:   ßr (1 Einträge total)
#
# Gruppe: () F (1 Einträge total)
#
# Gruppe:  Wai (1 Einträge total)
#
# Gruppe:  _ J (1 Einträge total)
#
# Gruppe:  Elm (1 Einträge total)
#
# Gruppe:   Vc (1 Einträge total)
#
# Gruppe:  Of (1 Einträge total)
#
# Gruppe: gefü (1 Einträge total)
#
# Gruppe: Remu (1 Einträge total)
#
# Gruppe:   GA (1 Einträge total)
#
# Gruppe:   Üt (1 Einträge total)
#
# Gruppe: . Ki (1 Einträge total)
#
# Gruppe:   Ct (1 Einträge total)
#
# Gruppe: Ì  N (1 Einträge total)
#
# Gruppe: TI   (1 Einträge total)
#
# Gruppe: ’ Ga (1 Einträge total)
#
# Gruppe: Graf (1 Einträge total)
#
# Gruppe: Ó Ke (1 Einträge total)
#
# Gruppe:  Î ( (1 Einträge total)
#
# Gruppe:  ’ ( (1 Einträge total)
#
# Gruppe:  ) n (1 Einträge total)
#
# Gruppe: IO ) (1 Einträge total)
#
# Gruppe: ahen (1 Einträge total)
#
# Gruppe:   (Ò (1 Einträge total)
#
# Gruppe: (vor (1 Einträge total)
#
# Gruppe:  ( i (1 Einträge total)
#
# Gruppe: b. V (1 Einträge total)
#
# Gruppe: Ott  (1 Einträge total)
#
# Gruppe:   FB (1 Einträge total)
#
# Gruppe: text (1 Einträge total)
#
# Gruppe:   f) (1 Einträge total)
#
# Gruppe: Rick (2 Einträge total)
#
# Gruppe:  _ K (1 Einträge total)
#
# Gruppe: ' Th (1 Einträge total)
#
# Gruppe:   B- (1 Einträge total)
#
# Gruppe:  Fäh (1 Einträge total)
#
# Gruppe:  d.  (1 Einträge total)
#
# Gruppe: Gäch (1 Einträge total)
#
# Gruppe: x „  (1 Einträge total)
#
# Gruppe: Ò Vo (1 Einträge total)
#
# Gruppe:  Gub (1 Einträge total)
#
# Gruppe: Zand (1 Einträge total)
#
# Gruppe: Wilc (1 Einträge total)
#
# Gruppe:   BT (1 Einträge total)
#
# Gruppe: (-Kr (1 Einträge total)
#
# Gruppe:  Î K (1 Einträge total)
#
# Gruppe: da I (1 Einträge total)
#
# Gruppe: Ô  E (1 Einträge total)
#
# Gruppe: AG v (1 Einträge total)
#
# Gruppe: (-Za (1 Einträge total)
#
# Gruppe: (-Eg (1 Einträge total)
#
# Gruppe: de g (1 Einträge total)
#
# Gruppe: (Rob (1 Einträge total)
#
# Gruppe: . In (1 Einträge total)
#
# Gruppe: ' Di (1 Einträge total)
#
# Gruppe:  Ò A (1 Einträge total)
#
# Gruppe: Qn s (1 Einträge total)
#
# Gruppe: Ó Gä (1 Einträge total)
#
# Gruppe: Härt (1 Einträge total)
#
# Gruppe: Sepa (1 Einträge total)
#
# Gruppe:  Vee (1 Einträge total)
#
# Gruppe: ' Vi (1 Einträge total)
#
# Gruppe:  Ï W (1 Einträge total)
#
# Gruppe:   ZU (1 Einträge total)
