# %%
# Mit diesem Code sollen alle einzelnen Berufe aus dem Jahr 1900 herausgefunden werden.

# Da die Daten zum Jahr 1900 noch nicht indexiert sind, wie bspw. jene fürs Jahr 1925, braucht es diesen Code.
# Der gesamte Code liest eine oder mehrere TSV-Dateien (Tab-separierte Werte) ein und zählt, wie oft bestimmte Zeichenketten in einer bestimmten Spalte auftreten, vorausgesetzt, 
# dass das Jahr in einer anderen Zeile den Wert '1900' enthält.

# Mit diesem Code werden die notwendigen reader importiert, damit das TSV (Tab Seperated Value - also Daten, die durch Leerschläge getrennt sind) lesbar wird
# und Regular Expressions, also die strings (Zeichenketten, also einzelne Worte und Zahlen) durchsucht werden können.

import csv
import re

# Die Funktion count_strings_in_tsv_files nimmt drei Argumente entgegen: 
# - file_paths: Eine Liste von Dateipfaden zu den TSV-Dateien, die analysiert werden sollen.
# - column_name: Der Name der Spalte, in der die Zeichenketten gezählt werden sollen.
# - encoding: Das Zeichenkodierungsformat der Dateien, standardmäßig 'utf-8'.
# Ein leeres Wörterbuch namens string_counts wird erstellt, um die Zählungen der Zeichenketten zu speichern.

def count_strings_in_tsv_files(file_paths, column_name, encoding='utf-8'):
    string_counts = {}
    
# Die Funktion durchläuft jede Datei in der , weiter unten, übergebenen Dateipfad.
# Die Datei wird geöffnet und zeilenweise eingelesen.
# Für jede Zeile (row) in der TSV-Datei wird überprüft, ob das Jahr den Wert '1900' enthält.
# Wenn das Jahr '1900' ist, wird der Inhalt der angegebenen Spalte (column_name) in der aktuellen Zeile in seine einzelnen Bestandteile aufgeteilt, die durch Kommas getrennt sein könnten.
# In dieser Spalte befinden sich auch die Berufe.
# Für jedes einzelne Element in den aufgeteilten Inhalten wird eine Bereinigung durchgeführt, um alle Zahlen aus der Zeichenkette zu entfernen.
# Wenn das bereinigte Element nicht leer ist, wird es im Zählwörterbuch string_counts aktualisiert (also, Vorkommnis +1 addiert) oder hinzugefügt.


    for file_path in file_paths: 
        with open(file_path, 'r', encoding=encoding) as tsvfile:
            tsvreader = csv.DictReader(tsvfile, delimiter='\t')
            for row in tsvreader:
                year = row.get('Year', '')
                if '1900' in year:
                    content = row.get(column_name, '')
                    for item in content.split(','):
                        clean_item = re.sub(r'\d+', '', item.strip())
                        if clean_item:
                            if clean_item in string_counts:
                                string_counts[clean_item] += 1
                            else:
                                string_counts[clean_item] = 1

# Nun wird das Wörterbuch (string_counts) zurückgegeben, das die Zählungen der bereinigten Zeichenketten enthält.
                                
    return string_counts

# Nun wird der, im Code oben, erwähnte Dateipfad definiert, sowie die zu untersuchende Zeile (column_name). Die zuvor definierte Funktion wird aufgerufen, anhand der Argumente (file_paths und column name)
# und das Ergebnis in der Variabel (result) gespeichert.

file_paths = ['C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/Telefonbuch/a1.tsv']
column_name = 'AggregatedContent'
result = count_strings_in_tsv_files(file_paths, column_name)

# Nun werden die Resultate (result) durchgezählt und sortiert.

sorted_result = sorted(result.items(), key=lambda x: x[1], reverse=True)

# Diese Code zeigt nun die 400 häufigsten Zeichenketten an, unter denen sich auch die Berufe befinden. Dabei wird die Zeichenkette und die Häufigkeit angezeigt.

for string, count in sorted_result[:400]:
    print(f"{string}: {count} Mal")
# Out:
# J.: 2039 Mal
# A.: 1451 Mal
# E.: 934 Mal
# H.: 800 Mal
# G.: 754 Mal
# F.: 675 Mal
# C.: 459 Mal
# Emil: 398 Mal
# R.: 355 Mal
# Dr.: 350 Mal
# Fritz: 311 Mal
# Ed.: 310 Mal
# W.: 306 Mal
# L.: 289 Mal
# M.: 284 Mal
# Fr.: 271 Mal
# Gebr.: 264 Mal
# Louis: 258 Mal
# Joh.: 244 Mal
# Th.: 242 Mal
# Alb.: 240 Mal
# Albert: 232 Mal
# Carl: 229 Mal
# Jean: 211 Mal
# Hans: 205 Mal
# Paul: 198 Mal
# Jakob: 197 Mal
# B.: 196 Mal
# S.: 189 Mal
# Hch.: 186 Mal
# Ad.: 185 Mal
# Karl: 184 Mal
# Jules: 179 Mal
# P.: 176 Mal
# Ch.: 174 Mal
# Henri: 172 Mal
# Otto: 170 Mal
# .: 169 Mal
# Alfred: 157 Mal
# Adolf: 154 Mal
# K.: 147 Mal
# Gebrüder: 145 Mal
# Frau: 141 Mal
# Wwe.: 140 Mal
# Jos.: 140 Mal
# Aug.: 139 Mal
# Jak.: 137 Mal
# Ernst: 134 Mal
# J. J.: 132 Mal
# Rud.: 129 Mal
# Hermann: 118 Mal
# Charles: 117 Mal
#  Rue Léopold Robert: 116 Mal
# Jb.: 115 Mal
# Arnold: 106 Mal
# Friedr.: 104 Mal
# Emile: 104 Mal
# Joli.: 103 Mal
# Rob.: 103 Mal
# frères: 103 Mal
# Franz: 102 Mal
# Gustav: 101 Mal
# fils: 101 Mal
# Metzger: 94 Mal
# Joseph: 93 Mal
# Dr. med.: 92 Mal
# Max: 91 Mal
# D.: 89 Mal
# Heinrich: 89 Mal
# Sohn: 87 Mal
# & Co.: 86 Mal
# Wilh.: 83 Mal
# Ang.: 81 Mal
# Herrn.: 81 Mal
# . Rue du Rhône: 80 Mal
# Chr.: 79 Mal
# Bud.: 79 Mal
# Jacques: 76 Mal
# Gotti.: 74 Mal
# Job.: 73 Mal
# Heinr.: 72 Mal
# & Cie.: 72 Mal
# Rudolf: 71 Mal
# Gottfr.: 65 Mal
# U.: 64 Mal
# Robert: 63 Mal
# François: 63 Mal
# Ferd.: 62 Mal
# August: 60 Mal
# Julius: 60 Mal
#  Rue du Parc: 60 Mal
# N.: 59 Mal
# Ernest: 59 Mal
# Wilhelm: 58 Mal
# Samuel: 57 Mal
# Jul.: 57 Mal
# Hrch.: 56 Mal
# Alfr.: 56 Mal
# Arthur: 56 Mal
# de  à  heures: 55 Mal
# Seiten : 54 Mal
# O.: 53 Mal
# Wwe: 53 Mal
# Heb.: 53 Mal
# Sam.: 51 Mal
# Eug.: 51 Mal
# Georg: 49 Mal
# J. G.: 49 Mal
# V.: 47 Mal
# Ph.: 47 Mal
# march: 47 Mal
# Victor: 46 Mal
# Auguste: 46 Mal
# Georges: 46 Mal
# Gust.: 45 Mal
# Oscar: 45 Mal
# Wirt: 44 Mal
# Willi.: 44 Mal
# IL: 44 Mal
# Léon: 44 Mal
#  Rue de la Serre: 44 Mal
# Oskar: 43 Mal
# Eduard: 43 Mal
# Eugène: 42 Mal
# Konrad: 42 Mal
# J. A.: 41 Mal
# Anton: 41 Mal
# Christian: 40 Mal
# J. H.: 39 Mal
# Theodor: 38 Mal
# Gottlieb: 38 Mal
# Gustave: 38 Mal
# Marc: 38 Mal
# Witwe: 37 Mal
# Gottfried: 37 Mal
# . Rue du Marché: 37 Mal
# J. C.: 36 Mal
# Eugen: 36 Mal
# Kaspar: 36 Mal
# Friedrich: 36 Mal
# Caspar: 36 Mal
# Edouard: 35 Mal
# Ulrich: 35 Mal
# Söhne: 34 Mal
# Conrad: 34 Mal
# Dr. jur.: 34 Mal
# Martin: 34 Mal
# Johann: 33 Mal
# J. U.: 33 Mal
# fahr: 33 Mal
# Ulr.: 33 Mal
# Eng.: 33 Mal
# . Rue du Mont-Blanc: 33 Mal
# Richard: 32 Mal
# Pierre: 32 Mal
# John: 32 Mal
# Josef: 30 Mal
# Ls.: 30 Mal
# Walter: 30 Mal
# Jobs.: 30 Mal
# Peter: 29 Mal
# Schweiz.: 29 Mal
# Maurice: 29 Mal
# J. B.: 28 Mal
# aligera.: 28 Mal
# Tierarzt: 28 Mal
# Niki.: 28 Mal
# Baumeister: 28 Mal
# Konr.: 28 Mal
#  Rue Numa Droz: 28 Mal
# T.: 27 Mal
# Daniel: 27 Mal
# Fran: 27 Mal
# Theod.: 27 Mal
# . Rue de Lausanne: 27 Mal
# Henry: 26 Mal
# Emanuel: 26 Mal
# Johs.: 26 Mal
# Architekt: 25 Mal
# Alois: 25 Mal
# David: 25 Mal
# Prof.: 25 Mal
# . Rue de Carouge: 25 Mal
# . Rue Petitot: 25 Mal
# . Rue de Bourg: 25 Mal
# Alex.: 24 Mal
# „ : 24 Mal
# Alphonse: 23 Mal
# J. F.: 23 Mal
# Anna: 23 Mal
# Dr: 23 Mal
# Adolphe: 23 Mal
# . Quai des Eaux-Vives: 23 Mal
# Mme: 22 Mal
#  ou  cent.: 22 Mal
# . Boulevard du Théâtre: 22 Mal
# Xaver: 21 Mal
#  Rue Jaquet-Droz: 21 Mal
#  Rue Fritz Courvoisier: 21 Mal
# . Rue du Commerce: 21 Mal
# . Cours de Rive: 21 Mal
# s. Tarif für das Netz Zürich: 21 Mal
# Fried.: 20 Mal
# Geschwister: 20 Mal
# H: 20 Mal
# C. A.: 20 Mal
# J. M.: 20 Mal
# Alf.: 20 Mal
# Ludwig: 20 Mal
# William: 20 Mal
# Leo: 19 Mal
# J. R.: 19 Mal
#  Rue du Progrès: 19 Mal
# . Rue du Stand: 19 Mal
# V”: 19 Mal
# Rechtsanwalt: 19 Mal
# Fri.: 18 Mal
# Basler: 18 Mal
# Kasp.: 18 Mal
#  Faubourg de l’Hôpital: 18 Mal
# M': 18 Mal
# . Rue d’Italie: 18 Mal
# . Rue Gevray: 18 Mal
# . Rue des Allemands: 18 Mal
# Bäcker: 18 Mal
# Jacq.: 18 Mal
# C. F.: 17 Mal
# F. J.: 17 Mal
# J: 17 Mal
# Solin: 17 Mal
# Félix: 17 Mal
#  Rue D. JeanRichard: 17 Mal
#  Grande Rue: 17 Mal
# de  à  heures  et de  heures et demie à  heures et demie du soir. — Novembre-mars :  de  à  heures du matin: 17 Mal
# . Corraterie: 17 Mal
# . Quai des Bergues: 17 Mal
# . Place du Molard: 17 Mal
# . Grand’Rue: 17 Mal
# J-: 16 Mal
# Moritz: 16 Mal
# Leop.: 16 Mal
# „   Consumverein: 16 Mal
# Alphons: 16 Mal
# Simon: 16 Mal
# notaire: 16 Mal
# Ls: 16 Mal
# Jacob: 16 Mal
#  Rue du Doubs: 16 Mal
# . Rue des Alpes: 16 Mal
# . Boulevard Helvétique: 16 Mal
# . Rue des Eaux-Vives: 16 Mal
# Rich.: 15 Mal
# avocat: 15 Mal
# Wasser- & Elektrizitätswerk: 15 Mal
# Lausanne: 15 Mal
#  oder  Cts. per  Minuten.: 15 Mal
# Edmond: 15 Mal
#  Rue de la Paix: 15 Mal
# . Rue Centrale: 15 Mal
# Höh.: 15 Mal
# resp. — Uhr vorm.: 15 Mal
# s. Tarif für das Netz Frauenfeld: 15 Mal
# Conr.: 15 Mal
# X.: 14 Mal
# Basel: 14 Mal
# Prof. Dr.: 14 Mal
# & Sohn: 14 Mal
# Clis.: 14 Mal
# Ant.: 14 Mal
#  Rue du Collège: 14 Mal
# Julien: 14 Mal
# Adrien: 14 Mal
# M'': 14 Mal
# . Boulevard James-Fazy: 14 Mal
# Fuhrhalter: 14 Mal
# —: 13 Mal
# Arn.: 13 Mal
# Camille: 13 Mal
# dir.: 13 Mal
# Ohr.: 13 Mal
# Ami: 13 Mal
#  Rue de la Promenade: 13 Mal
#  Rue D. Jean Richard: 13 Mal
# Frédéric: 13 Mal
#  Evole: 13 Mal
#  Rue Francillon: 13 Mal
# . Rue Lévrier: 13 Mal
# . Boulevard de Plainpalais: 13 Mal
# . Quai du Mont-Blanc: 13 Mal
# Ferdinand: 13 Mal
#  u.  Mit württemb. Netzen: 13 Mal
# Zahnarzt: 12 Mal
# Vater: 12 Mal
# Bernhard: 12 Mal
# Müller: 12 Mal
# Philipp: 12 Mal
# A.-G.: 12 Mal
# Milch-: 12 Mal
# Erben: 12 Mal
# Frau A.: 12 Mal
# Gehr.: 12 Mal
# siehe Tarif  für das Netz Bern: 12 Mal
# Christ.: 12 Mal
# Armand: 12 Mal
# Notar: 12 Mal
#  Rue Neuve: 12 Mal
#  Rue de l’Hôpital: 12 Mal
# .  Rue du Rhône: 12 Mal
# . Rue de Candolle: 12 Mal
# . Cours des Bastions: 12 Mal
# . Rue Général-Dufour: 12 Mal
# »: 12 Mal
# Bern: 11 Mal
# Viktor: 11 Mal
# Hugo: 11 Mal
# Frid.: 11 Mal
# Seb.: 11 Mal
# Frau L.: 11 Mal
# Chs.: 11 Mal
# Heli.: 11 Mal
# Louise: 11 Mal
# A: 11 Mal
# Alexander: 11 Mal
# Oberst: 11 Mal
# Sigm.: 11 Mal
# Alexandre: 11 Mal
#  Rue du Pont: 11 Mal
# Antoine: 11 Mal
# Lucien: 11 Mal
#  Rue Daniel JeanRichard: 11 Mal
# Armin: 11 Mal
#  Rue des Beaux-Arts: 11 Mal
# docteur: 11 Mal
# de  à  heures et de   à  heures et demie du soir. — Novembre-mars : de  heures à midi: 11 Mal
# . Rue de l’Entrepôt: 11 Mal
# . Rue de Hollande: 11 Mal
# . Rue des Chaudronniers: 11 Mal
# . Rue de la Croix-d’Or: 11 Mal
# . Rue Bonivard: 11 Mal
# G. A.: 11 Mal
# Frauenfeld: 11 Mal
# Jae.: 11 Mal
# Johannes: 11 Mal
# Charmoille: 10 Mal
# Mercerie: 10 Mal
# Ingenieur: 10 Mal
# Dr. H.: 10 Mal
# Urs: 10 Mal
# H. J.: 10 Mal
# Dr. E.: 10 Mal
# Alph.: 10 Mal
# Baugeschäft: 10 Mal
# Casimir: 10 Mal
# Achille: 10 Mal
# Léopold: 10 Mal
# A. G.: 10 Mal
# Fridolin: 10 Mal
#  Rue du Marché: 10 Mal
#  Place Neuve: 10 Mal
#  Rue du Grenier: 10 Mal
# Rodolphe: 10 Mal
# Jämes: 10 Mal
# César: 10 Mal
# Constant: 10 Mal
# de: 10 Mal
# J.-A.: 10 Mal
# Jaques: 10 Mal
#  Rue des Envers: 10 Mal
# Philippe: 10 Mal
# André: 10 Mal
# Alexis: 10 Mal
# J.-L.: 10 Mal
# de  à  heures et de  à   heures et demie du soir. — Novembre-mars : de  heures à midi: 10 Mal
# . Quai Pierre-Fatio: 10 Mal
# . Rue de l’Hôtel-de-Ville: 10 Mal
# . Route de Florissant: 10 Mal
# . Coulouvrenière: 10 Mal
# . Rue du Cendrier: 10 Mal
# . Corratene: 10 Mal
# . Rue Pierre-Fatio: 10 Mal
# V': 10 Mal
# Em.: 10 Mal
# . Rue du Simplon: 10 Mal
# s. Tarif f. d. Netz Zürich: 10 Mal
# Bäckerei: 10 Mal
# Neckar: 9 Mal
# Justin: 9 Mal
# S. J.: 9 Mal
# Advokat: 9 Mal
# &Co.: 9 Mal
# Melchior: 9 Mal
# Basler Droschkenanstalt: 9 Mal
# Fernand: 9 Mal
# René: 9 Mal
# Theophil: 9 Mal
# Felix: 9 Mal
# Etienne: 9 Mal
# J.-J.: 9 Mal
# Isaac: 9 Mal
# jun.: 9 Mal

# %%
# Dieser Code erstellt ein neues, leeres Wörterbuch.
grouped_result = {}

# Dieser Code zählt einzelnen Wortketten am Anfang jeder Zeile durch. Wenn die ersten vier Zeichen
# dieselben sind wie bereits im Wörterbuch vorhanden, wird es der Gruppe hinzugefügt. Wenn es noch
# keine Gruppe mit diesen vier Zeichen am Anfang gibt, wird eine neue Gruppe erstellt.
# Vier Zeichen hat sich durch ein paar Tests als ideale Länge herausgestellt, da so Metzgerei und
# Metzgerbeispielsweise in der selben Gruppe landen.

for string, count in sorted_result:
    key = string[:4]
    if key in grouped_result:
        grouped_result[key].append((string, count))
    else:
        grouped_result[key] = [(string, count)]

# Es wird nochmals ein neues, leeres Wörterbuch erstellt.
group_total_counts = {}

# Nun werden alle einzelnen Einträge in den Gruppend durchgezählt.
for key, values in grouped_result.items():
    total_count = sum(count for _, count in values)
    group_total_counts[key] = total_count

# Und als Gruppe mit Anzahl einträgen dargestellt.
for key, values in grouped_result.items():
    print(f"Gruppe: {key} ({group_total_counts[key]} Einträge total)")
    #for string, count in values:
    #    print(f"{string}: {count} Mal") Dieser Code würde die einzelnen EInträge in den Gruppen
    # anzeigen. Dies ist aber mehr verwirrend als hilfreich.
    print()
# Out:
# Gruppe: J. (2039 Einträge total)
#
# Gruppe: A. (1451 Einträge total)
#
# Gruppe: E. (934 Einträge total)
#
# Gruppe: H. (800 Einträge total)
#
# Gruppe: G. (754 Einträge total)
#
# Gruppe: F. (675 Einträge total)
#
# Gruppe: C. (459 Einträge total)
#
# Gruppe: Emil (688 Einträge total)
#
# Gruppe: R. (355 Einträge total)
#
# Gruppe: Dr. (350 Einträge total)
#
# Gruppe: Frit (429 Einträge total)
#
# Gruppe: Ed. (310 Einträge total)
#
# Gruppe: W. (306 Einträge total)
#
# Gruppe: L. (289 Einträge total)
#
# Gruppe: M. (284 Einträge total)
#
# Gruppe: Fr. (271 Einträge total)
#
# Gruppe: Gebr (582 Einträge total)
#
# Gruppe: Loui (367 Einträge total)
#
# Gruppe: Joh. (297 Einträge total)
#
# Gruppe: Th. (242 Einträge total)
#
# Gruppe: Alb. (284 Einträge total)
#
# Gruppe: Albe (309 Einträge total)
#
# Gruppe: Carl (350 Einträge total)
#
# Gruppe: Jean (273 Einträge total)
#
# Gruppe: Hans (302 Einträge total)
#
# Gruppe: Paul (279 Einträge total)
#
# Gruppe: Jako (241 Einträge total)
#
# Gruppe: B. (196 Einträge total)
#
# Gruppe: S. (189 Einträge total)
#
# Gruppe: Hch. (191 Einträge total)
#
# Gruppe: Ad. (185 Einträge total)
#
# Gruppe: Karl (239 Einträge total)
#
# Gruppe: Jule (232 Einträge total)
#
# Gruppe: P. (176 Einträge total)
#
# Gruppe: Ch. (174 Einträge total)
#
# Gruppe: Henr (286 Einträge total)
#
# Gruppe: Otto (228 Einträge total)
#
# Gruppe: . (169 Einträge total)
#
# Gruppe: Alfr (292 Einträge total)
#
# Gruppe: Adol (248 Einträge total)
#
# Gruppe: K. (147 Einträge total)
#
# Gruppe: Frau (682 Einträge total)
#
# Gruppe: Wwe. (258 Einträge total)
#
# Gruppe: Jos. (176 Einträge total)
#
# Gruppe: Aug. (179 Einträge total)
#
# Gruppe: Jak. (155 Einträge total)
#
# Gruppe: Erns (186 Einträge total)
#
# Gruppe: J. J (194 Einträge total)
#
# Gruppe: Rud. (169 Einträge total)
#
# Gruppe: Herm (166 Einträge total)
#
# Gruppe: Char (235 Einträge total)
#
# Gruppe:  Rue (841 Einträge total)
#
# Gruppe: Jb. (115 Einträge total)
#
# Gruppe: Arno (127 Einträge total)
#
# Gruppe: Frie (233 Einträge total)
#
# Gruppe: Joli (143 Einträge total)
#
# Gruppe: Rob. (123 Einträge total)
#
# Gruppe: frèr (134 Einträge total)
#
# Gruppe: Fran (370 Einträge total)
#
# Gruppe: Gust (243 Einträge total)
#
# Gruppe: fils (132 Einträge total)
#
# Gruppe: Metz (1139 Einträge total)
#
# Gruppe: Jose (165 Einträge total)
#
# Gruppe: Dr.  (1429 Einträge total)
#
# Gruppe: Max (91 Einträge total)
#
# Gruppe: D. (89 Einträge total)
#
# Gruppe: Hein (234 Einträge total)
#
# Gruppe: Sohn (130 Einträge total)
#
# Gruppe: & Co (183 Einträge total)
#
# Gruppe: Wilh (191 Einträge total)
#
# Gruppe: Ang. (95 Einträge total)
#
# Gruppe: Herr (153 Einträge total)
#
# Gruppe: . Ru (1239 Einträge total)
#
# Gruppe: Chr. (98 Einträge total)
#
# Gruppe: Bud. (98 Einträge total)
#
# Gruppe: Jacq (124 Einträge total)
#
# Gruppe: Gott (293 Einträge total)
#
# Gruppe: Job. (91 Einträge total)
#
# Gruppe: & Ci (88 Einträge total)
#
# Gruppe: Rudo (134 Einträge total)
#
# Gruppe: U. (64 Einträge total)
#
# Gruppe: Robe (98 Einträge total)
#
# Gruppe: Ferd (114 Einträge total)
#
# Gruppe: Augu (144 Einträge total)
#
# Gruppe: Juli (117 Einträge total)
#
# Gruppe: N. (59 Einträge total)
#
# Gruppe: Erne (85 Einträge total)
#
# Gruppe: Samu (82 Einträge total)
#
# Gruppe: Jul. (67 Einträge total)
#
# Gruppe: Hrch (70 Einträge total)
#
# Gruppe: Arth (78 Einträge total)
#
# Gruppe: de   (444 Einträge total)
#
# Gruppe: Seit (136 Einträge total)
#
# Gruppe: O. (53 Einträge total)
#
# Gruppe: Wwe (53 Einträge total)
#
# Gruppe: Heb. (55 Einträge total)
#
# Gruppe: Sam. (61 Einträge total)
#
# Gruppe: Eug. (59 Einträge total)
#
# Gruppe: Geor (140 Einträge total)
#
# Gruppe: J. G (73 Einträge total)
#
# Gruppe: V. (47 Einträge total)
#
# Gruppe: Ph. (47 Einträge total)
#
# Gruppe: marc (213 Einträge total)
#
# Gruppe: Vict (63 Einträge total)
#
# Gruppe: Osca (62 Einträge total)
#
# Gruppe: Wirt (889 Einträge total)
#
# Gruppe: Will (97 Einträge total)
#
# Gruppe: IL (44 Einträge total)
#
# Gruppe: Léon (65 Einträge total)
#
# Gruppe: Oska (51 Einträge total)
#
# Gruppe: Edua (72 Einträge total)
#
# Gruppe: Eugè (63 Einträge total)
#
# Gruppe: Konr (86 Einträge total)
#
# Gruppe: J. A (57 Einträge total)
#
# Gruppe: Anto (76 Einträge total)
#
# Gruppe: Chri (73 Einträge total)
#
# Gruppe: J. H (61 Einträge total)
#
# Gruppe: Theo (106 Einträge total)
#
# Gruppe: Marc (94 Einträge total)
#
# Gruppe: Witw (65 Einträge total)
#
# Gruppe: J. C (44 Einträge total)
#
# Gruppe: Euge (53 Einträge total)
#
# Gruppe: Kasp (56 Einträge total)
#
# Gruppe: Casp (40 Einträge total)
#
# Gruppe: Edou (69 Einträge total)
#
# Gruppe: Ulri (54 Einträge total)
#
# Gruppe: Söhn (57 Einträge total)
#
# Gruppe: Conr (72 Einträge total)
#
# Gruppe: Mart (65 Einträge total)
#
# Gruppe: Joha (56 Einträge total)
#
# Gruppe: J. U (39 Einträge total)
#
# Gruppe: fahr (36 Einträge total)
#
# Gruppe: Ulr. (39 Einträge total)
#
# Gruppe: Eng. (35 Einträge total)
#
# Gruppe: Rich (68 Einträge total)
#
# Gruppe: Pier (40 Einträge total)
#
# Gruppe: John (49 Einträge total)
#
# Gruppe: Ls. (30 Einträge total)
#
# Gruppe: Walt (47 Einträge total)
#
# Gruppe: Jobs (34 Einträge total)
#
# Gruppe: Pete (41 Einträge total)
#
# Gruppe: Schw (217 Einträge total)
#
# Gruppe: Maur (80 Einträge total)
#
# Gruppe: J. B (46 Einträge total)
#
# Gruppe: alig (28 Einträge total)
#
# Gruppe: Tier (209 Einträge total)
#
# Gruppe: Niki (37 Einträge total)
#
# Gruppe: Baum (523 Einträge total)
#
# Gruppe: T. (27 Einträge total)
#
# Gruppe: Dani (36 Einträge total)
#
# Gruppe: Eman (50 Einträge total)
#
# Gruppe: Johs (29 Einträge total)
#
# Gruppe: Arch (301 Einträge total)
#
# Gruppe: Aloi (30 Einträge total)
#
# Gruppe: Davi (37 Einträge total)
#
# Gruppe: Prof (204 Einträge total)
#
# Gruppe: Alex (88 Einträge total)
#
# Gruppe: „  (24 Einträge total)
#
# Gruppe: Alph (58 Einträge total)
#
# Gruppe: J. F (48 Einträge total)
#
# Gruppe: Anna (25 Einträge total)
#
# Gruppe: Dr (23 Einträge total)
#
# Gruppe: . Qu (107 Einträge total)
#
# Gruppe: Mme (22 Einträge total)
#
# Gruppe:  ou  (52 Einträge total)
#
# Gruppe: . Bo (159 Einträge total)
#
# Gruppe: Xave (25 Einträge total)
#
# Gruppe: . Co (105 Einträge total)
#
# Gruppe: s. T (58 Einträge total)
#
# Gruppe: Gesc (92 Einträge total)
#
# Gruppe: H (20 Einträge total)
#
# Gruppe: C. A (34 Einträge total)
#
# Gruppe: J. M (29 Einträge total)
#
# Gruppe: Alf. (26 Einträge total)
#
# Gruppe: Ludw (35 Einträge total)
#
# Gruppe: Leo (19 Einträge total)
#
# Gruppe: J. R (43 Einträge total)
#
# Gruppe: V” (19 Einträge total)
#
# Gruppe: Rech (157 Einträge total)
#
# Gruppe: Fri. (103 Einträge total)
#
# Gruppe: Basl (64 Einträge total)
#
# Gruppe:  Fau (36 Einträge total)
#
# Gruppe: M' (18 Einträge total)
#
# Gruppe: Bäck (540 Einträge total)
#
# Gruppe: C. F (21 Einträge total)
#
# Gruppe: F. J (21 Einträge total)
#
# Gruppe: J (17 Einträge total)
#
# Gruppe: Soli (27 Einträge total)
#
# Gruppe: Féli (26 Einträge total)
#
# Gruppe:  Gra (28 Einträge total)
#
# Gruppe: . Pl (188 Einträge total)
#
# Gruppe: . Gr (80 Einträge total)
#
# Gruppe: J- (16 Einträge total)
#
# Gruppe: Mori (29 Einträge total)
#
# Gruppe: Leop (33 Einträge total)
#
# Gruppe: „    (17 Einträge total)
#
# Gruppe: Simo (21 Einträge total)
#
# Gruppe: nota (134 Einträge total)
#
# Gruppe: Ls (16 Einträge total)
#
# Gruppe: Jaco (18 Einträge total)
#
# Gruppe: avoc (161 Einträge total)
#
# Gruppe: Wass (39 Einträge total)
#
# Gruppe: Laus (22 Einträge total)
#
# Gruppe:  ode (157 Einträge total)
#
# Gruppe: Edmo (29 Einträge total)
#
# Gruppe: Höh. (15 Einträge total)
#
# Gruppe: resp (108 Einträge total)
#
# Gruppe: X. (14 Einträge total)
#
# Gruppe: Base (34 Einträge total)
#
# Gruppe: & So (20 Einträge total)
#
# Gruppe: Clis (15 Einträge total)
#
# Gruppe: Ant. (16 Einträge total)
#
# Gruppe: Adri (23 Einträge total)
#
# Gruppe: M'' (14 Einträge total)
#
# Gruppe: Fuhr (297 Einträge total)
#
# Gruppe: — (13 Einträge total)
#
# Gruppe: Arn. (13 Einträge total)
#
# Gruppe: Cami (42 Einträge total)
#
# Gruppe: dir. (21 Einträge total)
#
# Gruppe: Ohr. (15 Einträge total)
#
# Gruppe: Ami (13 Einträge total)
#
# Gruppe: Fréd (28 Einträge total)
#
# Gruppe:  Evo (17 Einträge total)
#
# Gruppe:  u.  (50 Einträge total)
#
# Gruppe: Zahn (155 Einträge total)
#
# Gruppe: Vate (18 Einträge total)
#
# Gruppe: Bern (62 Einträge total)
#
# Gruppe: Müll (113 Einträge total)
#
# Gruppe: Phil (37 Einträge total)
#
# Gruppe: A.-G (69 Einträge total)
#
# Gruppe: Milc (39 Einträge total)
#
# Gruppe: Erbe (18 Einträge total)
#
# Gruppe: Gehr (19 Einträge total)
#
# Gruppe: sieh (180 Einträge total)
#
# Gruppe: Arma (17 Einträge total)
#
# Gruppe: Nota (169 Einträge total)
#
# Gruppe: .  R (238 Einträge total)
#
# Gruppe: » (12 Einträge total)
#
# Gruppe: Vikt (16 Einträge total)
#
# Gruppe: Hugo (21 Einträge total)
#
# Gruppe: Frid (25 Einträge total)
#
# Gruppe: Seb. (16 Einträge total)
#
# Gruppe: Chs. (12 Einträge total)
#
# Gruppe: Heli (11 Einträge total)
#
# Gruppe: A (11 Einträge total)
#
# Gruppe: Ober (164 Einträge total)
#
# Gruppe: Sigm (22 Einträge total)
#
# Gruppe: Luci (17 Einträge total)
#
# Gruppe: Armi (11 Einträge total)
#
# Gruppe: doct (275 Einträge total)
#
# Gruppe: G. A (23 Einträge total)
#
# Gruppe: Jae. (11 Einträge total)
#
# Gruppe: Merc (53 Einträge total)
#
# Gruppe: Inge (157 Einträge total)
#
# Gruppe: Urs (10 Einträge total)
#
# Gruppe: H. J (10 Einträge total)
#
# Gruppe: Baug (204 Einträge total)
#
# Gruppe: Casi (14 Einträge total)
#
# Gruppe: Achi (20 Einträge total)
#
# Gruppe: Léop (13 Einträge total)
#
# Gruppe: A. G (24 Einträge total)
#
# Gruppe:  Pla (45 Einträge total)
#
# Gruppe: Rodo (11 Einträge total)
#
# Gruppe: Jäme (12 Einträge total)
#
# Gruppe: Césa (12 Einträge total)
#
# Gruppe: Cons (36 Einträge total)
#
# Gruppe: de (10 Einträge total)
#
# Gruppe: J.-A (15 Einträge total)
#
# Gruppe: Jaqu (15 Einträge total)
#
# Gruppe: Andr (30 Einträge total)
#
# Gruppe: J.-L (14 Einträge total)
#
# Gruppe: . Ro (74 Einträge total)
#
# Gruppe: V' (10 Einträge total)
#
# Gruppe: Em. (10 Einträge total)
#
# Gruppe: Neck (19 Einträge total)
#
# Gruppe: Just (19 Einträge total)
#
# Gruppe: S. J (9 Einträge total)
#
# Gruppe: Advo (122 Einträge total)
#
# Gruppe: &Co. (16 Einträge total)
#
# Gruppe: Melc (13 Einträge total)
#
# Gruppe: Fern (10 Einträge total)
#
# Gruppe: René (11 Einträge total)
#
# Gruppe: Feli (21 Einträge total)
#
# Gruppe: Etie (10 Einträge total)
#
# Gruppe: J.-J (11 Einträge total)
#
# Gruppe: Isaa (18 Einträge total)
#
# Gruppe: jun. (9 Einträge total)
#
# Gruppe: II. (9 Einträge total)
#
# Gruppe: J.-H (12 Einträge total)
#
# Gruppe: père (16 Einträge total)
#
# Gruppe: Mari (34 Einträge total)
#
# Gruppe: Uste (17 Einträge total)
#
# Gruppe: Rupp (13 Einträge total)
#
# Gruppe: P. A (9 Einträge total)
#
# Gruppe: Bier (219 Einträge total)
#
# Gruppe: allg (41 Einträge total)
#
# Gruppe: W. H (8 Einträge total)
#
# Gruppe: juni (10 Einträge total)
#
# Gruppe: Math (32 Einträge total)
#
# Gruppe: St. (8 Einträge total)
#
# Gruppe: J. K (9 Einträge total)
#
# Gruppe: Nikl (11 Einträge total)
#
# Gruppe: Hud. (8 Einträge total)
#
# Gruppe: G (8 Einträge total)
#
# Gruppe: Bonn (28 Einträge total)
#
# Gruppe: Cäsa (9 Einträge total)
#
# Gruppe: mont (45 Einträge total)
#
# Gruppe: Fami (15 Einträge total)
#
# Gruppe: repr (71 Einträge total)
#
# Gruppe: avri (19 Einträge total)
#
# Gruppe: voir (46 Einträge total)
#
# Gruppe: .  B (87 Einträge total)
#
# Gruppe: . Te (19 Einträge total)
#
# Gruppe: ingé (87 Einträge total)
#
# Gruppe: M““ (8 Einträge total)
#
# Gruppe: M”' (8 Einträge total)
#
# Gruppe: . Sq (14 Einträge total)
#
# Gruppe: F. X (8 Einträge total)
#
# Gruppe: Wein (487 Einträge total)
#
# Gruppe: Hs. (8 Einträge total)
#
# Gruppe: Cond (94 Einträge total)
#
# Gruppe: R (7 Einträge total)
#
# Gruppe: Bonc (7 Einträge total)
#
# Gruppe: Chev (13 Einträge total)
#
# Gruppe: Luze (16 Einträge total)
#
# Gruppe: Oswa (7 Einträge total)
#
# Gruppe: J. L (18 Einträge total)
#
# Gruppe: Frz. (14 Einträge total)
#
# Gruppe: Buch (488 Einträge total)
#
# Gruppe: Leon (32 Einträge total)
#
# Gruppe: Rein (37 Einträge total)
#
# Gruppe: Pius (8 Einträge total)
#
# Gruppe: G. H (11 Einträge total)
#
# Gruppe: Améd (9 Einträge total)
#
# Gruppe: Gasp (13 Einträge total)
#
# Gruppe: Vve (7 Einträge total)
#
# Gruppe: St.  (49 Einträge total)
#
# Gruppe: Sped (52 Einträge total)
#
# Gruppe: West (15 Einträge total)
#
# Gruppe: J. P (8 Einträge total)
#
# Gruppe: Rod. (9 Einträge total)
#
# Gruppe: F. A (10 Einträge total)
#
# Gruppe: Alci (7 Einträge total)
#
# Gruppe: G. L (10 Einträge total)
#
# Gruppe: Bend (9 Einträge total)
#
# Gruppe: L (7 Einträge total)
#
# Gruppe: Geme (1077 Einträge total)
#
# Gruppe: Fs (7 Einträge total)
#
# Gruppe: épic (96 Einträge total)
#
# Gruppe: . Ch (218 Einträge total)
#
# Gruppe: M'“ (7 Einträge total)
#
# Gruppe: . Mo (36 Einträge total)
#
# Gruppe: . Av (83 Einträge total)
#
# Gruppe: Iwan (7 Einträge total)
#
# Gruppe: Hand (328 Einträge total)
#
# Gruppe: Reda (73 Einträge total)
#
# Gruppe: städ (86 Einträge total)
#
# Gruppe: Wint (22 Einträge total)
#
# Gruppe: Bade (154 Einträge total)
#
# Gruppe: J. W (13 Einträge total)
#
# Gruppe: Mech (88 Einträge total)
#
# Gruppe: Aloy (8 Einträge total)
#
# Gruppe: Step (7 Einträge total)
#
# Gruppe: Fina (9 Einträge total)
#
# Gruppe: G. & (16 Einträge total)
#
# Gruppe: K. J (6 Einträge total)
#
# Gruppe: H. A (7 Einträge total)
#
# Gruppe: Veuv (12 Einträge total)
#
# Gruppe: J. E (18 Einträge total)
#
# Gruppe: Biel (19 Einträge total)
#
# Gruppe: José (6 Einträge total)
#
# Gruppe: Ida (6 Einträge total)
#
# Gruppe: Graf (9 Einträge total)
#
# Gruppe: Kolo (174 Einträge total)
#
# Gruppe: Z. (6 Einträge total)
#
# Gruppe: Marx (6 Einträge total)
#
# Gruppe: J.-B (6 Einträge total)
#
# Gruppe: Negt (74 Einträge total)
#
# Gruppe: Aloï (9 Einträge total)
#
# Gruppe: J.-F (7 Einträge total)
#
# Gruppe: K (6 Einträge total)
#
# Gruppe: Genè (17 Einträge total)
#
# Gruppe:  Che (20 Einträge total)
#
# Gruppe: Nath (6 Einträge total)
#
# Gruppe:  Ecl (7 Einträge total)
#
# Gruppe: et d (74 Einträge total)
#
# Gruppe: .  C (81 Einträge total)
#
# Gruppe: M“' (6 Einträge total)
#
# Gruppe: .  T (10 Einträge total)
#
# Gruppe: Théo (10 Einträge total)
#
# Gruppe: Gabr (15 Einträge total)
#
# Gruppe: prof (64 Einträge total)
#
# Gruppe: F. W (9 Einträge total)
#
# Gruppe: Brod (133 Einträge total)
#
# Gruppe: H. E (6 Einträge total)
#
# Gruppe: Huld (6 Einträge total)
#
# Gruppe: Conn (6 Einträge total)
#
# Gruppe: Emma (13 Einträge total)
#
# Gruppe: E. F (10 Einträge total)
#
# Gruppe: Dd. (6 Einträge total)
#
# Gruppe: Ciga (156 Einträge total)
#
# Gruppe: Auge (24 Einträge total)
#
# Gruppe: Deli (26 Einträge total)
#
# Gruppe: Ing. (6 Einträge total)
#
# Gruppe: Zürc (29 Einträge total)
#
# Gruppe: h. (6 Einträge total)
#
# Gruppe: G-. (6 Einträge total)
#
# Gruppe: B (5 Einträge total)
#
# Gruppe: Solo (16 Einträge total)
#
# Gruppe: Gren (11 Einträge total)
#
# Gruppe: Hinw (6 Einträge total)
#
# Gruppe: Pfun (5 Einträge total)
#
# Gruppe: Turb (6 Einträge total)
#
# Gruppe: Wäde (8 Einträge total)
#
# Gruppe: Wetz (8 Einträge total)
#
# Gruppe: Lang (27 Einträge total)
#
# Gruppe: A. & (27 Einträge total)
#
# Gruppe: Trau (9 Einträge total)
#
# Gruppe: Gehn (5 Einträge total)
#
# Gruppe: With (7 Einträge total)
#
# Gruppe: Arx (5 Einträge total)
#
# Gruppe: Cd. (5 Einträge total)
#
# Gruppe: SI. (5 Einträge total)
#
# Gruppe: Othm (7 Einträge total)
#
# Gruppe: et f (5 Einträge total)
#
# Gruppe: E. J (7 Einträge total)
#
# Gruppe: Bert (20 Einträge total)
#
# Gruppe: Kant (61 Einträge total)
#
# Gruppe: ü. (5 Einträge total)
#
# Gruppe: Arzt (94 Einträge total)
#
# Gruppe: la (5 Einträge total)
#
# Gruppe: Ed (5 Einträge total)
#
# Gruppe: Inte (14 Einträge total)
#
# Gruppe: jeun (5 Einträge total)
#
# Gruppe: Bene (10 Einträge total)
#
# Gruppe: Edin (5 Einträge total)
#
# Gruppe: eidg (116 Einträge total)
#
# Gruppe: Ghr. (9 Einträge total)
#
# Gruppe: horl (87 Einträge total)
#
# Gruppe: .  (5 Einträge total)
#
# Gruppe: Hect (6 Einträge total)
#
# Gruppe: Deze (8 Einträge total)
#
# Gruppe: Taxe (25 Einträge total)
#
# Gruppe: Mai  (12 Einträge total)
#
# Gruppe: Gast (366 Einträge total)
#
# Gruppe: Getr (104 Einträge total)
#
# Gruppe: — un (503 Einträge total)
#
# Gruppe: Pape (60 Einträge total)
#
# Gruppe: J.-E (6 Einträge total)
#
# Gruppe: Mich (19 Einträge total)
#
# Gruppe: F.-A (8 Einträge total)
#
# Gruppe: D' (5 Einträge total)
#
# Gruppe: Nico (8 Einträge total)
#
# Gruppe:   Ru (78 Einträge total)
#
# Gruppe: ciga (10 Einträge total)
#
# Gruppe: Léo (5 Einträge total)
#
# Gruppe: arch (125 Einträge total)
#
# Gruppe: M“e (5 Einträge total)
#
# Gruppe: M” (5 Einträge total)
#
# Gruppe: Et. (5 Einträge total)
#
# Gruppe: .  Q (18 Einträge total)
#
# Gruppe: Pari (10 Einträge total)
#
# Gruppe: rout (43 Einträge total)
#
# Gruppe: chau (18 Einträge total)
#
# Gruppe: M”“ (5 Einträge total)
#
# Gruppe: Vale (11 Einträge total)
#
# Gruppe: entr (256 Einträge total)
#
# Gruppe: . Pr (24 Einträge total)
#
# Gruppe: Vinc (6 Einträge total)
#
# Gruppe: Nyon (96 Einträge total)
#
# Gruppe: Alfo (6 Einträge total)
#
# Gruppe: Vete (9 Einträge total)
#
# Gruppe: C. W (11 Einträge total)
#
# Gruppe: M. A (5 Einträge total)
#
# Gruppe: Fabr (187 Einträge total)
#
# Gruppe: Edw. (7 Einträge total)
#
# Gruppe: Edwi (8 Einträge total)
#
# Gruppe: „ (5 Einträge total)
#
# Gruppe: Rapp (14 Einträge total)
#
# Gruppe: K. H (7 Einträge total)
#
# Gruppe: Expo (25 Einträge total)
#
# Gruppe: Nied (18 Einträge total)
#
# Gruppe: Unte (56 Einträge total)
#
# Gruppe: Neue (25 Einträge total)
#
# Gruppe: Thal (17 Einträge total)
#
# Gruppe: Lich (9 Einträge total)
#
# Gruppe: Chur (9 Einträge total)
#
# Gruppe: Brug (14 Einträge total)
#
# Gruppe: Dona (5 Einträge total)
#
# Gruppe: Enz (4 Einträge total)
#
# Gruppe: H. & (28 Einträge total)
#
# Gruppe: F. & (17 Einträge total)
#
# Gruppe: Kell (13 Einträge total)
#
# Gruppe: E. & (17 Einträge total)
#
# Gruppe: W. L (4 Einträge total)
#
# Gruppe: J. & (24 Einträge total)
#
# Gruppe: Luka (4 Einträge total)
#
# Gruppe: Albr (12 Einträge total)
#
# Gruppe: Heus (8 Einträge total)
#
# Gruppe: Dros (59 Einträge total)
#
# Gruppe: J.F. (4 Einträge total)
#
# Gruppe: Niel (5 Einträge total)
#
# Gruppe: J    (67 Einträge total)
#
# Gruppe:   Mü (4 Einträge total)
#
# Gruppe: Bure (255 Einträge total)
#
# Gruppe: sei. (5 Einträge total)
#
# Gruppe: Ad.  (37 Einträge total)
#
# Gruppe: Fçoi (4 Einträge total)
#
# Gruppe: Erwi (4 Einträge total)
#
# Gruppe: Yve. (4 Einträge total)
#
# Gruppe: fabr (475 Einträge total)
#
# Gruppe: Benj (12 Einträge total)
#
# Gruppe: Albi (10 Einträge total)
#
# Gruppe: EL (4 Einträge total)
#
# Gruppe: Jkb. (4 Einträge total)
#
# Gruppe: Frei (16 Einträge total)
#
# Gruppe: AL (4 Einträge total)
#
# Gruppe: F (4 Einträge total)
#
# Gruppe: E. W (10 Einträge total)
#
# Gruppe: Fahr (13 Einträge total)
#
# Gruppe: L. A (4 Einträge total)
#
# Gruppe: G. R (6 Einträge total)
#
# Gruppe: Abra (8 Einträge total)
#
# Gruppe: Abr. (4 Einträge total)
#
# Gruppe: E. A (6 Einträge total)
#
# Gruppe: Mai (4 Einträge total)
#
# Gruppe: Herz (9 Einträge total)
#
# Gruppe: Soph (4 Einträge total)
#
# Gruppe: Holz (205 Einträge total)
#
# Gruppe: Schl (217 Einträge total)
#
# Gruppe: Fräu (24 Einträge total)
#
# Gruppe: Bob. (5 Einträge total)
#
# Gruppe: Chau (9 Einträge total)
#
# Gruppe: Clar (4 Einträge total)
#
# Gruppe:  Mey (5 Einträge total)
#
# Gruppe: Eise (277 Einträge total)
#
# Gruppe: A. D (6 Einträge total)
#
# Gruppe: Thom (8 Einträge total)
#
# Gruppe: H.-A (4 Einträge total)
#
# Gruppe: Clém (5 Einträge total)
#
# Gruppe:   (4 Einträge total)
#
# Gruppe: H.-F (4 Einträge total)
#
# Gruppe: Ulys (7 Einträge total)
#
# Gruppe: boul (128 Einträge total)
#
# Gruppe: L.-A (6 Einträge total)
#
# Gruppe:  Bel (6 Einträge total)
#
# Gruppe: L.-F (4 Einträge total)
#
# Gruppe: veuv (11 Einträge total)
#
# Gruppe: L’ (4 Einträge total)
#
# Gruppe: Aimé (5 Einträge total)
#
# Gruppe: aîné (6 Einträge total)
#
# Gruppe: L. e (7 Einträge total)
#
# Gruppe: Jame (6 Einträge total)
#
# Gruppe: lite (5 Einträge total)
#
# Gruppe: Fred (9 Einträge total)
#
# Gruppe: M“ (4 Einträge total)
#
# Gruppe: J.-M (5 Einträge total)
#
# Gruppe: .  P (66 Einträge total)
#
# Gruppe: Marg (11 Einträge total)
#
# Gruppe: Dupa (4 Einträge total)
#
# Gruppe: Beno (5 Einträge total)
#
# Gruppe: . Es (13 Einträge total)
#
# Gruppe: Elis (12 Einträge total)
#
# Gruppe: dire (58 Einträge total)
#
# Gruppe: F. H (6 Einträge total)
#
# Gruppe: Josu (7 Einträge total)
#
# Gruppe: Val. (4 Einträge total)
#
# Gruppe: v. (4 Einträge total)
#
# Gruppe: Raga (6 Einträge total)
#
# Gruppe: Fr.  (47 Einträge total)
#
# Gruppe: Gebh (7 Einträge total)
#
# Gruppe: Uhr  (23 Einträge total)
#
# Gruppe: Oech (5 Einträge total)
#
# Gruppe: Dom. (4 Einträge total)
#
# Gruppe: Mine (79 Einträge total)
#
# Gruppe: a. O (6 Einträge total)
#
# Gruppe: J. O (5 Einträge total)
#
# Gruppe: Glar (13 Einträge total)
#
# Gruppe: Rüti (13 Einträge total)
#
# Gruppe: Nik. (4 Einträge total)
#
# Gruppe: Br. (4 Einträge total)
#
# Gruppe: Nage (4 Einträge total)
#
# Gruppe: Gärt (62 Einträge total)
#
# Gruppe: Stad (67 Einträge total)
#
# Gruppe: Comp (27 Einträge total)
#
# Gruppe: Seid (277 Einträge total)
#
# Gruppe: mech (256 Einträge total)
#
# Gruppe: Büla (5 Einträge total)
#
# Gruppe: Scha (36 Einträge total)
#
# Gruppe: w. (4 Einträge total)
#
# Gruppe: Ib. (4 Einträge total)
#
# Gruppe: Phot (101 Einträge total)
#
# Gruppe: Wohn (519 Einträge total)
#
# Gruppe: C. M (4 Einträge total)
#
# Gruppe: Odoa (8 Einträge total)
#
# Gruppe: Musi (40 Einträge total)
#
# Gruppe: Vert (76 Einträge total)
#
# Gruppe: H. D (4 Einträge total)
#
# Gruppe: Mehl (44 Einträge total)
#
# Gruppe: Osk. (4 Einträge total)
#
# Gruppe: Ed.  (41 Einträge total)
#
# Gruppe: Bild (30 Einträge total)
#
# Gruppe: Piet (6 Einträge total)
#
# Gruppe: E. H (8 Einträge total)
#
# Gruppe: zur  (128 Einträge total)
#
# Gruppe: Geo. (7 Einträge total)
#
# Gruppe: Schi (79 Einträge total)
#
# Gruppe: Wm. (4 Einträge total)
#
# Gruppe: Manu (95 Einträge total)
#
# Gruppe: C. C (4 Einträge total)
#
# Gruppe: Trai (9 Einträge total)
#
# Gruppe: E  Z (7 Einträge total)
#
# Gruppe: Gaut (3 Einträge total)
#
# Gruppe: Schu (157 Einträge total)
#
# Gruppe: Donn (3 Einträge total)
#
# Gruppe: Sonc (4 Einträge total)
#
# Gruppe: Trav (6 Einträge total)
#
# Gruppe: Wohl (5 Einträge total)
#
# Gruppe: Grin (5 Einträge total)
#
# Gruppe: Kalc (3 Einträge total)
#
# Gruppe: Kerz (3 Einträge total)
#
# Gruppe: Kopp (4 Einträge total)
#
# Gruppe: Sign (5 Einträge total)
#
# Gruppe: Lyss (5 Einträge total)
#
# Gruppe: Rigg (5 Einträge total)
#
# Gruppe: Spie (25 Einträge total)
#
# Gruppe: Gelt (5 Einträge total)
#
# Gruppe: Reig (5 Einträge total)
#
# Gruppe: Aarb (5 Einträge total)
#
# Gruppe: Adli (5 Einträge total)
#
# Gruppe: Diet (8 Einträge total)
#
# Gruppe: Fisc (29 Einträge total)
#
# Gruppe: Horg (7 Einträge total)
#
# Gruppe: Klot (6 Einträge total)
#
# Gruppe: Lach (7 Einträge total)
#
# Gruppe: Lint (8 Einträge total)
#
# Gruppe: Männ (4 Einträge total)
#
# Gruppe: Meil (6 Einträge total)
#
# Gruppe: Sieb (6 Einträge total)
#
# Gruppe: Stec (4 Einträge total)
#
# Gruppe: Wäng (5 Einträge total)
#
# Gruppe: Bisc (7 Einträge total)
#
# Gruppe: Jags (5 Einträge total)
#
# Gruppe: Ball (3 Einträge total)
#
# Gruppe: eher (29 Einträge total)
#
# Gruppe: E.&C (3 Einträge total)
#
# Gruppe: Igna (11 Einträge total)
#
# Gruppe: G- (3 Einträge total)
#
# Gruppe: Krei (56 Einträge total)
#
# Gruppe: Geri (10 Einträge total)
#
# Gruppe: Xav. (4 Einträge total)
#
# Gruppe: Dire (188 Einträge total)
#
# Gruppe: Germ (7 Einträge total)
#
# Gruppe: Isle (4 Einträge total)
#
# Gruppe: Schm (61 Einträge total)
#
# Gruppe: Glas (89 Einträge total)
#
# Gruppe: J.J. (5 Einträge total)
#
# Gruppe: DI. (3 Einträge total)
#
# Gruppe: Beru (3 Einträge total)
#
# Gruppe: Burc (4 Einträge total)
#
# Gruppe: G. F (4 Einträge total)
#
# Gruppe: Lina (3 Einträge total)
#
# Gruppe: J.B. (3 Einträge total)
#
# Gruppe: M. F (3 Einträge total)
#
# Gruppe: Adam (3 Einträge total)
#
# Gruppe: Flor (29 Einträge total)
#
# Gruppe: Agen (177 Einträge total)
#
# Gruppe: P. . (11 Einträge total)
#
# Gruppe: C.F. (5 Einträge total)
#
# Gruppe: Bien (8 Einträge total)
#
# Gruppe: Conf (130 Einträge total)
#
# Gruppe: Salo (8 Einträge total)
#
# Gruppe: Gr. (3 Einträge total)
#
# Gruppe: Älpl (5 Einträge total)
#
# Gruppe: Dr.m (7 Einträge total)
#
# Gruppe: Oh. (3 Einträge total)
#
# Gruppe: Vve. (3 Einträge total)
#
# Gruppe: Haus (26 Einträge total)
#
# Gruppe: Mont (27 Einträge total)
#
# Gruppe: Edm. (6 Einträge total)
#
# Gruppe: F.X. (3 Einträge total)
#
# Gruppe: Drog (120 Einträge total)
#
# Gruppe: Clif (3 Einträge total)
#
# Gruppe: Spez (157 Einträge total)
#
# Gruppe: Büre (9 Einträge total)
#
# Gruppe: M (3 Einträge total)
#
# Gruppe: Sche (13 Einträge total)
#
# Gruppe: Beat (6 Einträge total)
#
# Gruppe: Burg (20 Einträge total)
#
# Gruppe: L. E (6 Einträge total)
#
# Gruppe: Jost (3 Einträge total)
#
# Gruppe: B. & (4 Einträge total)
#
# Gruppe: Pau] (3 Einträge total)
#
# Gruppe: Gh. (3 Einträge total)
#
# Gruppe: Neuc (6 Einträge total)
#
# Gruppe: etc. (6 Einträge total)
#
# Gruppe:  . (3 Einträge total)
#
# Gruppe: lieu (3 Einträge total)
#
# Gruppe: Raou (5 Einträge total)
#
# Gruppe: Guil (5 Einträge total)
#
# Gruppe: L.-E (3 Einträge total)
#
# Gruppe:   Be (9 Einträge total)
#
# Gruppe:  Ave (16 Einträge total)
#
# Gruppe: nég. (11 Einträge total)
#
# Gruppe: C.-F (4 Einträge total)
#
# Gruppe:  Ter (4 Einträge total)
#
# Gruppe:   Fa (9 Einträge total)
#
# Gruppe:  Saa (3 Einträge total)
#
# Gruppe:   Ev (4 Einträge total)
#
# Gruppe:  Clo (4 Einträge total)
#
# Gruppe: .. (3 Einträge total)
#
# Gruppe: V (3 Einträge total)
#
# Gruppe: L' (3 Einträge total)
#
# Gruppe: M'’ (3 Einträge total)
#
# Gruppe: Lyon (3 Einträge total)
#
# Gruppe:  bis (37 Einträge total)
#
# Gruppe: Eaux (36 Einträge total)
#
# Gruppe: G. e (6 Einträge total)
#
# Gruppe: .  G (30 Einträge total)
#
# Gruppe: porc (9 Einträge total)
#
# Gruppe: cris (4 Einträge total)
#
# Gruppe: faïe (5 Einträge total)
#
# Gruppe: vitr (19 Einträge total)
#
# Gruppe: .  A (41 Einträge total)
#
# Gruppe: bijo (39 Einträge total)
#
# Gruppe: drog (28 Einträge total)
#
# Gruppe: géra (22 Einträge total)
#
# Gruppe: thés (4 Einträge total)
#
# Gruppe: L“ (3 Einträge total)
#
# Gruppe: . Cr (10 Einträge total)
#
# Gruppe: . Cl (31 Einträge total)
#
# Gruppe: vins (86 Einträge total)
#
# Gruppe: coif (29 Einträge total)
#
# Gruppe: ling (5 Einträge total)
#
# Gruppe: . Ci (5 Einträge total)
#
# Gruppe: Jenn (4 Einträge total)
#
# Gruppe: I (3 Einträge total)
#
# Gruppe: suce (16 Einträge total)
#
# Gruppe: C (3 Einträge total)
#
# Gruppe: élec (15 Einträge total)
#
# Gruppe: Adèl (7 Einträge total)
#
# Gruppe: serr (57 Einträge total)
#
# Gruppe: V“ (3 Einträge total)
#
# Gruppe: . Gl (7 Einträge total)
#
# Gruppe: V' e (4 Einträge total)
#
# Gruppe: Edwa (4 Einträge total)
#
# Gruppe: G  A (4 Einträge total)
#
# Gruppe: . St (48 Einträge total)
#
# Gruppe: . Va (16 Einträge total)
#
# Gruppe: Fann (3 Einträge total)
#
# Gruppe:   Pl (17 Einträge total)
#
# Gruppe: Maup (11 Einträge total)
#
# Gruppe: . Ma (42 Einträge total)
#
# Gruppe: Schn (30 Einträge total)
#
# Gruppe: Säge (57 Einträge total)
#
# Gruppe: Oth. (3 Einträge total)
#
# Gruppe: Stic (142 Einträge total)
#
# Gruppe: Nend (3 Einträge total)
#
# Gruppe: Käse (136 Einträge total)
#
# Gruppe: K. A (3 Einträge total)
#
# Gruppe: Stef (3 Einträge total)
#
# Gruppe: Naef (5 Einträge total)
#
# Gruppe: E. E (3 Einträge total)
#
# Gruppe: Kd. (3 Einträge total)
#
# Gruppe: Rupe (3 Einträge total)
#
# Gruppe: Däni (3 Einträge total)
#
# Gruppe: Meie (8 Einträge total)
#
# Gruppe: Stäf (9 Einträge total)
#
# Gruppe: Card (3 Einträge total)
#
# Gruppe: Rest (309 Einträge total)
#
# Gruppe: Senn (19 Einträge total)
#
# Gruppe: Ths. (3 Einträge total)
#
# Gruppe: Gamp (4 Einträge total)
#
# Gruppe: Pfäf (10 Einträge total)
#
# Gruppe: A. W (13 Einträge total)
#
# Gruppe: e. (3 Einträge total)
#
# Gruppe: Sibl (5 Einträge total)
#
# Gruppe:      (185 Einträge total)
#
# Gruppe: Sal. (3 Einträge total)
#
# Gruppe: Pass (12 Einträge total)
#
# Gruppe: Aara (8 Einträge total)
#
# Gruppe: Feh. (3 Einträge total)
#
# Gruppe: A. J (4 Einträge total)
#
# Gruppe: Bièr (2 Einträge total)
#
# Gruppe: Brig (3 Einträge total)
#
# Gruppe: Copp (3 Einträge total)
#
# Gruppe: Bell (13 Einträge total)
#
# Gruppe: Cart (14 Einträge total)
#
# Gruppe: Sati (4 Einträge total)
#
# Gruppe: Vand (10 Einträge total)
#
# Gruppe: Vern (9 Einträge total)
#
# Gruppe: Vers (49 Einträge total)
#
# Gruppe: Luce (2 Einträge total)
#
# Gruppe: Mézi (4 Einträge total)
#
# Gruppe: Cras (3 Einträge total)
#
# Gruppe: Roll (10 Einträge total)
#
# Gruppe: Saxo (2 Einträge total)
#
# Gruppe: Colo (45 Einträge total)
#
# Gruppe: Noir (4 Einträge total)
#
# Gruppe: Bümp (7 Einträge total)
#
# Gruppe: Klei (34 Einträge total)
#
# Gruppe: Madi (3 Einträge total)
#
# Gruppe: Meir (2 Einträge total)
#
# Gruppe: Schü (22 Einträge total)
#
# Gruppe: Güns (2 Einträge total)
#
# Gruppe: Läuf (2 Einträge total)
#
# Gruppe: Köll (4 Einträge total)
#
# Gruppe: Lupf (2 Einträge total)
#
# Gruppe: Fric (4 Einträge total)
#
# Gruppe: Murg (2 Einträge total)
#
# Gruppe: Isli (3 Einträge total)
#
# Gruppe: Homb (5 Einträge total)
#
# Gruppe: Mühl (85 Einträge total)
#
# Gruppe: Trie (5 Einträge total)
#
# Gruppe: Amri (3 Einträge total)
#
# Gruppe: Baze (2 Einträge total)
#
# Gruppe: Büts (4 Einträge total)
#
# Gruppe: Dege (4 Einträge total)
#
# Gruppe: Ebna (3 Einträge total)
#
# Gruppe: Erma (2 Einträge total)
#
# Gruppe: Flaw (4 Einträge total)
#
# Gruppe: Heid (4 Einträge total)
#
# Gruppe: Lömm (2 Einträge total)
#
# Gruppe: Rehe (2 Einträge total)
#
# Gruppe: Rors (6 Einträge total)
#
# Gruppe: Enge (11 Einträge total)
#
# Gruppe: Kron (8 Einträge total)
#
# Gruppe: Mörs (5 Einträge total)
#
# Gruppe: Walz (20 Einträge total)
#
# Gruppe: Biss (4 Einträge total)
#
# Gruppe: Chia (2 Einträge total)
#
# Gruppe: Luga (3 Einträge total)
#
# Gruppe: Lenz (8 Einträge total)
#
# Gruppe: Würt (163 Einträge total)
#
# Gruppe: Acha (3 Einträge total)
#
# Gruppe: „  V (2 Einträge total)
#
# Gruppe: Ling (18 Einträge total)
#
# Gruppe: z. B (80 Einträge total)
#
# Gruppe: H. R (8 Einträge total)
#
# Gruppe: Färb (27 Einträge total)
#
# Gruppe: - (2 Einträge total)
#
# Gruppe: — Uh (32 Einträge total)
#
# Gruppe: J Bo (3 Einträge total)
#
# Gruppe: Raim (3 Einträge total)
#
# Gruppe: Ww. (2 Einträge total)
#
# Gruppe: Webe (49 Einträge total)
#
# Gruppe: Fd. (2 Einträge total)
#
# Gruppe: W. & (7 Einträge total)
#
# Gruppe: . . (2 Einträge total)
#
# Gruppe: Meye (4 Einträge total)
#
# Gruppe:  od. (20 Einträge total)
#
# Gruppe: Th.  (24 Einträge total)
#
# Gruppe: Garn (12 Einträge total)
#
# Gruppe: F- (2 Einträge total)
#
# Gruppe: Zimm (114 Einträge total)
#
# Gruppe: Gold (24 Einträge total)
#
# Gruppe: Wm   (4 Einträge total)
#
# Gruppe: Lage (25 Einträge total)
#
# Gruppe:   Al (3 Einträge total)
#
# Gruppe: Pers (2 Einträge total)
#
# Gruppe: Feue (48 Einträge total)
#
# Gruppe: Expe (19 Einträge total)
#
# Gruppe: Dépô (19 Einträge total)
#
# Gruppe: Wage (15 Einträge total)
#
# Gruppe: Kass (16 Einträge total)
#
# Gruppe: Baup (2 Einträge total)
#
# Gruppe: Hoch (12 Einträge total)
#
# Gruppe: Mobi (2 Einträge total)
#
# Gruppe: obri (2 Einträge total)
#
# Gruppe: II.  (46 Einträge total)
#
# Gruppe: Haup (47 Einträge total)
#
# Gruppe:   Ba (12 Einträge total)
#
# Gruppe: Male (78 Einträge total)
#
# Gruppe: Schr (136 Einträge total)
#
# Gruppe: C    (37 Einträge total)
#
# Gruppe: H    (39 Einträge total)
#
# Gruppe: Dr.W (2 Einträge total)
#
# Gruppe: Priv (118 Einträge total)
#
# Gruppe: F    (32 Einträge total)
#
# Gruppe: Möbe (110 Einträge total)
#
# Gruppe: öffe (25 Einträge total)
#
# Gruppe: Butt (34 Einträge total)
#
# Gruppe: WweC (6 Einträge total)
#
# Gruppe: S Ga (2 Einträge total)
#
# Gruppe: M. . (6 Einträge total)
#
# Gruppe: Bijo (42 Einträge total)
#
# Gruppe: Bäre (4 Einträge total)
#
# Gruppe: Tape (146 Einträge total)
#
# Gruppe: Rud  (28 Einträge total)
#
# Gruppe: W. A (5 Einträge total)
#
# Gruppe: Come (73 Einträge total)
#
# Gruppe: & Ap (2 Einträge total)
#
# Gruppe: Coif (66 Einträge total)
#
# Gruppe: B. d (6 Einträge total)
#
# Gruppe: L. C (2 Einträge total)
#
# Gruppe: Is. (2 Einträge total)
#
# Gruppe: H. . (18 Einträge total)
#
# Gruppe: Eish (6 Einträge total)
#
# Gruppe: E. . (31 Einträge total)
#
# Gruppe: W. . (6 Einträge total)
#
# Gruppe: E    (59 Einträge total)
#
# Gruppe: G. . (20 Einträge total)
#
# Gruppe: Entl (6 Einträge total)
#
# Gruppe: Kuns (46 Einträge total)
#
# Gruppe: Eisf (2 Einträge total)
#
# Gruppe: Kami (28 Einträge total)
#
# Gruppe: Koch (11 Einträge total)
#
# Gruppe: Tari (12 Einträge total)
#
# Gruppe: Druc (14 Einträge total)
#
# Gruppe: JSB (2 Einträge total)
#
# Gruppe: ob.  (27 Einträge total)
#
# Gruppe: J.C. (2 Einträge total)
#
# Gruppe: Ceme (54 Einträge total)
#
# Gruppe: Bren (22 Einträge total)
#
# Gruppe: Impo (15 Einträge total)
#
# Gruppe:   Da (3 Einträge total)
#
# Gruppe: A    (70 Einträge total)
#
# Gruppe: Baub (22 Einträge total)
#
# Gruppe: Rob  (14 Einträge total)
#
# Gruppe: Hôte (588 Einträge total)
#
# Gruppe: . &  (4 Einträge total)
#
# Gruppe: W    (22 Einträge total)
#
# Gruppe: Ferg (14 Einträge total)
#
# Gruppe: W. R (2 Einträge total)
#
# Gruppe: Aug  (16 Einträge total)
#
# Gruppe:  Dre (4 Einträge total)
#
# Gruppe: A.&  (2 Einträge total)
#
# Gruppe: S    (19 Einträge total)
#
# Gruppe: Hipp (5 Einträge total)
#
# Gruppe: L. d (2 Einträge total)
#
# Gruppe: Bürs (17 Einträge total)
#
# Gruppe: Bauu (88 Einträge total)
#
# Gruppe: Ch   (21 Einträge total)
#
# Gruppe: z. S (253 Einträge total)
#
# Gruppe: . .  (78 Einträge total)
#
# Gruppe: neue (28 Einträge total)
#
# Gruppe: Hafn (46 Einträge total)
#
# Gruppe: F. P (2 Einträge total)
#
# Gruppe:   Eh (2 Einträge total)
#
# Gruppe: Fili (118 Einträge total)
#
# Gruppe: Fürs (128 Einträge total)
#
# Gruppe: Satt (49 Einträge total)
#
# Gruppe: Witt (8 Einträge total)
#
# Gruppe: Dr.T (2 Einträge total)
#
# Gruppe: Lith (88 Einträge total)
#
# Gruppe: E.&W (2 Einträge total)
#
# Gruppe: Hch  (20 Einträge total)
#
# Gruppe: N  L (2 Einträge total)
#
# Gruppe: Max  (33 Einträge total)
#
# Gruppe: Iman (3 Einträge total)
#
# Gruppe: Jb B (2 Einträge total)
#
# Gruppe: C. . (31 Einträge total)
#
# Gruppe: Ld. (2 Einträge total)
#
# Gruppe: Opti (19 Einträge total)
#
# Gruppe: zum  (216 Einträge total)
#
# Gruppe: Stei (83 Einträge total)
#
# Gruppe: Wm (2 Einträge total)
#
# Gruppe: Sens (10 Einträge total)
#
# Gruppe: G    (38 Einträge total)
#
# Gruppe: Verw (38 Einträge total)
#
# Gruppe: Kond (96 Einträge total)
#
# Gruppe: Kauf (139 Einträge total)
#
# Gruppe: Nach (68 Einträge total)
#
# Gruppe: priv (6 Einträge total)
#
# Gruppe: Lütz (2 Einträge total)
#
# Gruppe: Lade (12 Einträge total)
#
# Gruppe: C. & (10 Einträge total)
#
# Gruppe: Spen (186 Einträge total)
#
# Gruppe: Bott (4 Einträge total)
#
# Gruppe: H. F (7 Einträge total)
#
# Gruppe: Herk (2 Einträge total)
#
# Gruppe: R. e (5 Einträge total)
#
# Gruppe: L. & (8 Einträge total)
#
# Gruppe: Apot (166 Einträge total)
#
# Gruppe: K. . (3 Einträge total)
#
# Gruppe: Ls.  (5 Einträge total)
#
# Gruppe: Ohre (6 Einträge total)
#
# Gruppe: Hutm (14 Einträge total)
#
# Gruppe: Drec (14 Einträge total)
#
# Gruppe: Dett (6 Einträge total)
#
# Gruppe: H Na (2 Einträge total)
#
# Gruppe: Zieg (79 Einträge total)
#
# Gruppe: J..  (12 Einträge total)
#
# Gruppe: vorm (101 Einträge total)
#
# Gruppe: Wwe  (103 Einträge total)
#
# Gruppe: B. F (2 Einträge total)
#
# Gruppe: & Sö (4 Einträge total)
#
# Gruppe: Börs (40 Einträge total)
#
# Gruppe: Meta (35 Einträge total)
#
# Gruppe: Farb (20 Einträge total)
#
# Gruppe: Häut (7 Einträge total)
#
# Gruppe: Kork (6 Einträge total)
#
# Gruppe: Flas (27 Einträge total)
#
# Gruppe: Ed P (2 Einträge total)
#
# Gruppe: Wech (4 Einträge total)
#
# Gruppe: W Al (2 Einträge total)
#
# Gruppe: . R. (7 Einträge total)
#
# Gruppe: Comm (30 Einträge total)
#
# Gruppe: Eier (35 Einträge total)
#
# Gruppe: S.Ad (2 Einträge total)
#
# Gruppe: Kalk (4 Einträge total)
#
# Gruppe: Wäsc (8 Einträge total)
#
# Gruppe: Ed   (50 Einträge total)
#
# Gruppe: Hele (2 Einträge total)
#
# Gruppe:   Ja (4 Einträge total)
#
# Gruppe: Gall (6 Einträge total)
#
# Gruppe: Tapi (11 Einträge total)
#
# Gruppe: B    (12 Einträge total)
#
# Gruppe: P    (9 Einträge total)
#
# Gruppe: Amtm (4 Einträge total)
#
# Gruppe: Müns (18 Einträge total)
#
# Gruppe:   Ka (6 Einträge total)
#
# Gruppe: Kupf (28 Einträge total)
#
# Gruppe: Joh  (16 Einträge total)
#
# Gruppe: Fide (4 Einträge total)
#
# Gruppe: Morf (3 Einträge total)
#
# Gruppe: Galv (4 Einträge total)
#
# Gruppe: z. O (53 Einträge total)
#
# Gruppe: elek (23 Einträge total)
#
# Gruppe: Wett (5 Einträge total)
#
# Gruppe:   Kö (3 Einträge total)
#
# Gruppe: M. & (9 Einträge total)
#
# Gruppe: Cent (40 Einträge total)
#
# Gruppe: Ameu (2 Einträge total)
#
# Gruppe: J.M. (2 Einträge total)
#
# Gruppe: & Be (2 Einträge total)
#
# Gruppe: & St (6 Einträge total)
#
# Gruppe: Reit (8 Einträge total)
#
# Gruppe: ülr. (2 Einträge total)
#
# Gruppe: Alb  (22 Einträge total)
#
# Gruppe: P. d (3 Einträge total)
#
# Gruppe: Emi. (4 Einträge total)
#
# Gruppe: A. . (45 Einträge total)
#
# Gruppe: R    (26 Einträge total)
#
# Gruppe: akad (2 Einträge total)
#
# Gruppe: S St (3 Einträge total)
#
# Gruppe: Pfer (45 Einträge total)
#
# Gruppe: Auss (20 Einträge total)
#
# Gruppe: Werk (40 Einträge total)
#
# Gruppe: Th   (27 Einträge total)
#
# Gruppe: Soeu (3 Einträge total)
#
# Gruppe: D. ( (12 Einträge total)
#
# Gruppe: z. K (98 Einträge total)
#
# Gruppe: Adr. (2 Einträge total)
#
# Gruppe: Lino (3 Einträge total)
#
# Gruppe: Küfe (61 Einträge total)
#
# Gruppe: J. d (4 Einträge total)
#
# Gruppe: Sarg (9 Einträge total)
#
# Gruppe: Café (107 Einträge total)
#
# Gruppe: Hafe (7 Einträge total)
#
# Gruppe: Lehr (41 Einträge total)
#
# Gruppe: Dr.H (2 Einträge total)
#
# Gruppe: Papi (55 Einträge total)
#
# Gruppe: Weis (21 Einträge total)
#
# Gruppe: Adal (2 Einträge total)
#
# Gruppe: R. F (6 Einträge total)
#
# Gruppe: J. . (29 Einträge total)
#
# Gruppe: Verb (2 Einträge total)
#
# Gruppe: phar (155 Einträge total)
#
# Gruppe: z. W (34 Einträge total)
#
# Gruppe: Stro (42 Einträge total)
#
# Gruppe: Immo (4 Einträge total)
#
# Gruppe: Gumm (14 Einträge total)
#
# Gruppe: A. P (5 Einträge total)
#
# Gruppe: Besi (2 Einträge total)
#
# Gruppe: A. R (3 Einträge total)
#
# Gruppe: Para (8 Einträge total)
#
# Gruppe: E St (6 Einträge total)
#
# Gruppe: Brau (46 Einträge total)
#
# Gruppe: R El (4 Einträge total)
#
# Gruppe: Gyps (54 Einträge total)
#
# Gruppe: Bett (30 Einträge total)
#
# Gruppe: prak (23 Einträge total)
#
# Gruppe: Büch (13 Einträge total)
#
# Gruppe: chir (15 Einträge total)
#
# Gruppe: Maie (14 Einträge total)
#
# Gruppe: Fr   (23 Einträge total)
#
# Gruppe: N    (6 Einträge total)
#
# Gruppe: Tafe (9 Einträge total)
#
# Gruppe: kant (146 Einträge total)
#
# Gruppe: Lic. (2 Einträge total)
#
# Gruppe: Sani (21 Einträge total)
#
# Gruppe: M.   (4 Einträge total)
#
# Gruppe: Dr.C (2 Einträge total)
#
# Gruppe: Wern (7 Einträge total)
#
# Gruppe: L    (11 Einträge total)
#
# Gruppe: von  (11 Einträge total)
#
# Gruppe: Korn (4 Einträge total)
#
# Gruppe: C. H (6 Einträge total)
#
# Gruppe: Pfar (57 Einträge total)
#
# Gruppe: A Ga (2 Einträge total)
#
# Gruppe: & Fi (2 Einträge total)
#
# Gruppe: J Rö (2 Einträge total)
#
# Gruppe: WweA (2 Einträge total)
#
# Gruppe: (Hôt (5 Einträge total)
#
# Gruppe: Chs  (6 Einträge total)
#
# Gruppe:    S (2 Einträge total)
#
# Gruppe: trai (2 Einträge total)
#
# Gruppe: Ch.  (40 Einträge total)
#
# Gruppe: E  S (13 Einträge total)
#
# Gruppe: Bang (2 Einträge total)
#
# Gruppe: WweR (4 Einträge total)
#
# Gruppe: Bank (47 Einträge total)
#
# Gruppe: Post (126 Einträge total)
#
# Gruppe: Géra (7 Einträge total)
#
# Gruppe: Sam  (5 Einträge total)
#
# Gruppe: Land (106 Einträge total)
#
# Gruppe: Stal (12 Einträge total)
#
# Gruppe: E By (2 Einträge total)
#
# Gruppe: Bart (7 Einträge total)
#
# Gruppe: G.Fr (2 Einträge total)
#
# Gruppe: WweM (3 Einträge total)
#
# Gruppe: WweJ (2 Einträge total)
#
# Gruppe: chri (2 Einträge total)
#
# Gruppe: & Fu (2 Einträge total)
#
# Gruppe: Pfr. (6 Einträge total)
#
# Gruppe: J.Au (2 Einträge total)
#
# Gruppe: Zith (2 Einträge total)
#
# Gruppe: „Bas (2 Einträge total)
#
# Gruppe: Dien (12 Einträge total)
#
# Gruppe: C Mi (2 Einträge total)
#
# Gruppe: F. . (21 Einträge total)
#
# Gruppe: R. . (15 Einträge total)
#
# Gruppe: Kran (13 Einträge total)
#
# Gruppe: Brun (14 Einträge total)
#
# Gruppe: G. K (2 Einträge total)
#
# Gruppe: Bald (2 Einträge total)
#
# Gruppe: Erz. (2 Einträge total)
#
# Gruppe: M .  (7 Einträge total)
#
# Gruppe: Ed M (2 Einträge total)
#
# Gruppe: phot (40 Einträge total)
#
# Gruppe: F Bä (2 Einträge total)
#
# Gruppe: R. G (3 Einträge total)
#
# Gruppe: Etti (2 Einträge total)
#
# Gruppe: Münc (4 Einträge total)
#
# Gruppe: agri (8 Einträge total)
#
# Gruppe: IL S (2 Einträge total)
#
# Gruppe: Bass (4 Einträge total)
#
# Gruppe: négt (29 Einträge total)
#
# Gruppe: vété (38 Einträge total)
#
# Gruppe: bouc (292 Einträge total)
#
# Gruppe: ferb (66 Einträge total)
#
# Gruppe: Rina (2 Einträge total)
#
# Gruppe: Co. (2 Einträge total)
#
# Gruppe: bras (37 Einträge total)
#
# Gruppe: libr (42 Einträge total)
#
# Gruppe: rest (56 Einträge total)
#
# Gruppe: Béat (2 Einträge total)
#
# Gruppe: négo (201 Einträge total)
#
# Gruppe: Chef (21 Einträge total)
#
# Gruppe: méca (22 Einträge total)
#
# Gruppe: Ripp (2 Einträge total)
#
# Gruppe: denr (41 Einträge total)
#
# Gruppe: Cour (11 Einträge total)
#
# Gruppe: Deve (2 Einträge total)
#
# Gruppe: Fiec (2 Einträge total)
#
# Gruppe: Dr L (4 Einträge total)
#
# Gruppe: Epic (8 Einträge total)
#
# Gruppe: Nunn (2 Einträge total)
#
# Gruppe: Amma (16 Einträge total)
#
# Gruppe: Ditt (2 Einträge total)
#
# Gruppe: Rösc (2 Einträge total)
#
# Gruppe: Ersc (2 Einträge total)
#
# Gruppe: Fehr (3 Einträge total)
#
# Gruppe: . Li (4 Einträge total)
#
# Gruppe: Akti (17 Einträge total)
#
# Gruppe: Dest (2 Einträge total)
#
# Gruppe: Liqu (11 Einträge total)
#
# Gruppe: F Fr (3 Einträge total)
#
# Gruppe: cons (65 Einträge total)
#
# Gruppe: usin (16 Einträge total)
#
# Gruppe: tuil (11 Einträge total)
#
# Gruppe: A Sp (2 Einträge total)
#
# Gruppe: de B (2 Einträge total)
#
# Gruppe: Alle (5 Einträge total)
#
# Gruppe: manu (30 Einträge total)
#
# Gruppe: Muni (30 Einträge total)
#
# Gruppe: four (26 Einträge total)
#
# Gruppe: Kohl (25 Einträge total)
#
# Gruppe: gran (9 Einträge total)
#
# Gruppe: Rous (3 Einträge total)
#
# Gruppe: comm (96 Einträge total)
#
# Gruppe: Jos  (15 Einträge total)
#
# Gruppe: vill (21 Einträge total)
#
# Gruppe: conf (109 Einträge total)
#
# Gruppe: d’ho (23 Einträge total)
#
# Gruppe: ameu (7 Einträge total)
#
# Gruppe: aube (49 Einträge total)
#
# Gruppe: Frég (2 Einträge total)
#
# Gruppe: Fahy (2 Einträge total)
#
# Gruppe: wie  (2 Einträge total)
#
# Gruppe: Cell (4 Einträge total)
#
# Gruppe: Hote (127 Einträge total)
#
# Gruppe: Wege (2 Einträge total)
#
# Gruppe: I. A (36 Einträge total)
#
# Gruppe: Haas (2 Einträge total)
#
# Gruppe: Ebau (4 Einträge total)
#
# Gruppe: Band (26 Einträge total)
#
# Gruppe: z. L (110 Einträge total)
#
# Gruppe: Uhre (65 Einträge total)
#
# Gruppe: Summ (5 Einträge total)
#
# Gruppe: Henn (5 Einträge total)
#
# Gruppe: B.. (2 Einträge total)
#
# Gruppe:   So (4 Einträge total)
#
# Gruppe: Jérô (2 Einträge total)
#
# Gruppe:   St (18 Einträge total)
#
# Gruppe: Xavi (2 Einträge total)
#
# Gruppe: Laup (4 Einträge total)
#
# Gruppe: Murt (11 Einträge total)
#
# Gruppe: Thun (12 Einträge total)
#
# Gruppe: Veve (16 Einträge total)
#
# Gruppe: Kons (25 Einträge total)
#
# Gruppe: Bund (26 Einträge total)
#
# Gruppe: K. T (2 Einträge total)
#
# Gruppe: P. ( (7 Einträge total)
#
# Gruppe: Au s (2 Einträge total)
#
# Gruppe: Eisl (4 Einträge total)
#
# Gruppe: Kava (4 Einträge total)
#
# Gruppe: Dame (31 Einträge total)
#
# Gruppe: Masc (116 Einträge total)
#
# Gruppe: Dach (33 Einträge total)
#
# Gruppe: G. G (5 Einträge total)
#
# Gruppe: Rabu (2 Einträge total)
#
# Gruppe: Ostb (2 Einträge total)
#
# Gruppe: Revi (5 Einträge total)
#
# Gruppe: Plac (18 Einträge total)
#
# Gruppe: Sekr (25 Einträge total)
#
# Gruppe: Gugg (9 Einträge total)
#
# Gruppe: Wais (5 Einträge total)
#
# Gruppe: Prok (2 Einträge total)
#
# Gruppe: Hs (2 Einträge total)
#
# Gruppe: K. L (4 Einträge total)
#
# Gruppe: Saue (6 Einträge total)
#
# Gruppe: Tele (55 Einträge total)
#
# Gruppe: bürg (5 Einträge total)
#
# Gruppe: Spin (54 Einträge total)
#
# Gruppe: K. D (2 Einträge total)
#
# Gruppe: Chem (45 Einträge total)
#
# Gruppe: R  F (2 Einträge total)
#
# Gruppe: Alte (2 Einträge total)
#
# Gruppe: .loh (3 Einträge total)
#
# Gruppe: ride (3 Einträge total)
#
# Gruppe: Banq (43 Einträge total)
#
# Gruppe: Firn (4 Einträge total)
#
# Gruppe: Tuch (96 Einträge total)
#
# Gruppe: Sach (4 Einträge total)
#
# Gruppe: Spri (8 Einträge total)
#
# Gruppe: Gebe (2 Einträge total)
#
# Gruppe: J.L. (2 Einträge total)
#
# Gruppe: Dorf (9 Einträge total)
#
# Gruppe: G. J (4 Einträge total)
#
# Gruppe: Gotl (4 Einträge total)
#
# Gruppe: Quar (9 Einträge total)
#
# Gruppe: Dr.. (49 Einträge total)
#
# Gruppe: H  I (2 Einträge total)
#
# Gruppe: Reg. (9 Einträge total)
#
# Gruppe: Pens (75 Einträge total)
#
# Gruppe: S. ( (6 Einträge total)
#
# Gruppe: Korb (17 Einträge total)
#
# Gruppe: Dr.j (7 Einträge total)
#
# Gruppe: E. T (2 Einträge total)
#
# Gruppe: Posa (15 Einträge total)
#
# Gruppe: tech (39 Einträge total)
#
# Gruppe: Zeug (7 Einträge total)
#
# Gruppe: & Fr (2 Einträge total)
#
# Gruppe: Heba (25 Einträge total)
#
# Gruppe: Oele (4 Einträge total)
#
# Gruppe: « Li (2 Einträge total)
#
# Gruppe: Sain (12 Einträge total)
#
# Gruppe: à la (6 Einträge total)
#
# Gruppe: Quin (12 Einträge total)
#
# Gruppe: Lede (44 Einträge total)
#
# Gruppe: Staa (12 Einträge total)
#
# Gruppe: Kfm. (5 Einträge total)
#
# Gruppe: Gewü (2 Einträge total)
#
# Gruppe:   Lü (2 Einträge total)
#
# Gruppe: Jour (21 Einträge total)
#
# Gruppe: en g (12 Einträge total)
#
# Gruppe: W. E (2 Einträge total)
#
# Gruppe: Kar] (2 Einträge total)
#
# Gruppe: Gros (35 Einträge total)
#
# Gruppe: Baus (31 Einträge total)
#
# Gruppe: Zeer (2 Einträge total)
#
# Gruppe: Seif (15 Einträge total)
#
# Gruppe: hist (2 Einträge total)
#
# Gruppe: Dr-m (5 Einträge total)
#
# Gruppe: Gene (44 Einträge total)
#
# Gruppe: Füss (3 Einträge total)
#
# Gruppe: K    (4 Einträge total)
#
# Gruppe: Hamm (6 Einträge total)
#
# Gruppe: Klav (6 Einträge total)
#
# Gruppe: Marb (4 Einträge total)
#
# Gruppe: med. (18 Einträge total)
#
# Gruppe: Spir (8 Einträge total)
#
# Gruppe: Repr (4 Einträge total)
#
# Gruppe: F. ( (31 Einträge total)
#
# Gruppe: Flei (38 Einträge total)
#
# Gruppe: Pelz (6 Einträge total)
#
# Gruppe: Back (12 Einträge total)
#
# Gruppe: Corr (5 Einträge total)
#
# Gruppe: de I (4 Einträge total)
#
# Gruppe: de L (5 Einträge total)
#
# Gruppe: Mini (2 Einträge total)
#
# Gruppe:   Ro (9 Einträge total)
#
# Gruppe: Mm (2 Einträge total)
#
# Gruppe: Luis (2 Einträge total)
#
# Gruppe: Poli (29 Einträge total)
#
# Gruppe: E.A. (2 Einträge total)
#
# Gruppe: Knop (2 Einträge total)
#
# Gruppe: J. T (2 Einträge total)
#
# Gruppe: Parq (32 Einträge total)
#
# Gruppe: alt  (20 Einträge total)
#
# Gruppe: Pflä (16 Einträge total)
#
# Gruppe: Maas (2 Einträge total)
#
# Gruppe: z. T (43 Einträge total)
#
# Gruppe: Orts (3 Einträge total)
#
# Gruppe: M. ( (12 Einträge total)
#
# Gruppe: Adju (6 Einträge total)
#
# Gruppe: Amts (49 Einträge total)
#
# Gruppe: Urba (4 Einträge total)
#
# Gruppe: Früc (4 Einträge total)
#
# Gruppe: Sulg (3 Einträge total)
#
# Gruppe: Erzi (5 Einträge total)
#
# Gruppe: Irre (4 Einträge total)
#
# Gruppe: Dr   (58 Einträge total)
#
# Gruppe: «Ber (2 Einträge total)
#
# Gruppe: ILO. (2 Einträge total)
#
# Gruppe: Vieh (65 Einträge total)
#
# Gruppe: Ob.- (2 Einträge total)
#
# Gruppe: Tepp (19 Einträge total)
#
# Gruppe: Les  (10 Einträge total)
#
# Gruppe: S. F (2 Einträge total)
#
# Gruppe: Bahn (101 Einträge total)
#
# Gruppe: Gasg (7 Einträge total)
#
# Gruppe:    A (2 Einträge total)
#
# Gruppe: auf  (13 Einträge total)
#
# Gruppe: Bezi (69 Einträge total)
#
# Gruppe: Mlle (13 Einträge total)
#
# Gruppe: nouv (16 Einträge total)
#
# Gruppe: Beau (4 Einträge total)
#
# Gruppe: étab (6 Einträge total)
#
# Gruppe: Lind (7 Einträge total)
#
# Gruppe: Mode (23 Einträge total)
#
# Gruppe: atel (26 Einträge total)
#
# Gruppe: Chal (18 Einträge total)
#
# Gruppe: G.)  (8 Einträge total)
#
# Gruppe: Secr (3 Einträge total)
#
# Gruppe: Spec (3 Einträge total)
#
# Gruppe: merc (21 Einträge total)
#
# Gruppe: au C (2 Einträge total)
#
# Gruppe: posa (2 Einträge total)
#
# Gruppe: E.-L (4 Einträge total)
#
# Gruppe: (ils (3 Einträge total)
#
# Gruppe: Gari (3 Einträge total)
#
# Gruppe: E Ip (2 Einträge total)
#
# Gruppe: Négo (11 Einträge total)
#
# Gruppe: Adle (9 Einträge total)
#
# Gruppe: Grim (2 Einträge total)
#
# Gruppe: à l’ (5 Einträge total)
#
# Gruppe: Span (9 Einträge total)
#
# Gruppe: P. J (4 Einträge total)
#
# Gruppe: Déco (2 Einträge total)
#
# Gruppe: H.-C (4 Einträge total)
#
# Gruppe: Vill (153 Einträge total)
#
# Gruppe:  Ros (3 Einträge total)
#
# Gruppe: Molk (12 Einträge total)
#
# Gruppe: Kuhn (2 Einträge total)
#
# Gruppe: Port (9 Einträge total)
#
# Gruppe: Matt (6 Einträge total)
#
# Gruppe: Ofen (26 Einträge total)
#
# Gruppe: Wert (2 Einträge total)
#
# Gruppe: Waff (10 Einträge total)
#
# Gruppe: Hirs (14 Einträge total)
#
# Gruppe: seni (4 Einträge total)
#
# Gruppe: Lein (12 Einträge total)
#
# Gruppe: Rent (6 Einträge total)
#
# Gruppe: klei (3 Einträge total)
#
# Gruppe: Taba (24 Einträge total)
#
# Gruppe: M... (10 Einträge total)
#
# Gruppe: . He (5 Einträge total)
#
# Gruppe: z. F (110 Einträge total)
#
# Gruppe: We. (2 Einträge total)
#
# Gruppe: Gsch (3 Einträge total)
#
# Gruppe: Tric (23 Einträge total)
#
# Gruppe: Laut (9 Einträge total)
#
# Gruppe: Kuts (13 Einträge total)
#
# Gruppe: F. N (4 Einträge total)
#
# Gruppe: Domi (4 Einträge total)
#
# Gruppe: Bras (32 Einträge total)
#
# Gruppe: voit (110 Einträge total)
#
# Gruppe: Sieg (15 Einträge total)
#
# Gruppe: Eber (3 Einträge total)
#
# Gruppe: Bunt (6 Einträge total)
#
# Gruppe: Wiss (2 Einträge total)
#
# Gruppe: Biem (2 Einträge total)
#
# Gruppe: Spar (3 Einträge total)
#
# Gruppe: Neum (5 Einträge total)
#
# Gruppe: medi (35 Einträge total)
#
# Gruppe: de M (5 Einträge total)
#
# Gruppe: . Ly (2 Einträge total)
#
# Gruppe: Jh. (2 Einträge total)
#
# Gruppe: Oeko (4 Einträge total)
#
# Gruppe: stat (50 Einträge total)
#
# Gruppe:  Sch (16 Einträge total)
#
# Gruppe: ober (15 Einträge total)
#
# Gruppe: Nego (30 Einträge total)
#
# Gruppe: . So (5 Einträge total)
#
# Gruppe: Hess (13 Einträge total)
#
# Gruppe: V. N (3 Einträge total)
#
# Gruppe: Rekt (7 Einträge total)
#
# Gruppe: L  K (2 Einträge total)
#
# Gruppe: Tsch (3 Einträge total)
#
# Gruppe: Jägg (2 Einträge total)
#
# Gruppe: Zell (6 Einträge total)
#
# Gruppe: sen. (3 Einträge total)
#
# Gruppe: Muse (6 Einträge total)
#
# Gruppe: N  W (2 Einträge total)
#
# Gruppe: Faul (2 Einträge total)
#
# Gruppe: Nati (15 Einträge total)
#
# Gruppe: Toil (2 Einträge total)
#
# Gruppe: Erle (5 Einträge total)
#
# Gruppe: Gerl (2 Einträge total)
#
# Gruppe: Watt (3 Einträge total)
#
# Gruppe: Lebe (17 Einträge total)
#
# Gruppe: W.)  (2 Einträge total)
#
# Gruppe: Inst (46 Einträge total)
#
# Gruppe: Schö (18 Einträge total)
#
# Gruppe: Dr.- (9 Einträge total)
#
# Gruppe: Gies (23 Einträge total)
#
# Gruppe: Baza (20 Einträge total)
#
# Gruppe: Abon (16 Einträge total)
#
# Gruppe: Gebt (3 Einträge total)
#
# ...
#
# Gruppe:  Amr (1 Einträge total)
#
# Gruppe: J Di (1 Einträge total)
#
# Gruppe: golt (1 Einträge total)
#
# Gruppe:  I.  (2 Einträge total)
#
# Gruppe: ßär  (1 Einträge total)
#
# Gruppe: joh. (1 Einträge total)
#
# Gruppe: Häfn (1 Einträge total)
#
# Gruppe: jj j (1 Einträge total)
#
# Gruppe: Rohi (1 Einträge total)
#
# Gruppe: Tage (1 Einträge total)
#
# Gruppe: Brii (1 Einträge total)
#
# Gruppe: . G- (1 Einträge total)
#
# Gruppe: Milh (1 Einträge total)
#
# Gruppe: F „  (1 Einträge total)
#
# Gruppe: C „  (1 Einträge total)
#
# Gruppe: N (1 Einträge total)
#
# Gruppe: P  J (1 Einträge total)
#
# Gruppe: J  J (2 Einträge total)
#
# Gruppe: Luch (1 Einträge total)
#
# Gruppe: J Bu (1 Einträge total)
#
# Gruppe: F ”  (1 Einträge total)
#
# Gruppe: Trüm (1 Einträge total)
#
# Gruppe: W  W (2 Einträge total)
#
# Gruppe: . Go (1 Einträge total)
#
# Gruppe: Febr (1 Einträge total)
#
# Gruppe:  Rüt (2 Einträge total)
#
# Gruppe:  Aff (1 Einträge total)
#
# Gruppe: Dümt (1 Einträge total)
#
# Gruppe: :. H (1 Einträge total)
#
# Gruppe: Pfis (1 Einträge total)
#
# Gruppe: R Fe (1 Einträge total)
#
# Gruppe: Oasp (1 Einträge total)
#
# Gruppe: Odin (1 Einträge total)
#
# Gruppe: Hroh (1 Einträge total)
#
# Gruppe: ” z. (1 Einträge total)
#
# Gruppe: Tucl (1 Einträge total)
#
# Gruppe: . ll (1 Einträge total)
#
# Gruppe:   „  (2 Einträge total)
#
# Gruppe: ijei (1 Einträge total)
#
# Gruppe: Oett (1 Einträge total)
#
# Gruppe: Und. (1 Einträge total)
#
# Gruppe: K.   (1 Einträge total)
#
# Gruppe: Chi. (1 Einträge total)
#
# Gruppe: ; -  (1 Einträge total)
#
# Gruppe: - „  (1 Einträge total)
#
# Gruppe: räse (1 Einträge total)
#
# Gruppe: Sch. (1 Einträge total)
#
# Gruppe: —/ „ (1 Einträge total)
#
# Gruppe: J Bä (2 Einträge total)
#
# Gruppe: l- S (1 Einträge total)
#
# Gruppe: zumC (1 Einträge total)
#
# Gruppe: Jb R (1 Einträge total)
#
# Gruppe: Z. W (1 Einträge total)
#
# Gruppe: A-G (1 Einträge total)
#
# Gruppe: ! Me (1 Einträge total)
#
# Gruppe: Kobi (1 Einträge total)
#
# Gruppe: . Ni (1 Einträge total)
#
# Gruppe: GO o (1 Einträge total)
#
# Gruppe: Bior (1 Einträge total)
#
# Gruppe: Irge (1 Einträge total)
#
# Gruppe: Gem  (1 Einträge total)
#
# Gruppe: . Ff (1 Einträge total)
#
# Gruppe: Neft (1 Einträge total)
#
# Gruppe: (St. (1 Einträge total)
#
# Gruppe:  Mei (3 Einträge total)
#
# Gruppe: Hies (1 Einträge total)
#
# Gruppe: Â. (1 Einträge total)
#
# Gruppe: Â.-G (1 Einträge total)
#
# Gruppe: Pfen (1 Einträge total)
#
# Gruppe: Dr A (2 Einträge total)
#
# Gruppe: A An (1 Einträge total)
#
# Gruppe: wwe. (1 Einträge total)
#
# Gruppe: N. O (1 Einträge total)
#
# Gruppe: Mtz. (1 Einträge total)
#
# Gruppe: Bauv (1 Einträge total)
#
# Gruppe: KolO (1 Einträge total)
#
# Gruppe: ZOT  (1 Einträge total)
#
# Gruppe: Brüt (1 Einträge total)
#
# Gruppe: Fiet (1 Einträge total)
#
# Gruppe: Wolu (1 Einträge total)
#
# Gruppe: AMI (1 Einträge total)
#
# Gruppe: R A  (1 Einträge total)
#
# Gruppe: Ti   (1 Einträge total)
#
# Gruppe: ReMi (1 Einträge total)
#
# Gruppe: Knöp (1 Einträge total)
#
# Gruppe: F Me (1 Einträge total)
#
# Gruppe: sen  (1 Einträge total)
#
# Gruppe: z (1 Einträge total)
#
# Gruppe: A Ra (1 Einträge total)
#
# Gruppe: ResU (1 Einträge total)
#
# Gruppe: Sigg (1 Einträge total)
#
# Gruppe: Paji (1 Einträge total)
#
# Gruppe: Bubo (1 Einträge total)
#
# Gruppe: Beis (1 Einträge total)
#
# Gruppe: Vett (2 Einträge total)
#
# Gruppe: Dr W (1 Einträge total)
#
# Gruppe: C  Z (2 Einträge total)
#
# Gruppe: Gemc (1 Einträge total)
#
# Gruppe: S Ob (1 Einträge total)
#
# Gruppe: /—/  (1 Einträge total)
#
# Gruppe: -*/t (1 Einträge total)
#
# Gruppe: G-em (1 Einträge total)
#
# Gruppe: WOln (1 Einträge total)
#
# Gruppe: Rand (1 Einträge total)
#
# Gruppe:  „  (1 Einträge total)
#
# Gruppe: Bucb (1 Einträge total)
#
# Gruppe: Kümb (1 Einträge total)
#
# Gruppe: Ulr (1 Einträge total)
#
# Gruppe: J  Z (1 Einträge total)
#
# Gruppe: J J  (1 Einträge total)
#
# Gruppe: stöc (1 Einträge total)
#
# Gruppe: IJln (1 Einträge total)
#
# Gruppe: Zent (2 Einträge total)
#
# Gruppe: A Kü (1 Einträge total)
#
# Gruppe: ‘Wei (1 Einträge total)
#
# Gruppe: Gess (2 Einträge total)
#
# Gruppe: Naum (1 Einträge total)
#
# Gruppe: EL.  (1 Einträge total)
#
# Gruppe: EEei (1 Einträge total)
#
# Gruppe:  Fis (1 Einträge total)
#
# Gruppe: Cafe (1 Einträge total)
#
# Gruppe: g Ge (1 Einträge total)
#
# Gruppe: —§/  (1 Einträge total)
#
# Gruppe: Uhi' (1 Einträge total)
#
# Gruppe: —’/« (1 Einträge total)
#
# Gruppe: Jörg (1 Einträge total)
#
# Gruppe: Rcg. (1 Einträge total)
#
# Gruppe: Codi (1 Einträge total)
#
# Gruppe: Edm  (1 Einträge total)
#
# Gruppe: P es (1 Einträge total)
#
# Gruppe: z Ro (1 Einträge total)
#
# Gruppe:   z. (1 Einträge total)
#
# Gruppe: Burm (1 Einträge total)
#
# Gruppe: H Pl (1 Einträge total)
#
# Gruppe: Dr V (1 Einträge total)
#
# Gruppe: Inha (1 Einträge total)
#
# Gruppe: Ed’. (1 Einträge total)
#
# Gruppe: Gnid (1 Einträge total)
#
# Gruppe: Grög (1 Einträge total)
#
# Gruppe: Alif (1 Einträge total)
#
# Gruppe: Hofm (1 Einträge total)
#
# Gruppe: JO   (1 Einträge total)
#
# Gruppe: Wied (1 Einträge total)
#
# Gruppe: C Ku (1 Einträge total)
#
# Gruppe: T  L (1 Einträge total)
#
# Gruppe: E. Q (1 Einträge total)
#
# Gruppe: J Rä (1 Einträge total)
#
# Gruppe: Eeue (1 Einträge total)
#
# Gruppe: Paui (1 Einträge total)
#
# Gruppe: Sohö (1 Einträge total)
#
# Gruppe: Tb W (1 Einträge total)
#
# Gruppe: M  R (1 Einträge total)
#
# Gruppe: Scbr (1 Einträge total)
#
# Gruppe: U- (1 Einträge total)
#
# Gruppe: (FGÜ (1 Einträge total)
#
# Gruppe: Sulz (1 Einträge total)
#
# Gruppe: A Vo (1 Einträge total)
#
# Gruppe: G Vo (1 Einträge total)
#
# Gruppe: E Ru (1 Einträge total)
#
# Gruppe: Hann (1 Einträge total)
#
# Gruppe: Ron. (1 Einträge total)
#
# Gruppe: —V „ (1 Einträge total)
#
# Gruppe: Wahr (1 Einträge total)
#
# Gruppe: Vom  (1 Einträge total)
#
# Gruppe: ;  - (1 Einträge total)
#
# Gruppe:  _   (1 Einträge total)
#
# Gruppe: » St (1 Einträge total)
#
# Gruppe: WÜFt (1 Einträge total)
#
# Gruppe: Preu (1 Einträge total)
#
# Gruppe: . _  (2 Einträge total)
#
# Gruppe: . à. (1 Einträge total)
#
# Gruppe: WMßm (1 Einträge total)
#
# Gruppe: Wiir (1 Einträge total)
#
# Gruppe: ; .  (1 Einträge total)
#
# Gruppe: „ Fe (1 Einträge total)
#
# Gruppe: „ Mü (1 Einträge total)
#
# Gruppe: Zeh. (5 Einträge total)
#
# Gruppe: Filä (1 Einträge total)
#
# Gruppe: „ -. (1 Einträge total)
#
# Gruppe: Savo (2 Einträge total)
#
# Gruppe: Hte. (7 Einträge total)
#
# Gruppe: Ardè (1 Einträge total)
#
# Gruppe: Vauc (1 Einträge total)
#
# Gruppe: Hit. (1 Einträge total)
#
# Gruppe: Ain. (4 Einträge total)
#
# Gruppe: Isèr (5 Einträge total)
#
# Gruppe: Côte (1 Einträge total)
#
# Gruppe: Vosg (1 Einträge total)
#
# Gruppe: — _  (2 Einträge total)
#
# Gruppe: Loir (1 Einträge total)
#
# Gruppe: Drôm (1 Einträge total)
#
# Gruppe: - —  (2 Einträge total)
#
# Gruppe: Ht.  (2 Einträge total)
#
# Gruppe: — Fr (1 Einträge total)
#
# Gruppe:  Net (1 Einträge total)
#
# Gruppe: C Au (1 Einträge total)
#
# Gruppe: F Se (1 Einträge total)
#
# Gruppe: Harn (1 Einträge total)
#
# Gruppe: Ed V (1 Einträge total)
#
# Gruppe:  Akt (1 Einträge total)
#
# Gruppe:  Aep (1 Einträge total)
#
# Gruppe: Wbhn (4 Einträge total)
#
# Gruppe: Reel (1 Einträge total)
#
# Gruppe: .Fur (1 Einträge total)
#
# Gruppe: Or.  (1 Einträge total)
#
# Gruppe: SeiM (1 Einträge total)
#
# Gruppe: MOlt (1 Einträge total)
#
# Gruppe: 'Wai (1 Einträge total)
#
# Gruppe:  Ben (1 Einträge total)
#
# Gruppe: Gras (1 Einträge total)
#
# Gruppe: R.. (1 Einträge total)
#
# Gruppe: Dr.i (1 Einträge total)
#
# Gruppe:   Fo (1 Einträge total)
#
# Gruppe: Jupo (1 Einträge total)
#
# Gruppe: (Rot (1 Einträge total)
#
# Gruppe: Ooer (1 Einträge total)
#
# Gruppe: l Zü (1 Einträge total)
#
# Gruppe:  Bla (1 Einträge total)
#
# Gruppe: '  B (1 Einträge total)
#
# Gruppe: J Bl (1 Einträge total)
#
# Gruppe: S .  (1 Einträge total)
#
# Gruppe: L Bl (1 Einträge total)
#
# Gruppe: O sk (1 Einträge total)
#
# Gruppe: Bodm (2 Einträge total)
#
# Gruppe:  Bod (1 Einträge total)
#
# Gruppe: À  B (2 Einträge total)
#
# Gruppe: Llmn (1 Einträge total)
#
# Gruppe:  Bom (1 Einträge total)
#
# Gruppe: O  B (1 Einträge total)
#
# Gruppe: V. G (1 Einträge total)
#
# Gruppe: Bech (2 Einträge total)
#
# Gruppe: Nacb (1 Einträge total)
#
# Gruppe: U  B (1 Einträge total)
#
# Gruppe: (Dru (1 Einträge total)
#
# Gruppe: ßleK (1 Einträge total)
#
# Gruppe: Jill (1 Einträge total)
#
# Gruppe: W.Gi (1 Einträge total)
#
# Gruppe: Aro. (1 Einträge total)
#
# Gruppe: sieg (1 Einträge total)
#
# Gruppe: frat (1 Einträge total)
#
# Gruppe: a. (1 Einträge total)
#
# Gruppe: Hera (1 Einträge total)
#
# Gruppe: VOff (1 Einträge total)
#
# Gruppe:  Dal (1 Einträge total)
#
# Gruppe: Ulr  (1 Einträge total)
#
# Gruppe: “ il (1 Einträge total)
#
# Gruppe: i. E (1 Einträge total)
#
# Gruppe: Aut  (1 Einträge total)
#
# Gruppe:  Dol (1 Einträge total)
#
# Gruppe: R.U. (1 Einträge total)
#
# Gruppe: M.&  (1 Einträge total)
#
# Gruppe:  Dür (1 Einträge total)
#
# Gruppe: G .  (1 Einträge total)
#
# Gruppe: Dr D (1 Einträge total)
#
# Gruppe: deut (1 Einträge total)
#
# Gruppe: jetz (1 Einträge total)
#
# Gruppe: C.àu (1 Einträge total)
#
# Gruppe: U« (1 Einträge total)
#
# Gruppe: Mian (1 Einträge total)
#
# Gruppe: Rämi (1 Einträge total)
#
# Gruppe: J n. (1 Einträge total)
#
# Gruppe: R Su (1 Einträge total)
#
# Gruppe:  Ern (1 Einträge total)
#
# Gruppe: Fetz (1 Einträge total)
#
# Gruppe: Calm (1 Einträge total)
#
# Gruppe: j. g (1 Einträge total)
#
# Gruppe: mecù (1 Einträge total)
#
# Gruppe:  För (1 Einträge total)
#
# Gruppe: alko (2 Einträge total)
#
# Gruppe: Pedi (1 Einträge total)
#
# Gruppe: C. T (1 Einträge total)
#
# Gruppe: M  F (1 Einträge total)
#
# Gruppe: „ Bl (1 Einträge total)
#
# Gruppe: -A-T (1 Einträge total)
#
# Gruppe: H Bl (1 Einträge total)
#
# Gruppe: Eapi (1 Einträge total)
#
# Gruppe:  Î?  (1 Einträge total)
#
# Gruppe:  Lim (1 Einträge total)
#
# Gruppe: Lieo (1 Einträge total)
#
# Gruppe:  Ger (1 Einträge total)
#
# Gruppe: W’ho (1 Einträge total)
#
# Gruppe: AMat (1 Einträge total)
#
# Gruppe: Ä.-G (1 Einträge total)
#
# Gruppe:  Glä (1 Einträge total)
#
# Gruppe: Led. (1 Einträge total)
#
# Gruppe: 'Wie (1 Einträge total)
#
# Gruppe:  Gos (1 Einträge total)
#
# Gruppe: 'Wil (2 Einträge total)
#
# Gruppe: Dr j (1 Einträge total)
#
# Gruppe: Loka (1 Einträge total)
#
# Gruppe: H.ji (1 Einträge total)
#
# Gruppe:  Gün (1 Einträge total)
#
# Gruppe: Gl   (1 Einträge total)
#
# Gruppe: J Ka (1 Einträge total)
#
# Gruppe: NI B (1 Einträge total)
#
# Gruppe: I.Di (1 Einträge total)
#
# Gruppe: U Bl (1 Einträge total)
#
# Gruppe:  Hag (1 Einträge total)
#
# Gruppe: Jon. (1 Einträge total)
#
# Gruppe: Sigd (1 Einträge total)
#
# Gruppe: (Emi (1 Einträge total)
#
# Gruppe:  Hae (1 Einträge total)
#
# Gruppe: El. (1 Einträge total)
#
# Gruppe: Tert (1 Einträge total)
#
# Gruppe: m. (1 Einträge total)
#
# Gruppe: W  H (1 Einträge total)
#
# Gruppe: F  H (2 Einträge total)
#
# Gruppe: h (1 Einträge total)
#
# Gruppe: Rons (1 Einträge total)
#
# Gruppe:  Hon (1 Einträge total)
#
# Gruppe: (Jos (1 Einträge total)
#
# Gruppe: Dold (1 Einträge total)
#
# Gruppe: Uetl (1 Einträge total)
#
# Gruppe: Dacì (1 Einträge total)
#
# Gruppe: Prud (1 Einträge total)
#
# Gruppe:  Hün (1 Einträge total)
#
# Gruppe: Bncb (1 Einträge total)
#
# Gruppe:  Ihm (1 Einträge total)
#
# Gruppe: C  I (1 Einträge total)
#
# Gruppe:  Ith (1 Einträge total)
#
# Gruppe: W  J (1 Einträge total)
#
# Gruppe: „The (1 Einträge total)
#
# Gruppe: smis (1 Einträge total)
#
# Gruppe: H Fr (1 Einträge total)
#
# Gruppe:  Käs (1 Einträge total)
#
# Gruppe: Ed- (1 Einträge total)
#
# Gruppe:   Rä (1 Einträge total)
#
# Gruppe:    K (1 Einträge total)
#
# Gruppe:  Kir (1 Einträge total)
#
# Gruppe: Ida. (1 Einträge total)
#
# Gruppe:  Kne (1 Einträge total)
#
# Gruppe: Erk (1 Einträge total)
#
# Gruppe:  Kol (1 Einträge total)
#
# Gruppe:  Kra (1 Einträge total)
#
# Gruppe: ^öll (1 Einträge total)
#
# Gruppe:  Bez (1 Einträge total)
#
# Gruppe: A Al (1 Einträge total)
#
# Gruppe: A(]l (1 Einträge total)
#
# Gruppe:  Leu (1 Einträge total)
#
# Gruppe: GUSS (1 Einträge total)
#
# Gruppe: ScNO (1 Einträge total)
#
# Gruppe: Ph.. (2 Einträge total)
#
# Gruppe: K..  (1 Einträge total)
#
# Gruppe:  Lun (1 Einträge total)
#
# Gruppe: Pffl (1 Einträge total)
#
# Gruppe: Pflv (1 Einträge total)
#
# Gruppe:  Mah (1 Einträge total)
#
# Gruppe: F„ V (1 Einträge total)
#
# Gruppe: L. G (1 Einträge total)
#
# Gruppe: Kud. (1 Einträge total)
#
# Gruppe: 'Woh (2 Einträge total)
#
# Gruppe: A.do (1 Einträge total)
#
# Gruppe: C. Ä (1 Einträge total)
#
# Gruppe: Gioa (1 Einträge total)
#
# Gruppe:  Mol (1 Einträge total)
#
# Gruppe: E* (1 Einträge total)
#
# Gruppe:    M (2 Einträge total)
#
# Gruppe: WiDt (1 Einträge total)
#
# Gruppe: Moss (1 Einträge total)
#
# Gruppe: ïï. (1 Einträge total)
#
# Gruppe: Cöle (1 Einträge total)
#
# Gruppe: H Mü (1 Einträge total)
#
# Gruppe: C Mü (1 Einträge total)
#
# Gruppe:  Mül (1 Einträge total)
#
# Gruppe: Pong (1 Einträge total)
#
# Gruppe: Flli (1 Einträge total)
#
# Gruppe:  Nie (1 Einträge total)
#
# Gruppe: A  O (1 Einträge total)
#
# Gruppe: F.jN (1 Einträge total)
#
# Gruppe: Fort (1 Einträge total)
#
# Gruppe: AVwe (1 Einträge total)
#
# Gruppe: Seln (1 Einträge total)
#
# Gruppe: Metr (1 Einträge total)
#
# Gruppe: Poll (1 Einträge total)
#
# Gruppe: ‘ '  (1 Einträge total)
#
# Gruppe: Cas- (1 Einträge total)
#
# Gruppe:  Rec (1 Einträge total)
#
# Gruppe: “ Il (1 Einträge total)
#
# Gruppe: (Joc (1 Einträge total)
#
# Gruppe: (Rel (2 Einträge total)
#
# Gruppe: Äege (1 Einträge total)
#
# Gruppe: Älbi (1 Einträge total)
#
# Gruppe: Gans (1 Einträge total)
#
# Gruppe: y Go (1 Einträge total)
#
# Gruppe: n  v (1 Einträge total)
#
# Gruppe: RIMl (1 Einträge total)
#
# Gruppe: » Ba (1 Einträge total)
#
# Gruppe: Mr.  (1 Einträge total)
#
# Gruppe: d. F (1 Einträge total)
#
# Gruppe: R Mf (1 Einträge total)
#
# Gruppe:  Ron (1 Einträge total)
#
# Gruppe: Papî (1 Einträge total)
#
# Gruppe: 'Wur (1 Einträge total)
#
# Gruppe: u Ba (1 Einträge total)
#
# Gruppe:  Rus (1 Einträge total)
#
# Gruppe: seid (1 Einträge total)
#
# Gruppe: cta. (1 Einträge total)
#
# Gruppe: ). . (1 Einträge total)
#
# Gruppe: (Vol (1 Einträge total)
#
# Gruppe: mar  (1 Einträge total)
#
# Gruppe: F. K (1 Einträge total)
#
# Gruppe: (Bot (1 Einträge total)
#
# Gruppe: I    (1 Einträge total)
#
# Gruppe: Einl (1 Einträge total)
#
# Gruppe: Rüde (1 Einträge total)
#
# Gruppe: Pins (1 Einträge total)
#
# Gruppe: Fläs (1 Einträge total)
#
# Gruppe: J ak (1 Einträge total)
#
# Gruppe: Eing (2 Einträge total)
#
# Gruppe: (SCh (1 Einträge total)
#
# Gruppe: ADHO (1 Einträge total)
#
# Gruppe: A.G. (1 Einträge total)
#
# Gruppe: A -G (1 Einträge total)
#
# Gruppe: Aoen (1 Einträge total)
#
# Gruppe: in K (1 Einträge total)
#
# Gruppe: Cd.. (1 Einträge total)
#
# Gruppe: H. O (1 Einträge total)
#
# Gruppe: u. R (1 Einträge total)
#
# Gruppe:  Spr (1 Einträge total)
#
# Gruppe: Sprü (1 Einträge total)
#
# Gruppe: (Eck (1 Einträge total)
#
# Gruppe: DI   (1 Einträge total)
#
# Gruppe: (Spr (1 Einträge total)
#
# Gruppe: L- (1 Einträge total)
#
# Gruppe: Üebr (1 Einträge total)
#
# Gruppe: Mgnr (1 Einträge total)
#
# Gruppe: H Ho (1 Einträge total)
#
# Gruppe: M Mi (1 Einträge total)
#
# Gruppe: III  (1 Einträge total)
#
# Gruppe:   Wü (1 Einträge total)
#
# Gruppe: 'Wer (1 Einträge total)
#
# Gruppe: n Bü (1 Einträge total)
#
# Gruppe: Ti S (1 Einträge total)
#
# Gruppe: Ï He (1 Einträge total)
#
# Gruppe: n Wü (1 Einträge total)
#
# Gruppe: n Du (1 Einträge total)
#
# Gruppe: T Sp (1 Einträge total)
#
# Gruppe: HI (1 Einträge total)
#
# Gruppe: » w  (1 Einträge total)
#
# Gruppe:  Kun (1 Einträge total)
#
# Gruppe:  Tie (1 Einträge total)
#
# Gruppe:   Go (1 Einträge total)
#
# Gruppe: Ang (1 Einträge total)
#
# Gruppe: Akt! (1 Einträge total)
#
# Gruppe: Stör (1 Einträge total)
#
# Gruppe:  Tha (2 Einträge total)
#
# Gruppe: Del. (1 Einträge total)
#
# Gruppe:  Tog (1 Einträge total)
#
# Gruppe: H Al (1 Einträge total)
#
# Gruppe: H Sp (1 Einträge total)
#
# Gruppe: Oons (1 Einträge total)
#
# Gruppe: F  U (1 Einträge total)
#
# Gruppe: J  U (1 Einträge total)
#
# Gruppe: A. L (1 Einträge total)
#
# Gruppe: Veil (1 Einträge total)
#
# Gruppe: H  V (2 Einträge total)
#
# Gruppe: in W (1 Einträge total)
#
# Gruppe: A Ba (1 Einträge total)
#
# Gruppe: R Wa (1 Einträge total)
#
# Gruppe: mecö (1 Einträge total)
#
# Gruppe: A.. (1 Einträge total)
#
# Gruppe: NacM (1 Einträge total)
#
# Gruppe:  Weg (1 Einträge total)
#
# Gruppe: vonn (1 Einträge total)
#
# Gruppe: & Pi (1 Einträge total)
#
# Gruppe: in C (1 Einträge total)
#
# Gruppe: pate (1 Einträge total)
#
# Gruppe: A Zä (1 Einträge total)
#
# Gruppe:    W (1 Einträge total)
#
# Gruppe: F. F (1 Einträge total)
#
# Gruppe: AOeH (1 Einträge total)
#
# Gruppe:  Wid (1 Einträge total)
#
# Gruppe: Wipt (1 Einträge total)
#
# Gruppe: (. B (1 Einträge total)
#
# Gruppe: d. C (1 Einträge total)
#
# Gruppe: ). R (1 Einträge total)
#
# Gruppe:  Wis (1 Einträge total)
#
# Gruppe: Baii (1 Einträge total)
#
# Gruppe: i. B (1 Einträge total)
#
# Gruppe: G.jB (1 Einträge total)
#
# Gruppe: i.Sc (1 Einträge total)
#
# Gruppe:  Wun (1 Einträge total)
#
# Gruppe: rein (1 Einträge total)
#
# Gruppe: D. P (1 Einträge total)
#
# Gruppe: J? N (1 Einträge total)
