# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read all the files into separate DataFrames
jobs_b1 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b1.tsv')
jobs_b2 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b2.tsv')
jobs_b3 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b3.tsv')
jobs_b4 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b4.tsv')
jobs_b5 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b5.tsv')
jobs_b6 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b6.tsv')
# jobs_b7 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b7.tsv')
# jobs_b8 = pd.read_table('C:/Users/dkilc/OneDrive - Universitaet Bern/Neu/Desktop/Studium/DH_WORK/PTT/Telefonbuch/b8.tsv')

# Combine all DataFrames into one
all_jobs = pd.concat([jobs_b1, jobs_b2, jobs_b3, jobs_b4, jobs_b5, jobs_b6])

# Drop rows with missing values in the "Supplement" column
all_jobs.dropna(subset=['Supplement'], inplace=True)

# Filter the DataFrame to include only rows where the "Supplement" column contains the string 'radio'
radio_jobs = all_jobs[all_jobs['Supplement'].str.contains('radio', case=False)]

# Group by "Year" and count occurrences of 'radio' for each year
radio_counts = radio_jobs.groupby('Year').size()

# Plot the counts
radio_counts.plot(kind='bar', xlabel='Year', ylabel='Count', title='Occurrences of "radio" in Supplement Column by Year')
plt.show()
